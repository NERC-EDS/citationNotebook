# %%
import requests

# %%
schol_url = 'http://api.scholexplorer.openaire.eu/v2/Links'
# format = '?format=json'
# page = '?page=87'
# url = catalogue_url + page

headers = {
    'sourcePid': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
}

r = requests.get(schol_url, headers)
print(r.status_code)
r.json()
# Out:
# 200
# {'currentPage': 0,
#  'totalLinks': 2514,
#  'totalPages': 26,
#  'result': [{'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.y3gyt4',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.y3gyt4'},
#      {'ID': '50|doi_________::cae80049d444f3f4b4f89c3b04ccc736',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::cae80049d444f3f4b4f89c3b04ccc736'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.2kwzsm',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.2kwzsm'},
#      {'ID': '50|doi_________::c48e1d16c38db3cae822feda9786c807',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::c48e1d16c38db3cae822feda9786c807'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.x5n53h',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.x5n53h'},
#      {'ID': '50|doi_________::65c8fb961537a0ba584eff113a4ab044',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::65c8fb961537a0ba584eff113a4ab044'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.fjexf5',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.fjexf5'},
#      {'ID': '50|doi_________::ec1f319d6c4187d92916a58bdfa56a28',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::ec1f319d6c4187d92916a58bdfa56a28'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.uxw6jr',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.uxw6jr'},
#      {'ID': '50|doi_________::2e9f4b1cd8a61da6453b7eb102c13ff7',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::2e9f4b1cd8a61da6453b7eb102c13ff7'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.5cbv94',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.5cbv94'},
#      {'ID': '50|doi_________::70c2539b6d058afec3132c98458f6d7a',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::70c2539b6d058afec3132c98458f6d7a'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.4b44fn',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.4b44fn'},
#      {'ID': '50|doi_________::9fff19a3d469b1fa6270bd4794b5fce2',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::9fff19a3d469b1fa6270bd4794b5fce2'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.q7chzf',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.q7chzf'},
#      {'ID': '50|doi_________::c30dc3b9259c2a7d07fcaf38be30a792',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::c30dc3b9259c2a7d07fcaf38be30a792'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.zmkb4q',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.zmkb4q'},
#      {'ID': '50|doi_________::669f2621835fff10765cf556db277cb5',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::669f2621835fff10765cf556db277cb5'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.m2psjz',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.m2psjz'},
#      {'ID': '50|doi_________::6de22eaa1c6660bcf43d1a09ae278fb9',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::6de22eaa1c6660bcf43d1a09ae278fb9'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.95a8sk',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.95a8sk'},
#      {'ID': '50|doi_________::d9b831779533e7ed7e117f6c05c3fe50',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::d9b831779533e7ed7e117f6c05c3fe50'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.behu3s',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.behu3s'},
#      {'ID': '50|doi_________::ac5d90cbe4f47b7649b7b422f2a955da',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::ac5d90cbe4f47b7649b7b422f2a955da'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.cmeygk',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.cmeygk'},
#      {'ID': '50|doi_________::1f1548bc511e4a85ac9366146fd9e4e8',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::1f1548bc511e4a85ac9366146fd9e4e8'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.wbxvjf',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.wbxvjf'},
#      {'ID': '50|doi_________::38a0f52df4f792a97e3c7a2dd2943618',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::38a0f52df4f792a97e3c7a2dd2943618'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.3m2r8t',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.3m2r8t'},
#      {'ID': '50|doi_________::37655ec05052acb4a54c356e4cc201d3',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::37655ec05052acb4a54c356e4cc201d3'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2022-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2022-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2022-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.kmqpn8',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.kmqpn8'},
#      {'ID': '50|doi_________::55b263f9d48c5d60d89d5ef0542203b9',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::55b263f9d48c5d60d89d5ef0542203b9'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2022-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.gchkcf',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.gchkcf'},
#      {'ID': '50|doi_________::e5276548bbb5cc988a2f74888eca6017',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::e5276548bbb5cc988a2f74888eca6017'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.h53pd2',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.h53pd2'},
#      {'ID': '50|doi_________::a704c38a4bc43998916c65dac0898883',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a704c38a4bc43998916c65dac0898883'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.m9fy7g',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.m9fy7g'},
#      {'ID': '50|doi_________::8f0a90ccb3dfce3791033b281cf1cb89',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::8f0a90ccb3dfce3791033b281cf1cb89'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2022-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2022-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2022-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.h9ezgj',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.h9ezgj'},
#      {'ID': '50|doi_________::9c6966603d82a7ba86cc3681b785f702',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::9c6966603d82a7ba86cc3681b785f702'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.n96ver',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.n96ver'},
#      {'ID': '50|doi_________::0734dc8485eb8a1d31e8dff1623bea28',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::0734dc8485eb8a1d31e8dff1623bea28'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.9hcu35',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.9hcu35'},
#      {'ID': '50|doi_________::8da7307898a48bd4b8b69149f9b5ee3a',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::8da7307898a48bd4b8b69149f9b5ee3a'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.943cev',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.943cev'},
#      {'ID': '50|doi_________::0c0a197ea4453b4f1440addf5b12a83b',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::0c0a197ea4453b4f1440addf5b12a83b'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.cvhvvh',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.cvhvvh'},
#      {'ID': '50|doi_________::e95c7822be1e60168026136880f59b24',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::e95c7822be1e60168026136880f59b24'}],
#     'Title': 'Occurrence Download',
# ...
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.9pyene',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.9pyene'},
#      {'ID': '50|doi_________::a1725c87c72b245569eb5bc9238bcefe',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a1725c87c72b245569eb5bc9238bcefe'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2022-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.cfeqek',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.cfeqek'},
#      {'ID': '50|doi_________::6051d8f3ab05b657da0451745ebe2e2d',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::6051d8f3ab05b657da0451745ebe2e2d'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2020-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.c3fpqg',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.c3fpqg'},
#      {'ID': '50|doi_________::8f8b12be9cfa4fbf0a87d1ebe3461a9b',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::8f8b12be9cfa4fbf0a87d1ebe3461a9b'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.fqmanr',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.fqmanr'},
#      {'ID': '50|doi_________::dbab3d53ebf583c8436e8f288f928707',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::dbab3d53ebf583c8436e8f288f928707'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.d93ccs',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.d93ccs'},
#      {'ID': '50|doi_________::b1b1951b07206f1de149bb4ac6c64be3',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::b1b1951b07206f1de149bb4ac6c64be3'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.hzsddb',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.hzsddb'},
#      {'ID': '50|doi_________::94fec3fe5aa47837be314a70dd6f7ca2',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::94fec3fe5aa47837be314a70dd6f7ca2'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.8q4gb2',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.8q4gb2'},
#      {'ID': '50|doi_________::30c7107e0280e2f9b54c7c651a9eacac',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::30c7107e0280e2f9b54c7c651a9eacac'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2021-01-01',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2021-01-01'},
#   {'RelationshipType': {'Name': 'IsReferencedBy',
#     'SubType': 'IsReferencedBy',
#     'SubTypeSchema': 'datacite'},
#    'source': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.5285/5a711904-ef42-46a3-9f47-3f0d6b231f65'},
#      {'ID': '50|doi_________::a2f2b74897a88aee2881ab2ec17d5294',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::a2f2b74897a88aee2881ab2ec17d5294'}],
#     'Title': 'Epipelagic mesozooplankton distribution and abundance in Southern Ocean Atlantic sector and the North Atlantic and Arctic 1996-2013',
#     'Creator': [{'Name': 'Ward, Peter', 'Identifier': []},
#      {'Name': 'Tarling, Geraint', 'Identifier': []},
#      {'Name': 'Shreeve, Rachael', 'Identifier': []},
#      {'Name': 'ten Hoopen, Petra', 'Identifier': []}],
#     'PublicationDate': '2020-03-13',
#     'Publisher': [{'name': 'UK Polar Data Centre, Natural Environment Research Council, UK Research & Innovation',
#       'identifier': []}]},
#    'target': {'Type': 'dataset',
#     'Identifier': [{'ID': '10.15468/dl.qdq5ys',
#       'IDScheme': 'doi',
#       'IDURL': 'https://dx.doi.org/10.15468/dl.qdq5ys'},
#      {'ID': '50|doi_________::edfbd883b6ac70d6e58215932b61fce5',
#       'IDScheme': 'D-Net Identifier',
#       'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_________::edfbd883b6ac70d6e58215932b61fce5'}],
#     'Title': 'Occurrence Download',
#     'Creator': [{'Name': 'Occdownload Gbif.Org', 'Identifier': []}],
#     'PublicationDate': '2021-01-01',
#     'Publisher': [{'name': 'The Global Biodiversity Information Facility',
#       'identifier': []}]},
#    'HarvestDate': '2020-03-13',
#    'LicenseURL': None,
#    'LinkProvider': [{'name': 'Datacite',
#      'identifier': [{'ID': '10|openaire____::9e3be59865b2c1c335d32dae2fe7b254',
#        'IDScheme': 'DNET Identifier',
#        'IDURL': None}]}],
#    'LinkPublicationDate': '2020-03-13'}]}

# %%
Scholex_df['datasetTitle'][1]
# Out:
# 'Southern Hemisphere winter sea ice concentration simulated by HadCM3 to best explain the early last interglacial Antarctic isotope peak'

# %%
citations = r.json()['totalLinks']
print(citations)
# Out:
# 4

# %%
dataseries = r.json()['result']
type(dataseries)
print(len(r.json()['result']))
# Out:
# 4

# %%
dataseries[0]['target']['Identifier']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16432/1592180105.py in <module>
# ----> 1 dataseries[0]['target']
#
# NameError: name 'dataseries' is not defined

# %%
dataseries[3]['target']
# Out:
# {'Type': 'literature',
#  'Identifier': [{'ID': '10.5194/essd-2019-74',
#    'IDScheme': 'doi',
#    'IDURL': 'https://dx.doi.org/10.5194/essd-2019-74'},
#   {'ID': '50|doi_dedup___::3534ece06aa3e2369c55417bc9c907bb',
#    'IDScheme': 'D-Net Identifier',
#    'IDURL': 'http://scholexplorer.openaire.eu/index.html#/detail/50|doi_dedup___::3534ece06aa3e2369c55417bc9c907bb'}],
#  'Title': 'The UK Environmental Change Network datasets – integrated and co-located data for long-term environmental research (1993–2015)',
#  'Creator': [{'Name': 'Rennie, Susannah', 'Identifier': []},
#   {'Name': 'Andrews, Chris', 'Identifier': []},
#   {'Name': 'Atkinson, Sarah', 'Identifier': []},
#   {'Name': 'Beaumont, Deborah', 'Identifier': []},
#   {'Name': 'Benham, Sue', 'Identifier': []},
#   {'Name': 'Bowmaker, Vic', 'Identifier': []},
#   {'Name': 'Dick, Jan', 'Identifier': []},
#   {'Name': 'Dodd, Bev', 'Identifier': []},
#   {'Name': 'McKenna, Colm', 'Identifier': []},
#   {'Name': 'Pallett, Denise', 'Identifier': []},
#   {'Name': 'Rose, Rob', 'Identifier': []},
#   {'Name': 'Schäfer, Stefanie M.', 'Identifier': []},
#   {'Name': 'Scott, Tony', 'Identifier': []},
#   {'Name': 'Taylor, Carol', 'Identifier': []},
#   {'Name': 'Watson, Helen', 'Identifier': []}],
#  'PublicationDate': '2020-01-14',
#  'Publisher': []}

# %%
# get info
citations = r.json()['totalLinks']
dataseries = r.json()['result']
relationshipType = dataseries[0]['RelationshipType']['Name']
linkPublicationDate = dataseries[0]['LinkPublicationDate']
pubTitle = dataseries[0]['target']['Title']
publicationDate = dataseries[0]['target']['PublicationDate']
print(citations)
print(relationshipType)
print(linkPublicationDate)
print(pubTitle)
print(publicationDate)
# Out:
# 4
# IsReferencedBy
# 2020-05-06
# State Tagging for Improved Earth and Environmental Data Quality Assurance
# 2020-05-06

# %%
import requests
import pandas as pd
# this will be list of dataset DOIs from datacite API:
datasetDOIs = ['10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73', '10.5285/f493ad5c-585c-475d-a374-2f77b5866bc4', '10.5285/74a588cc-723c-4a35-ac0c-223f5b92ee36'] 
schol_url = 'http://api.scholexplorer.openaire.eu/v2/Links'


info = []

for doi in datasetDOIs:
    headers = {'sourcePid': doi}
    r = requests.get(schol_url, headers)
    print(headers)
    print(r.status_code)
    
    dataseries = r.json()['result']
    citations = r.json()['totalLinks']
    
    info.append([citations,
                         dataseries[0]['RelationshipType']['Name'],
                         dataseries[0]['LinkPublicationDate'],
                         dataseries[0]['target']['Title'],
                         dataseries[0]['target']['PublicationDate']])
    
    
column_names = ["citations", "relationshipType", "linkPubDate", "pubTitle", "pubDate"]
df = pd.DataFrame(info, columns = column_names)
# Out:
# {'sourcePid': '10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73'}
# 200
# {'sourcePid': '10.5285/f493ad5c-585c-475d-a374-2f77b5866bc4'}
# 200
# {'sourcePid': '10.5285/74a588cc-723c-4a35-ac0c-223f5b92ee36'}
# 200

# %%
df
# Out:
#    citations relationshipType linkPubDate  \
# 0         18   IsReferencedBy  2017-01-01
# 1          1   IsReferencedBy  2020-01-01
# 2          5   IsReferencedBy  2016-01-01
#
#                                             pubTitle     pubDate
# 0  Managing hedgerows for nocturnal wildlife: Do ...  2019-05-28
# 1  Abrupt changes in Great Britain vegetation car...  2019-10-11
# 2  Estimación de datos faltantes de lluvia mensua...  2018-09-01

# %%
def getDatasetCitations(dataDOIs):
    scholexInfo = []

    for doi in dataDOIs:
        headers = {'sourcePid': doi}
        r = requests.get('http://api.scholexplorer.openaire.eu/v2/Links', headers)
        print(headers)
        print(r.status_code)

        dataseries = r.json()['result']
        citations = r.json()['totalLinks']
        
        # scholex hold no further info if no citations, therefore need a catcher here
        if citations == 0:
            break
        else:
            
            
            
            
            scholexInfo.append([citations,
                             dataseries[0]['RelationshipType']['Name'],
                             dataseries[0]['LinkPublicationDate'],
                             dataseries[0]['target']['Title'],
                             dataseries[0]['target']['PublicationDate']])
            

    column_names = ["citations", "relationshipType", "linkPubDate", "pubTitle", "pubDate"]
    Scholex_df = pd.DataFrame(scholexInfo, columns = column_names)
    return Scholex_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12088/3731971676.py in <module>
#      25     Scholex_df = pd.DataFrame(scholexInfo, columns = column_names)
#      26     return Scholex_df
# ---> 27 Scholex_df = getDatasetCitations()
#
# TypeError: getDatasetCitations() missing 1 required positional argument: 'dataDOIs'

# %%
import requests
import pandas as pd

dataDOIs = ['10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73', '10.5285/f493ad5c-585c-475d-a374-2f77b5866bc4', '10.5285/74a588cc-723c-4a35-ac0c-223f5b92ee36'] 

Scholex_df = getDatasetCitations(dataDOIs)
# Out:
# {'sourcePid': '10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73'}
# 200
# {'sourcePid': '10.5285/f493ad5c-585c-475d-a374-2f77b5866bc4'}
# 200
# {'sourcePid': '10.5285/74a588cc-723c-4a35-ac0c-223f5b92ee36'}
# 200

# %%
Scholex_df
# Out:
#    citations relationshipType linkPubDate  \
# 0         18   IsReferencedBy  2017-01-01
# 1          1   IsReferencedBy  2020-01-01
# 2          5   IsReferencedBy  2016-01-01
#
#                                             pubTitle     pubDate
# 0  Managing hedgerows for nocturnal wildlife: Do ...  2019-05-28
# 1  Abrupt changes in Great Britain vegetation car...  2019-10-11
# 2  Estimación de datos faltantes de lluvia mensua...  2018-09-01
