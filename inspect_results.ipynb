# %%
# load and inspect results
import pandas as pd
latest_results = pd.read_csv("/home/matnic/Projects/citationNotebook/Results/v3/latest_results.csv")
latest_results.columns
# Out:
# Index(['data_doi', 'data_publisher', 'data_title', 'data_publication_year',
#        'data_authors', 'relation_type_id', 'publication_doi',
#        'publication_title', 'publication_date', 'publication_authors',
#        'citation_event_source', 'pub_publisher', 'publication_type',
#        'PubCitationStr', 'data_doi_url', 'publication_doi_url',
#        'publicationYear', 'date_added'],
#       dtype='object')

# %%
latest_results.head()
# Out:
#                                        data_doi  \
# 0  10.5285/2641515f-5b76-445c-a936-1da51bf365ad
# 1  10.5285/6feac38a-5847-46f9-84e4-e7e9d291f935
# 2  10.5285/db55406b-c9a1-4a9e-88c2-2abbcb4bcad3
# 3  10.5285/5321bc6e-be35-4ed3-9b56-25598d61ac8f
# 4  10.5285/c4ecfe25-12f2-453b-ad19-49a19e90ee32
#
#                                  data_publisher  \
# 0  Environmental Information Data Centre (EIDC)
# 1                       Polar Data Centre (PDC)
# 2  Environmental Information Data Centre (EIDC)
# 3  Environmental Information Data Centre (EIDC)
# 4                       Polar Data Centre (PDC)
#
#                                           data_title  data_publication_year  \
# 0  Exposure of burrowing mammals to Radon Rn-222 ...                 2012.0
# 1  Snow accumulation from the Bryan Coast ice cor...                 2017.0
# 2  Foraging behaviour of Parus major held in temp...                 2017.0
# 3  Invertebrate activity data from an experiment ...                 2017.0
# 4  Antarctic regional snow accumulation composite...                 2017.0
#
#                                         data_authors relation_type_id  \
# 0  ['Beresford, N.A.', 'Barnett, C.L.', 'Vives i ...      is-cited-by
# 1                              ['Thomas, Elizabeth']      is-cited-by
# 2          ['Thorogood, R', 'Kokko, H', 'Mappes, J']      is-cited-by
# 3  ['Griffiths, H.M.', 'Ashton, L.A.', 'Walker, A...      is-cited-by
# 4                              ['Thomas, Elizabeth']      is-cited-by
#
#                    publication_doi  \
# 0  10.1016/j.scitotenv.2012.05.023
# 1             10.1002/2015gl065750
# 2               10.17863/cam.20713
# 3          10.1111/1365-2656.12728
# 4               10.5194/cp-2017-18
#
#                                    publication_title publication_date  \
# 0             Exposure of burrowing mammals to 222Rn        10/6/2012
# 1  Twentieth century increase in snowfall in coas...        3/11/2015
# 2                                     Info not given   Info not given
# 3  Ants are the major agents of resource removal ...         9/8/2017
# 4  Review of regional Antarctic snow accumulation...        28/3/2017
#
#                                  publication_authors citation_event_source  \
# 0  [['N.A.', 'Beresford'], ['C.L.', 'Barnett'], [...     datacite-crossref
# 1  [['E. R.', 'Thomas'], ['J. S.', 'Hosking'], ['...     datacite-crossref
# 2                                     Info not given      datacite-related
# 3  [['Hannah M.', 'Griffiths'], ['Louise A.', 'As...     datacite-crossref
# 4  [['Elizabeth R.', 'Thomas'], ['J. Melchior', '...     datacite-crossref
#
#      pub_publisher publication_type  \
# 0  journal-article  journal-article
# 1  journal-article  journal-article
# 2   Info not given   Info not given
# 3  journal-article  journal-article
# 4   posted-content   posted-content
#
#                                       PubCitationStr  \
# 0  Beresford, N.A., Barnett, C.L., Vives i Batlle...
# 1  Thomas, E.R., Hosking, J.S., Tuckwell, R.R., W...
# 2  Thorogood, R., Kokko, H. & Mappes, J. (2018) S...
# 3  Griffiths, H.M., Ashton, L.A., Walker, A.E., H...
# 4  Thomas, E.R., van Wessem, J.M., Roberts, J., e...
#
#                                         data_doi_url  \
# 0  doi.org/10.5285/2641515f-5b76-445c-a936-1da51b...
# 1  doi.org/10.5285/6feac38a-5847-46f9-84e4-e7e9d2...
# 2  doi.org/10.5285/db55406b-c9a1-4a9e-88c2-2abbcb...
# 3  doi.org/10.5285/5321bc6e-be35-4ed3-9b56-25598d...
# 4  doi.org/10.5285/c4ecfe25-12f2-453b-ad19-49a19e...
#
#                        publication_doi_url publicationYear  date_added
# 0  doi.org/10.1016/j.scitotenv.2012.05.023            2012  2025-10-15
# 1             doi.org/10.1002/2015gl065750            2015  2025-10-15
# 2               doi.org/10.17863/cam.20713             NaN  2025-10-15
# 3          doi.org/10.1111/1365-2656.12728            2017  2025-10-15
# 4               doi.org/10.5194/cp-2017-18            2017  2025-10-15

# %%
len(latest_results['data_publication_year'])
# Out:
# 12725

# %%
# how many rows and how many "Info not given" per publisher
summary = (
    latest_results
    .groupby("data_publisher")
    .agg(
        total_rows=("data_doi", "count"),
        missing_pub_title=("publication_title", lambda x: (x == "Info not given").sum()),
        missing_pub_date=("publication_date", lambda x: (x == "Info not given").sum()),
        missing_pub_authors=("publication_authors", lambda x: (x == "Info not given").sum()),
    )
)

# Add percentages to make it easy to interpret
for col in summary.columns[1:]:
    summary[f"{col}_pct"] = summary[col] / summary["total_rows"] * 100

summary.sort_values("total_rows", ascending=False)
# Out:
#                                                total_rows  missing_pub_title  \
# data_publisher
# Environmental Information Data Centre (EIDC)         4940                 68
# Polar Data Centre (PDC)                              3477                769
# Centre for Environmental Data Analysis (CEDA)        3280                  0
# British Oceanographic Data Centre (BODC)              673                  0
# National Geoscience Data Centre (NGDC)                284                  0
#
#                                                missing_pub_date  \
# data_publisher
# Environmental Information Data Centre (EIDC)                165
# Polar Data Centre (PDC)                                     785
# Centre for Environmental Data Analysis (CEDA)                 0
# British Oceanographic Data Centre (BODC)                      0
# National Geoscience Data Centre (NGDC)                        0
#
#                                                missing_pub_authors  \
# data_publisher
# Environmental Information Data Centre (EIDC)                    69
# Polar Data Centre (PDC)                                        769
# Centre for Environmental Data Analysis (CEDA)                    0
# British Oceanographic Data Centre (BODC)                         0
# National Geoscience Data Centre (NGDC)                           0
#
#                                                missing_pub_title_pct  \
# data_publisher
# Environmental Information Data Centre (EIDC)                1.376518
# Polar Data Centre (PDC)                                    22.116767
# Centre for Environmental Data Analysis (CEDA)               0.000000
# British Oceanographic Data Centre (BODC)                    0.000000
# National Geoscience Data Centre (NGDC)                      0.000000
#
#                                                missing_pub_date_pct  \
# data_publisher
# Environmental Information Data Centre (EIDC)               3.340081
# Polar Data Centre (PDC)                                   22.576934
# Centre for Environmental Data Analysis (CEDA)              0.000000
# British Oceanographic Data Centre (BODC)                   0.000000
# National Geoscience Data Centre (NGDC)                     0.000000
#
#                                                missing_pub_authors_pct
# data_publisher
# Environmental Information Data Centre (EIDC)                  1.396761
# Polar Data Centre (PDC)                                      22.116767
# Centre for Environmental Data Analysis (CEDA)                 0.000000
# British Oceanographic Data Centre (BODC)                      0.000000
# National Geoscience Data Centre (NGDC)                        0.000000

# %%
duplicates = latest_results.groupby(["data_doi", "publication_doi"]).size().reset_index(name="count")
duplicates = duplicates[duplicates["count"] > 1]

# %%
cols_to_check = ["publication_title", "publication_date", "publication_authors"]
latest_results["any_missing"] = latest_results[cols_to_check].apply(
    lambda row: any(v == "Info not given" for v in row), axis=1
)
publisher_missing = latest_results.groupby("pub_publisher")["any_missing"].mean() * 100
print(publisher_missing.sort_values(ascending=False))
# Out:
# pub_publisher
# report                                            100.0
# not a doi                                         100.0
# Info not given                                    100.0
# Molluscan Research                                  0.0
# Monthly Weather Review                              0.0
#                                                   ...
# Geological Society London Memoirs                   0.0
# Geological Society London Special Publications      0.0
# Geological Society of America Bulletin              0.0
# Geology                                             0.0
# Geochemical Transactions                            0.0
# Name: any_missing, Length: 650, dtype: float64

# %%
bodc = latest_results[latest_results['data_publisher'] == "British Oceanographic Data Centre (BODC)"]
bodc["publicationYear"].value_counts()

# %%
gbif = latest_results[latest_results['publication_doi'].str.contains("10.15468")]
gbif
# Out:
# Empty DataFrame
# Columns: [data_doi, data_publisher, data_title, data_publication_year, data_authors, relation_type_id, publication_doi, publication_title, publication_date, publication_authors, citation_event_source, pub_publisher, publication_type, PubCitationStr, data_doi_url, publication_doi_url, publicationYear, date_added, any_missing]
# Index: []

# %%
latest_results['data_publisher'].unique()
# Out:
# array(['Environmental Information Data Centre (EIDC)',
#        'Polar Data Centre (PDC)', nan,
#        'British Oceanographic Data Centre (BODC)',
#        'Centre for Environmental Data Analysis (CEDA)',
#        'National Geoscience Data Centre (NGDC)'], dtype=object)

# %%
# see most cited dataset dois for each publisher

for dc in latest_results['data_publisher'].unique():

    dc_results = latest_results[latest_results['data_publisher'] == dc]
    print(dc)
    print(dc_results['data_doi'].value_counts()[0:5])
# Out:
# Environmental Information Data Centre (EIDC)
# data_doi
# 10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73    82
# 10.5285/33604ea0-c238-4488-813d-0ad9ab7c51ca    64
# 10.5285/bb15e200-9349-403c-bda9-b430093807c7    49
# 10.5285/5dc179dc-f692-49ba-9326-a6893a503f6e    40
# 10.5285/8baf805d-39ce-4dac-b224-c926ada353b7    35
# Name: count, dtype: int64
# Polar Data Centre (PDC)
# data_doi
# 10.5285/324137d3-cfc5-4cf6-a360-1a293a3e9ed6    32
# 10.5285/a89028f1-76d0-41f4-bee0-021633a8b0ed    32
# 10.5285/2fd95199-365e-4da1-ae26-3b6d48b3e6ac    30
# 10.5285/0f90d926-99ce-43c9-b536-0c7791d1728b    30
# 10.5285/f4dfc0ee-4f61-47c5-a5a8-238e02ff2fdd    28
# Name: count, dtype: int64
# nan
# Series([], Name: count, dtype: int64)
# British Oceanographic Data Centre (BODC)
# data_doi
# 10.5285/cd857050-0c6d-3a71-e053-6c86abc08527    12
# 10.5285/bbaf922a-e46e-7e94-e053-6c86abc0089a    11
# 10.5285/7a150d33-956b-0fec-e053-6c86abc0b35c    10
# 10.5285/215a1e9b-428b-52f5-e053-6c86abc06d17     9
# 10.5285/f7021d34-0290-70fc-e044-000b5de50f38     9
# Name: count, dtype: int64
# Centre for Environmental Data Analysis (CEDA)
# data_doi
# 10.5285/7273023a04d24da58ec5d83343cd861d    21
# 10.5285/e3d21f98cc764d1185b0d6e662532831    21
# 10.5285/d35ac1955c264deea9699d08dbc568f2    21
# 10.5285/80c10f8aeb7049778c5a15ede4917128    21
# 10.5285/44adfc4f92834bd9950341dd24d6d2e0    21
# Name: count, dtype: int64
# National Geoscience Data Centre (NGDC)
# data_doi
# 10.5285/bbbacfee-7b9d-4d05-882d-9c14de89bff4    15
# 10.5285/2edf6c47-fd18-4540-b449-b78d12422193    12
# 10.5285/f8c2c92a-450d-49e7-bfac-9317d2828e33    12
# 10.5285/1f19a50c-b600-4f63-9512-e6c94f79d49c    11
# 10.5285/7a7bf4c1-b7be-42cc-aa58-a6c96acaf41a     9
# Name: count, dtype: int64

# %%
# view citations for a particular data_doi
doi = "10.5285/bbaf922a-e46e-7e94-e053-6c86abc0089a"
result = latest_results[latest_results['data_doi'] == doi]
print(result['data_title'].iloc[0])
result = result[[# 'relation_type_id', 
                 'publication_doi',
       'publication_title', # 'publication_date', 'publication_authors',
       'citation_event_source', 'pub_publisher', 
       #'publication_type'
       ]]

with pd.option_context('display.max_colwidth', 400):
    display(result)
# Out:
# Physical and modelled interactions between coral growth and water hydrodynamics using <em>Lophelia pertusa</em> as a model organism.
#                                    publication_doi  \
# 9567                        10.5281/zenodo.1254523
# 9568  10.5285/aaf5a71d-75ea-38d5-e053-6c86abc03e63
# 9569                         10.5281/zenodo.570586
# 9570                  10.1371/journal.pone.0194659
# 9571                         10.5281/zenodo.570861
# 9572                        10.5281/zenodo.3566881
# 9573                        10.5281/zenodo.3484709
# 9574                     10.1007/s00300-016-1957-3
# 9575                        10.5281/zenodo.1255751
# 9576                         10.5281/zenodo.570850
# 9577                    10.1038/s41598-022-24711-7
#
#                                                                                                                                                                                                       publication_title  \
# 9567                                                                                                                                                   Does Food Quality Control The Distribution Of Cold-Water Corals?
# 9568  Physical and visual effects of ocean acidification on cold-water coral (<em>Lophelia pertusa</em>) skeleton samples from the Southern California Bight, USA (2010-2015) and the Mingulay Reef Complex, UK (2012).
# 9569                                                                                                                                                       The Sensitivity Of Cold-Water Corals To Environmental Change
# 9570                                                                                               Niche overlap between a cold-water coral and an associated sponge for isotopically-enriched particulate food sources
# 9571                                                                                 The Lofoten-Vesterålen Ocean Observatory; Understanding Behavioural Response Of Benthic Organisms From Long-Term Multi-Sensor Data
# 9572                                                                 Raw data for Maier et al. "Seasonal controls on the diet, metabolic activity, tissue reserves and growth of the cold-water coral Lophelia pertusa"
# 9573                                                                                   Ecophysiology of Lophelia pertusa and Madrepora oculata from Formigas Seamount (Azores): The influence of different water masses
# 9574                                                                      Water mass characteristics and associated fauna of a recently discovered Lophelia pertusa (Scleractinia: Anthozoa) reef in Greenlandic waters
# 9575                                                                                                        Biophysical Modelling Of Lophelia Pertusa Larval Dispersal In The Skagerrak – An Area Isolated By Distance?
# 9576                                                                                                  Fate Of Cold-Water Coral Reefs-Identifying Drivers Of Ecosystem Change: Project Overview And Synergies With Atlas
# 9577                                                                                                                            Local-scale feedbacks influencing cold-water coral growth and subsequent reef formation
#
#      citation_event_source       pub_publisher
# 9567               scholex              ZENODO
# 9568               scholex  Unknown Repository
# 9569               scholex              ZENODO
# 9570               scholex            PLoS ONE
# 9571               scholex              ZENODO
# 9572               scholex              ZENODO
# 9573               scholex              ZENODO
# 9574               scholex       Polar Biology
# 9575               scholex              ZENODO
# 9576               scholex              ZENODO
# 9577               scholex  Unknown Repository

# %%
latest_results.columns
# Out:
# Index(['data_doi', 'data_publisher', 'data_title', 'data_publication_year',
#        'data_authors', 'relation_type_id', 'publication_doi',
#        'publication_title', 'publication_date', 'publication_authors',
#        'citation_event_source', 'pub_publisher', 'publication_type',
#        'PubCitationStr', 'data_doi_url', 'publication_doi_url',
#        'publicationYear', 'date_added', 'any_missing'],
#       dtype='object')
