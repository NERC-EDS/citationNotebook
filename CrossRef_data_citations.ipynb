# %% [markdown]
# ### Workflow to collect citation information for datasets published by NERC data centres

# %%
import sys
sys.path.insert(0, '..')

# module to run event data queries
from crossRef_fun import getDataCiteInfo, eventData, eventRecord
import os # some file manipulations
from math import ceil
import json
import pandas as pd
import time
import re
import requests
import datetime

# %%
email = "matnic@ceh.ac.uk"
prefix = "10.5285"
start_date = "2023-01-01"
end_date = "2023-03-01" # something to check date is valid
datetime.date.fromisoformat(start_date)
datetime.date.fromisoformat(end_date)

# filename to save json event data to
filename = "event_data_" + prefix + "_" + start_date + "_" + end_date + ".json"

# Set up the query
ed = mrced2.eventData(email = email, outputFile = filename)
ed.buildQuery({'obj-id.prefix' : prefix, 'from-occurred-date' : start_date, 'until-occurred-date' : end_date}) 

# run the query to determine number of events
ed.runQuery(retry = 5) # scholix = False - can query scholix api as well - worth exploring

# calculate how many pages will need to be iterated over
num_pages = ceil(ed.events.count()/1000)

# set up folder to result jsons into
results_folder = "NERC_EDS_events_from_" + start_date + "_up_to_" + end_date
os.mkdir(results_folder) # not able to overwrite folder of the same name - delete folder and re-write?, or, add a folder with a new name each time?

# find info from all the pages
ed.getAllPages(num_pages, {'rows': 1000, 'obj-id.prefix' : prefix, 'from-occurred-date' : start_date, 'until-occurred-date' : end_date}, fileprefix = (results_folder + '/page')) #

# %%
# Code for getting results based on a list of DOIs rather than a date range
import sys
sys.path.insert(0, '..')

import mrced2 # module to run event data queries
from getDataCiteInfo import getDataCiteInfo
import os # some file manipulations
from math import ceil
import json
import pandas as pd
import time
import re
import requests
import datetime

email = "matnic@ceh.ac.uk"

# import list of DOIs to find event data for
doi_list = pd.read_csv("marika_doi_list.csv", header = None)

# set up folder to result jsons into
results_folder = "NERC_EDS_events_from_doi_list_scholix"
os.makedirs(results_folder, exist_ok=True)

for count, doi in enumerate(doi_list[0]):
    print(doi)

    fileDoi = doi.replace("/", "_")
    
    # Set up the query
    # filename to save json event data to
    filename = f"{results_folder}/event_data_{fileDoi}_{count}.json"
    ed = mrced2.eventData(email=email, outputFile=filename)
    ed.buildQuery({'obj-id': doi})
    
    # run the query to determine number of events
    ed.runQuery(retry=5) # scholix = False - can query scholix api as well - worth exploring
    
    # calculate how many pages will need to be iterated over
    num_pages = ceil(ed.events.count()/1000)
    
    # find info from all the pages
    ed.getAllPages(num_pages, {'rows': 1000, 'obj-id': doi}, fileprefix=f"{results_folder}/{fileDoi}_page{count}") # fileDoi to give each result json a unique name, otherwise it writes over previous results 

print('Done!')
# Out:
# 10.5285/0a7d65e8-8bc8-46e5-ab72-ee64ed851583
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/0a7d65e8-8bc8-46e5-ab72-ee64ed851583
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_0a7d65e8-8bc8-46e5-ab72-ee64ed851583_0.json
# 9 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=88c6e237-05c7-46e2-9ff3-730cbc5574a1&rows=1000&obj-id=10.5285/0a7d65e8-8bc8-46e5-ab72-ee64ed851583
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_0a7d65e8-8bc8-46e5-ab72-ee64ed851583_page00000.json
# 10.5285/1d78e01a-a9c1-4371-8482-1c1b57d9661f
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/1d78e01a-a9c1-4371-8482-1c1b57d9661f
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_1d78e01a-a9c1-4371-8482-1c1b57d9661f_1.json
# 19 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=d629a5e4-098f-4a2f-8757-6a099cac6d32&rows=1000&obj-id=10.5285/1d78e01a-a9c1-4371-8482-1c1b57d9661f
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_1d78e01a-a9c1-4371-8482-1c1b57d9661f_page10000.json
# 10.5285/331659d7-da72-48a2-9b52-63c003557990
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/331659d7-da72-48a2-9b52-63c003557990
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_331659d7-da72-48a2-9b52-63c003557990_2.json
# 1 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=634ae3e5-691a-4bee-a2f9-257fa41df182&rows=1000&obj-id=10.5285/331659d7-da72-48a2-9b52-63c003557990
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_331659d7-da72-48a2-9b52-63c003557990_page20000.json
# 10.5285/507a5e1f-e056-454c-8ff6-d185f3da8556
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/507a5e1f-e056-454c-8ff6-d185f3da8556
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_507a5e1f-e056-454c-8ff6-d185f3da8556_3.json
# 1039 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=7ae529b8-8f47-4f1f-bd3d-962fc729de20&rows=1000&obj-id=10.5285/507a5e1f-e056-454c-8ff6-d185f3da8556
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_507a5e1f-e056-454c-8ff6-d185f3da8556_page30000.json
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=520e0182-e4d9-4aee-a02e-1573743e5b85&rows=1000&obj-id=10.5285/507a5e1f-e056-454c-8ff6-d185f3da8556
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_507a5e1f-e056-454c-8ff6-d185f3da8556_page30001.json
# 10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_6c6c9203-7333-4d96-88ab-78925e7a4e73_4.json
# 14 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=0c5b152b-2b21-4ef8-900b-28955fdeced4&rows=1000&obj-id=10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_6c6c9203-7333-4d96-88ab-78925e7a4e73_page40000.json
# 10.5285/94c9eaa3-a178-4de4-8905-dbfab03b69a0
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/94c9eaa3-a178-4de4-8905-dbfab03b69a0
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_94c9eaa3-a178-4de4-8905-dbfab03b69a0_5.json
# 757 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=3a8de881-a24e-408e-b4b4-3f9a0abe702b&rows=1000&obj-id=10.5285/94c9eaa3-a178-4de4-8905-dbfab03b69a0
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_94c9eaa3-a178-4de4-8905-dbfab03b69a0_page50000.json
# 10.5285/97c65c35-1db5-49d5-8ee0-ae5c7b699634
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/97c65c35-1db5-49d5-8ee0-ae5c7b699634
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_97c65c35-1db5-49d5-8ee0-ae5c7b699634_6.json
# 1 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=808a02ab-3040-4369-a1f4-73150b0bf3ae&rows=1000&obj-id=10.5285/97c65c35-1db5-49d5-8ee0-ae5c7b699634
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_97c65c35-1db5-49d5-8ee0-ae5c7b699634_page60000.json
# 10.5285/9e4451f8-23d3-40dc-9302-73e30ad3dd76
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/9e4451f8-23d3-40dc-9302-73e30ad3dd76
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_9e4451f8-23d3-40dc-9302-73e30ad3dd76_7.json
# 2 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=194240f7-920f-4238-89a4-be65ac780eb7&rows=1000&obj-id=10.5285/9e4451f8-23d3-40dc-9302-73e30ad3dd76
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_9e4451f8-23d3-40dc-9302-73e30ad3dd76_page70000.json
# 10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_b745e7b1-626c-4ccc-ac27-56582e77b900_8.json
# 21 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=c59f99c1-2c81-4076-acec-3c7b8f6669f0&rows=1000&obj-id=10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_b745e7b1-626c-4ccc-ac27-56582e77b900_page80000.json
# 10.5285/b79e887e-a2a7-4224-8fd7-e78066b950b3
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/b79e887e-a2a7-4224-8fd7-e78066b950b3
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_b79e887e-a2a7-4224-8fd7-e78066b950b3_9.json
# 671 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=503d8020-3af7-47ad-8e73-63ceb9ee4d69&rows=1000&obj-id=10.5285/b79e887e-a2a7-4224-8fd7-e78066b950b3
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_b79e887e-a2a7-4224-8fd7-e78066b950b3_page90000.json
# 10.5285/ca2b1766-2acc-4eeb-82d1-29970e9a5667
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/ca2b1766-2acc-4eeb-82d1-29970e9a5667
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_ca2b1766-2acc-4eeb-82d1-29970e9a5667_10.json
# 475 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=a00bc87f-78ed-4ad8-a9f8-d34b57bb64fb&rows=1000&obj-id=10.5285/ca2b1766-2acc-4eeb-82d1-29970e9a5667
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_ca2b1766-2acc-4eeb-82d1-29970e9a5667_page100000.json
# 10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_d7da6cb9-104b-4dbc-b709-c1f7ba94fb16_11.json
# 1 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=ff25c35a-d5e6-4c39-89a7-1c72e2e3e04b&rows=1000&obj-id=10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_d7da6cb9-104b-4dbc-b709-c1f7ba94fb16_page110000.json
# 10.5285/f2856ee8-da6e-4b67-bedb-590520c77b3c
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/f2856ee8-da6e-4b67-bedb-590520c77b3c
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_f2856ee8-da6e-4b67-bedb-590520c77b3c_12.json
# 52 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=4b3f16b0-e44d-41ff-9a8b-b98fec5843d8&rows=1000&obj-id=10.5285/f2856ee8-da6e-4b67-bedb-590520c77b3c
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_f2856ee8-da6e-4b67-bedb-590520c77b3c_page120000.json
# 10.5285/80887755-1426-4dab-a4a6-250919d5020c
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/80887755-1426-4dab-a4a6-250919d5020c
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_80887755-1426-4dab-a4a6-250919d5020c_13.json
# 19 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=366afe61-a13c-4431-bfcd-ed208cd66493&rows=1000&obj-id=10.5285/80887755-1426-4dab-a4a6-250919d5020c
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_80887755-1426-4dab-a4a6-250919d5020c_page130000.json
# 10.5285/33604ea0-c238-4488-813d-0ad9ab7c51ca
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/33604ea0-c238-4488-813d-0ad9ab7c51ca
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_33604ea0-c238-4488-813d-0ad9ab7c51ca_14.json
# 37 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=a47f91f3-96eb-411a-bba1-933178accbcb&rows=1000&obj-id=10.5285/33604ea0-c238-4488-813d-0ad9ab7c51ca
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_33604ea0-c238-4488-813d-0ad9ab7c51ca_page140000.json
# 10.5285/9d1eada2-3f8b-4a7b-a9b0-a7a04d05ff72
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/9d1eada2-3f8b-4a7b-a9b0-a7a04d05ff72
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_9d1eada2-3f8b-4a7b-a9b0-a7a04d05ff72_15.json
# 0 events found
# 10.5285/bad1514f-119e-44a4-8e1e-442735bb9797
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/bad1514f-119e-44a4-8e1e-442735bb9797
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_bad1514f-119e-44a4-8e1e-442735bb9797_16.json
# 3 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=3b6311d6-4e72-40bd-8657-07222ceaa133&rows=1000&obj-id=10.5285/bad1514f-119e-44a4-8e1e-442735bb9797
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_bad1514f-119e-44a4-8e1e-442735bb9797_page160000.json
# 10.5285/f3723162-4fed-4d9d-92c6-dd17412fa37b
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/f3723162-4fed-4d9d-92c6-dd17412fa37b
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_f3723162-4fed-4d9d-92c6-dd17412fa37b_17.json
# 3 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=e6691cd4-55c3-4e43-a6c2-e80028de74c1&rows=1000&obj-id=10.5285/f3723162-4fed-4d9d-92c6-dd17412fa37b
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_f3723162-4fed-4d9d-92c6-dd17412fa37b_page170000.json
# 10.5285/fd7ca5ef-460a-463c-ad2b-5ad48bb4e22e
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/fd7ca5ef-460a-463c-ad2b-5ad48bb4e22e
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_fd7ca5ef-460a-463c-ad2b-5ad48bb4e22e_18.json
# 4 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=00466807-516c-418a-8689-b736df24bfa1&rows=1000&obj-id=10.5285/fd7ca5ef-460a-463c-ad2b-5ad48bb4e22e
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_fd7ca5ef-460a-463c-ad2b-5ad48bb4e22e_page180000.json
# 10.5285/789bea37-0450-4822-9857-3dc848feb937
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/789bea37-0450-4822-9857-3dc848feb937
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_789bea37-0450-4822-9857-3dc848feb937_19.json
# 2 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=60b77d9b-5b81-4c52-b270-d0176160f7c1&rows=1000&obj-id=10.5285/789bea37-0450-4822-9857-3dc848feb937
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_789bea37-0450-4822-9857-3dc848feb937_page190000.json
# 10.5285/c76096d6-45d4-4a69-a310-4c67f8dcf096
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/c76096d6-45d4-4a69-a310-4c67f8dcf096
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_c76096d6-45d4-4a69-a310-4c67f8dcf096_20.json
# 2 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=c75bc9c8-5a7b-460e-b5e4-73460b684505&rows=1000&obj-id=10.5285/c76096d6-45d4-4a69-a310-4c67f8dcf096
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_c76096d6-45d4-4a69-a310-4c67f8dcf096_page200000.json
# 10.5285/d329f4d6-95ba-4134-b77a-a377e0755653
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/d329f4d6-95ba-4134-b77a-a377e0755653
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_d329f4d6-95ba-4134-b77a-a377e0755653_21.json
# 44 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=45d954b0-fa64-4384-9e3b-531d39e61903&rows=1000&obj-id=10.5285/d329f4d6-95ba-4134-b77a-a377e0755653
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_d329f4d6-95ba-4134-b77a-a377e0755653_page210000.json
# 10.5285/6b0c4358-2bf3-4924-aa8f-793d468b92be
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/6b0c4358-2bf3-4924-aa8f-793d468b92be
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_6b0c4358-2bf3-4924-aa8f-793d468b92be_22.json
# 6 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=664de883-6b67-4e09-bb8c-6df9ec0cbfe6&rows=1000&obj-id=10.5285/6b0c4358-2bf3-4924-aa8f-793d468b92be
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_6b0c4358-2bf3-4924-aa8f-793d468b92be_page220000.json
# 10.5285/5f0605e4-aa2a-48ab-b47c-bf5510823e8f
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/5f0605e4-aa2a-48ab-b47c-bf5510823e8f
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_5f0605e4-aa2a-48ab-b47c-bf5510823e8f_23.json
# 3 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=de2cb51e-2887-4e57-aa14-8bb8d28fbb57&rows=1000&obj-id=10.5285/5f0605e4-aa2a-48ab-b47c-bf5510823e8f
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_5f0605e4-aa2a-48ab-b47c-bf5510823e8f_page230000.json
# 10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_d7da6cb9-104b-4dbc-b709-c1f7ba94fb16_24.json
# 1 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=ff25c35a-d5e6-4c39-89a7-1c72e2e3e04b&rows=1000&obj-id=10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_d7da6cb9-104b-4dbc-b709-c1f7ba94fb16_page240000.json
# 10.5285/0995e94d-6d42-40c1-8ed4-5090d82471e1
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/0995e94d-6d42-40c1-8ed4-5090d82471e1
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_0995e94d-6d42-40c1-8ed4-5090d82471e1_25.json
# 8 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=c377dccb-7231-46be-ab62-c6421d880e23&rows=1000&obj-id=10.5285/0995e94d-6d42-40c1-8ed4-5090d82471e1
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_0995e94d-6d42-40c1-8ed4-5090d82471e1_page250000.json
# 10.5285/fc9bcd1c-e3fc-4c5a-b569-2fe62d40f2f5
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/fc9bcd1c-e3fc-4c5a-b569-2fe62d40f2f5
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_fc9bcd1c-e3fc-4c5a-b569-2fe62d40f2f5_26.json
# 7 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=b8351e01-9650-49ee-8b1b-23cd1b6a15a2&rows=1000&obj-id=10.5285/fc9bcd1c-e3fc-4c5a-b569-2fe62d40f2f5
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_fc9bcd1c-e3fc-4c5a-b569-2fe62d40f2f5_page260000.json
# 10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_b745e7b1-626c-4ccc-ac27-56582e77b900_27.json
# 21 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=c59f99c1-2c81-4076-acec-3c7b8f6669f0&rows=1000&obj-id=10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_b745e7b1-626c-4ccc-ac27-56582e77b900_page270000.json
# 10.5285/10874370-bc58-4d23-a118-ea07df8a07f2
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/10874370-bc58-4d23-a118-ea07df8a07f2
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_10874370-bc58-4d23-a118-ea07df8a07f2_28.json
# 49 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=64a969db-1619-45d6-8ce9-22cc4d38fca5&rows=1000&obj-id=10.5285/10874370-bc58-4d23-a118-ea07df8a07f2
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_10874370-bc58-4d23-a118-ea07df8a07f2_page280000.json
# 10.5285/5dc179dc-f692-49ba-9326-a6893a503f6e
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/5dc179dc-f692-49ba-9326-a6893a503f6e
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_5dc179dc-f692-49ba-9326-a6893a503f6e_29.json
# 26 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=81798fa4-39eb-429b-9980-03da0cb4e830&rows=1000&obj-id=10.5285/5dc179dc-f692-49ba-9326-a6893a503f6e
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_5dc179dc-f692-49ba-9326-a6893a503f6e_page290000.json
# 10.5285/8baf805d-39ce-4dac-b224-c926ada353b7
# https://api.eventdata.crossref.org/v1/events/scholix?mailto=Anonymous&rows=1000&obj-id=10.5285/8baf805d-39ce-4dac-b224-c926ada353b7
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/event_data_10.5285_8baf805d-39ce-4dac-b224-c926ada353b7_30.json
# 26 events found
# https://api.eventdata.crossref.org/v1/events?mailto=Anonymous&cursor=47488312-ac18-49db-8f63-fa1a7adad1ce&rows=1000&obj-id=10.5285/8baf805d-39ce-4dac-b224-c926ada353b7
# Event Data query started...
# API query complete  200
# output file written to NERC_EDS_events_from_doi_list_scholix/10.5285_8baf805d-39ce-4dac-b224-c926ada353b7_page300000.json
# Done!

# %%
# instance of a class to interpret the events
jd1 = mrced2.eventRecord()

# get all the filenames
files = os.listdir(results_folder)

# load the json event data from multiple files
jd1.mergeJsons(files, folder = results_folder)

## filter out twitter wikipedia etc - later add options to include these info
filters = {"source_id" : ['twitter', 'wikipedia', 'newsfeed', 'wordpressdotcom', 'reddit-links']}
filtered_info = jd1.filter(filters, mode = 'NOT')

# collect relevant citation info for NERC project
citationInfo = filtered_info.collectCitationInfo()

# convert to dataframe
crossRef_df = pd.DataFrame(citationInfo)

# filter out gbif registrant code prefix 10.15468
crossRef_df_gbif_filtered = crossRef_df[~crossRef_df.subj_id.str.contains("10.15468")]

# filter out relationship_type_id values that we don't want - is_referenced_by, discusses
crossRef_df_gbif_filtered2 = crossRef_df_gbif_filtered[~crossRef_df_gbif_filtered.relation_type_id.str.contains("is_referenced_by|discusses|is_new_version_of|is_supplemented_by|is_previous_version_of")]

# remove duplicate subj_ids for each obj_id - e.g. 10.5285/a7f28dea-64f7-43b5-bc39-a6cfcdeefbda has multiple references from 10.5285/65140444-b5fa-4a5e-9ab4-e86c106051e2
# find rows where obj_id and subj_id are the same - should I match any other columns?
dups = crossRef_df_gbif_filtered2.duplicated(subset=['obj_id', 'subj_id'])
crossRef_df_gbif_filtered2_deduplicated = crossRef_df_gbif_filtered2.drop(crossRef_df_gbif_filtered2[dups].index)

# %%
# Pass citation info to datacite API to collect relevant info on the datasets, data centres etc
(errors, dataCite_df) = getDataCiteInfo(crossRef_df_gbif_filtered2_deduplicated)
# Out:
# https://doi.org/10.5285/507A5E1F-E056-454C-8FF6-D185F3DA8556 https://doi.org/10.29110/soylemdergi.1169829
# API response:  200
# https://doi.org/10.5285/0995e94d-6d42-40c1-8ed4-5090d82471e1 https://doi.org/10.1075/silv.27.11bla
# API response:  200
# https://doi.org/10.5285/0a7d65e8-8bc8-46e5-ab72-ee64ed851583 https://doi.org/10.1111/icad.12578
# API response:  200
# https://doi.org/10.5285/10874370-bc58-4d23-a118-ea07df8a07f2 https://doi.org/10.5194/essd-10-951-2018
# API response:  200
# https://doi.org/10.5285/1d78e01a-a9c1-4371-8482-1c1b57d9661f https://doi.org/10.1002/esp.4005
# API response:  200
# https://doi.org/10.5285/331659d7-da72-48a2-9b52-63c003557990 https://doi.org/10.1007/s10661-022-10118-4
# API response:  200
# https://doi.org/10.5285/33604ea0-c238-4488-813d-0ad9ab7c51ca https://doi.org/10.1007/s10584-018-2145-y
# API response:  200
# https://doi.org/10.5285/5dc179dc-f692-49ba-9326-a6893a503f6e https://doi.org/10.5194/hess-23-4011-2019
# API response:  200
# https://doi.org/10.5285/5f0605e4-aa2a-48ab-b47c-bf5510823e8f https://doi.org/10.2478/jlecol-2018-0015
# API response:  200
# https://doi.org/10.5285/6b0c4358-2bf3-4924-aa8f-793d468b92be https://doi.org/10.5194/gmd-12-1909-2019
# API response:  200
# https://doi.org/10.5285/6c6c9203-7333-4d96-88ab-78925e7a4e73 https://doi.org/10.1007/s11368-018-1990-7
# API response:  200
# https://doi.org/10.5285/789bea37-0450-4822-9857-3dc848feb937 https://doi.org/10.5194/gmd-15-1913-2022
# API response:  200
# https://doi.org/10.5285/80887755-1426-4dab-a4a6-250919d5020c https://doi.org/10.1007/s40745-015-0067-3
# API response:  200
# https://doi.org/10.5285/8baf805d-39ce-4dac-b224-c926ada353b7 https://doi.org/10.5194/hess-24-561-2020
# API response:  200
# https://doi.org/10.5285/94c9eaa3-a178-4de4-8905-dbfab03b69a0 https://doi.org/10.5194/hess-23-4583-2019
# API response:  200
# https://doi.org/10.5285/94C9EAA3-A178-4DE4-8905-DBFAB03B69A0 https://doi.org/10.33326/26644649.2021.5.2.1191
# API response:  200
# https://doi.org/10.5285/97c65c35-1db5-49d5-8ee0-ae5c7b699634 https://doi.org/10.3390/su132313030
# API response:  200
# https://doi.org/10.5285/9e4451f8-23d3-40dc-9302-73e30ad3dd76 https://doi.org/10.1038/s41598-022-05476-5
# API response:  200
# https://doi.org/10.5285/b745e7b1-626c-4ccc-ac27-56582e77b900 https://doi.org/10.5194/bg-16-1641-2019
# API response:  200
# https://doi.org/10.5285/B79E887E-A2A7-4224-8FD7-E78066B950B3 https://doi.org/10.53047/josse.998220
# API response:  200
# https://doi.org/10.5285/bad1514f-119e-44a4-8e1e-442735bb9797 https://doi.org/10.1007/s11269-018-1914-8
# API response:  200
# https://doi.org/10.5285/c76096d6-45d4-4a69-a310-4c67f8dcf096 https://doi.org/10.1038/s43247-021-00334-0
# API response:  200
# https://doi.org/10.5285/CA2B1766-2ACC-4EEB-82D1-29970E9A5667 https://doi.org/10.23947/2334-8496-2020-8-3-47-59
# API response:  200
# https://doi.org/10.5285/d329f4d6-95ba-4134-b77a-a377e0755653 https://doi.org/10.5194/hess-21-1189-2017
# API response:  200
# https://doi.org/10.5285/d7da6cb9-104b-4dbc-b709-c1f7ba94fb16 https://doi.org/10.1016/j.agee.2021.107755
# API response:  200
# https://doi.org/10.5285/f2856ee8-da6e-4b67-bedb-590520c77b3c https://doi.org/10.5194/hess-22-611-2018
# API response:  200
# https://doi.org/10.5285/f3723162-4fed-4d9d-92c6-dd17412fa37b https://doi.org/10.1007/s00799-016-0175-5
# API response:  200
# https://doi.org/10.5285/fd7ca5ef-460a-463c-ad2b-5ad48bb4e22e https://doi.org/10.1002/2017jg004312
# API response:  200
# Data Retrieved!
# Data Centre names processed!

# %% [markdown]
# Pass citation info to datacite API to collect relevant info on the datasets, data centres etc

# %%
errors
dataCite_df
# Out:
#                                           dataset_DOI  \
# 0   https://doi.org/10.5285/507A5E1F-E056-454C-8FF...
# 1   https://doi.org/10.5285/0995e94d-6d42-40c1-8ed...
# 2   https://doi.org/10.5285/0a7d65e8-8bc8-46e5-ab7...
# 3   https://doi.org/10.5285/10874370-bc58-4d23-a11...
# 4   https://doi.org/10.5285/1d78e01a-a9c1-4371-848...
# 5   https://doi.org/10.5285/331659d7-da72-48a2-9b5...
# 6   https://doi.org/10.5285/33604ea0-c238-4488-813...
# 7   https://doi.org/10.5285/5dc179dc-f692-49ba-932...
# 8   https://doi.org/10.5285/5f0605e4-aa2a-48ab-b47...
# 9   https://doi.org/10.5285/6b0c4358-2bf3-4924-aa8...
# 10  https://doi.org/10.5285/6c6c9203-7333-4d96-88a...
# 11  https://doi.org/10.5285/789bea37-0450-4822-985...
# 12  https://doi.org/10.5285/80887755-1426-4dab-a4a...
# 13  https://doi.org/10.5285/8baf805d-39ce-4dac-b22...
# 14  https://doi.org/10.5285/94c9eaa3-a178-4de4-890...
# 15  https://doi.org/10.5285/94C9EAA3-A178-4DE4-890...
# 16  https://doi.org/10.5285/97c65c35-1db5-49d5-8ee...
# 17  https://doi.org/10.5285/9e4451f8-23d3-40dc-930...
# 18  https://doi.org/10.5285/b745e7b1-626c-4ccc-ac2...
# 19  https://doi.org/10.5285/B79E887E-A2A7-4224-8FD...
# 20  https://doi.org/10.5285/bad1514f-119e-44a4-8e1...
# 21  https://doi.org/10.5285/c76096d6-45d4-4a69-a31...
# 22  https://doi.org/10.5285/CA2B1766-2ACC-4EEB-82D...
# 23  https://doi.org/10.5285/d329f4d6-95ba-4134-b77...
# 24  https://doi.org/10.5285/d7da6cb9-104b-4dbc-b70...
# 25  https://doi.org/10.5285/f2856ee8-da6e-4b67-bed...
# 26  https://doi.org/10.5285/f3723162-4fed-4d9d-92c...
# 27  https://doi.org/10.5285/fd7ca5ef-460a-463c-ad2...
#
#                                         dataset_Title  \
# 0   Water chemistry, hydrology and fluvial carbon ...
# 1   UK gridded population 2011 based on Census 201...
# 2   Moth trends for Britain and Ireland from the R...
# 3   Climate hydrology and ecology research support...
# 4                    Land Cover Map 2007 (vector, GB)
# 5   High resolution water quality and flow monitor...
# 6   Gridded estimates of daily and monthly areal r...
# 7   Gridded estimates of daily and monthly areal r...
# 8       ITE Land Classification of Great Britain 2007
# 9     High-resolution global topographic index values
# 10                   Land Cover Map 2015 (vector, GB)
# 11  Gross Primary Productivity simulations of Grea...
# 12  Climate hydrology and ecology research support...
# 13  Climate hydrology and ecology research support...
# 14  Gridded Standardized Precipitation Index (SPI)...
# 15  Gridded Standardized Precipitation Index (SPI)...
# 16  Scenarios of future land use change in Mozambi...
# 17  Model estimates of topsoil carbon [Countryside...
# 18  Climate hydrology and ecology research support...
# 19                   Land Cover Map 2000 (vector, GB)
# 20                          Future flows climate data
# 21  Water, carbon and energy fluxes simulation for...
# 22  UK Environmental Change Network (ECN) frog dat...
# 23  Climate hydrology and ecology research support...
# 24  Woody linear features framework, Great Britain...
# 25  Gridded estimates of daily and monthly areal r...
# 26                        Future flows hydrology data
# 27  UK Environmental Change Network (ECN) stream w...
#
#                                       dataset_authors dataset_date  \
# 0                      [Vihermaa, L. E., Waldron, S.]   2015-06-01
# 1   [Reis, S., Liska, T., Steinle, S., Carnell, E....   2017-11-22
# 2   [Harrower, C.A., Bell, J.R., Blumgart, D., Bot...   2020-04-20
# 3   [Robinson, E.L., Blyth, E., Clark, D.B., Comyn...   2016-12-12
# 4   [Morton, R.D., Rowland, C., Wood, C., Meek, L....   2011-04-08
# 5   [Hawkins, C.E, Kelly, T.J., Loewenthal, M., Sm...   2019-04-03
# 6   [Tanguy, M., Dixon, H., Prosdocimi, I., Morris...   2016-11-04
# 7   [Tanguy, M., Dixon, H., Prosdocimi, I., Morris...   2014-05-01
# 8   [Bunce, R.G.H., Barr, C.J., Clarke, R.T., Howa...   2007-05-01
# 9   [Marthews, T.R., Dadson, S.J., Lehner, B., Abe...   2015-03-03
# 10  [Rowland, C.S., Morton, R.D., Carrasco, L., Mc...   2017-04-12
# 11  [Baker, E., Harper, A., Williamson, D., Challe...   2021-06-11
# 12  [Robinson, E.L., Blyth, E., Clark, D.B., Finch...   2015-11-13
# 13  [Robinson, E.L., Blyth, E., Clark, D.B., Comyn...   2016-12-14
# 14  [Tanguy, M., Hannaford, J., Barker, L., Svenss...   2015-04-30
# 15  [Tanguy, M., Hannaford, J., Barker, L., Svenss...   2015-04-30
# 16  [Zorrilla-Miras, P., Matediane, J., Mahamane, ...   2018-11-06
# 17  [Henrys, P.A., Keith, A.M., Robinson, D.A., Em...   2012-03-26
# 18  [Robinson, E.L., Blyth, E., Clark, D.B., Comyn...   2017-02-07
# 19  [Fuller, R.M., Smith, G.M., Sanderson, J.M., H...   2002-01-01
# 20  [Prudhomme, C., Dadson, S., Morris, D., Willia...   2012-04-01
# 21  [Martinez-De La Torre, A., Blyth, E.M., Robins...   2018-01-26
# 22  [Rennie, S., Adamson, J., Anderson, R., Andrew...   2015-02-25
# 23  [Robinson, E.L., Blyth, E., Clark, D.B., Finch...   2015-11-12
# 24  [Scholefield, P.A., Morton, R.D., Rowland, C.S...   2016-11-08
# 25  [Tanguy, M., Dixon, H., Prosdocimi, I., Morris...   2015-09-25
# 26  [Haxton, T., Crooks, S., Jackson, C.R., Barkwi...   2012-04-01
# 27  [Rennie, S., Adamson, J., Anderson, R., Andrew...   2017-12-07
#
#    dataset_date_Type                           related_identifiers_list  \
# 0          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 1          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 2          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 3          Submitted  [{'relationType': 'IsNewVersionOf', 'relatedId...
# 4          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 5          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 6          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 7          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 8          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 9          Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 10         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 11         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 12         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 13         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 14         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 15         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 16         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 17         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 18         Submitted  [{'relationType': 'IsNewVersionOf', 'relatedId...
# 19         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 20         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 21         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 22         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 23         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 24         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 25         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 26         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 27         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
#
#     DataCite_Citation_count  \
# 0                        22
# 1                         1
# 2                         2
# 3                         4
# 4                         9
# 5                         1
# 6                        47
# 7                        25
# 8                         5
# 9                         8
# 10                       61
# 11                        1
# 12                        5
# 13                       26
# 14                       14
# 15                       14
# 16                        0
# 17                        2
# 18                       15
# 19                       10
# 20                        6
# 21                        3
# 22                        6
# 23                        8
# 24                        3
# 25                        5
# 26                        6
# 27                        4
#
#                               DataCite_Citations_list  \
# 0   [{'id': '10.18778/0208-600x.78.05', 'type': 'd...
# 1   [{'id': '10.1016/j.envint.2018.10.005', 'type'...
# 2   [{'id': '10.1111/icad.12578', 'type': 'dois'},...
# 3   [{'id': '10.5194/essd-10-951-2018', 'type': 'd...
# 4   [{'id': '10.1002/esp.4005', 'type': 'dois'}, {...
# 5   [{'id': '10.1007/s10661-022-10118-4', 'type': ...
# 6   [{'id': '10.1016/j.jhydrol.2018.07.034', 'type...
# 7   [{'id': '10.5194/hess-21-1189-2017', 'type': '...
# 8   [{'id': '10.1111/ele.13157', 'type': 'dois'}, ...
# 9   [{'id': '10.5194/hess-19-91-2015', 'type': 'do...
# 10  [{'id': '10.1007/s11368-018-1990-7', 'type': '...
# 11  [{'id': '10.5194/gmd-15-1913-2022', 'type': 'd...
# 12  [{'id': '10.5194/hess-21-1189-2017', 'type': '...
# 13  [{'id': '10.1016/j.agsy.2019.02.015', 'type': ...
# 14  [{'id': '10.1016/j.agsy.2019.02.015', 'type': ...
# 15  [{'id': '10.1016/j.agsy.2019.02.015', 'type': ...
# 16                                                 []
# 17  [{'id': '10.1111/sum.12658', 'type': 'dois'}, ...
# 18  [{'id': '10.5194/essd-10-951-2018', 'type': 'd...
# 19  [{'id': '10.1007/s00125-020-05087-7', 'type': ...
# 20  [{'id': '10.1007/s10750-015-2181-9', 'type': '...
# 21  [{'id': '10.5194/gmd-12-765-2019', 'type': 'do...
# 22  [{'id': '10.1016/j.ecolind.2016.01.060', 'type...
# 23  [{'id': '10.5194/hess-21-1189-2017', 'type': '...
# 24  [{'id': '10.1111/1365-2664.13412', 'type': 'do...
# 25  [{'id': '10.5194/hess-22-611-2018', 'type': 'd...
# 26  [{'id': '10.5194/hess-22-5387-2018', 'type': '...
# 27  [{'id': '10.1002/2017jg004312', 'type': 'dois'...
#
#                      dataset_publisher_processed
# 0   Environmental Information Data Centre (EIDC)
# 1   Environmental Information Data Centre (EIDC)
# 2   Environmental Information Data Centre (EIDC)
# 3   Environmental Information Data Centre (EIDC)
# 4   Environmental Information Data Centre (EIDC)
# 5   Environmental Information Data Centre (EIDC)
# 6   Environmental Information Data Centre (EIDC)
# 7   Environmental Information Data Centre (EIDC)
# 8   Environmental Information Data Centre (EIDC)
# 9   Environmental Information Data Centre (EIDC)
# 10  Environmental Information Data Centre (EIDC)
# 11  Environmental Information Data Centre (EIDC)
# 12  Environmental Information Data Centre (EIDC)
# 13  Environmental Information Data Centre (EIDC)
# 14  Environmental Information Data Centre (EIDC)
# 15  Environmental Information Data Centre (EIDC)
# 16  Environmental Information Data Centre (EIDC)
# 17  Environmental Information Data Centre (EIDC)
# 18  Environmental Information Data Centre (EIDC)
# 19  Environmental Information Data Centre (EIDC)
# 20  Environmental Information Data Centre (EIDC)
# 21  Environmental Information Data Centre (EIDC)
# 22  Environmental Information Data Centre (EIDC)
# 23  Environmental Information Data Centre (EIDC)
# 24  Environmental Information Data Centre (EIDC)
# 25  Environmental Information Data Centre (EIDC)
# 26  Environmental Information Data Centre (EIDC)
# 27  Environmental Information Data Centre (EIDC)

# %%
# # What to do with publication type information? if posted content probably want to ignore?
# crossRef_df_gbif_filtered2_deduplicated['obj_id']

# # for each dataset count each type of publication that cites it
# for data_doi in crossRef_df_processed

# %%
# merge crossRef_df and dataCite_df to get dataset info in crossref_df
# for each column create a mapping pair of dataset DOI and that column name, but skips first column 'Dataset_DOI' in loop
for ii in dataCite_df.columns[1:]: # 
    
    # create dictionary of data_doi, value pairs 
    d = dataCite_df.set_index('dataset_DOI')[ii].to_dict()
    
    # use the data doi to map the dictionary to the crossref_df
    crossRef_df_gbif_filtered2_deduplicated.loc[:,ii] = crossRef_df_gbif_filtered2_deduplicated.obj_id.map(d)


    
# create data frame that just lists each dataset and has citations counts from crossref, scholex, datacite etc
# remove rows from crossref with duplicated obj_id
dups = crossRef_df_gbif_filtered2_deduplicated.duplicated('obj_id')
dataset_df = crossRef_df_gbif_filtered2_deduplicated.drop(crossRef_df_gbif_filtered2_deduplicated[dups].index)
dataset_df = dataset_df.drop(['relation_type_id', 'source_id', 'subj_id', 'subj_work_type_id'], axis = 1) # 'subj_work_type_id'

# count how many times each dataset DOI appears in crossRef_df_processed and add this number to dataset_df
crossRef_citation_counts = crossRef_df_gbif_filtered2_deduplicated['obj_id'].value_counts()

# need counts that include or exclude different relation_type_ids and subj_work_type_id

# create dictionary of data_doi, crossRef_citation_counts 
d = crossRef_citation_counts.to_dict()

# use the data doi to map the dictionary to the dataset_df
dataset_df['crossRef_citation_count'] = dataset_df.obj_id.map(d)

# %%
# # pass publication DOIs to DOI.org to determine type of publication using checkDOIpubType function defined above
# pubTypeList = []
# pubDOI = []

# for count, doi in enumerate(crossRef_df_processed['subj_id']):
#     doiComponents = doi.split('/')[-2:]
#     doi = doiComponents[0] + "/" + doiComponents[1]
#     # print(type(doi))
#     pubType = checkDOIpubType(doi)
#     pubTypeList.append(pubType)
#     pubDOI.append(doi)
    
#     # add code to catch retries limit exceeded - might need to be in function itself?
#     # e.g. https://stackoverflow.com/questions/23013220/max-retries-exceeded-with-url-in-requests
    
#     time.sleep(0.5)
#     # if count % 200 == 0: # if count is a multiple of 200 wait for a bit
#     #         time.sleep(180)

# print('Done!')

# crossRef_df_processed['publicationType'] = pubTypeList
# crossRef_df_processed['publication_DOI'] = pubDOI


# # split publicationType column into publicationType1 and publicationSubType columns
# crossRef_df_processed[['publicationType1','publicationSubType']] = pd.DataFrame(crossRef_df_processed['publicationType'].tolist(), index=crossRef_df_processed.index)


# # determine publication type for records where DOI.org API call failed - ~10 mins
# newPubTypeList = []

# # get the unknown rows from scholex_df pubtype column and the pubDOI
# for pubType, pubDOI in zip(crossRef_df_processed['publicationType1'],crossRef_df_processed['publication_DOI']):
    
#     if pubType == 'unknown':

#         # need a catcher to make sure pubDOI is a single ID - in the cases where there was no DOI there is more than one ID recorded
#         if len(pubDOI) < 100: # if the length is less than 100 (arbitrarily) then it will be a single DOI
#             pass
#         else: # if there is no DOI skip this record
#             newPubTypeList.append(pubType) # leave it the same
#             #newPubType = pubType 
#             continue
        
#         # determine if crossref or datacite supplies the DOI
#         print('Pub DOI: ', pubDOI)
#         r = requests.get(('https://doi.org/doiRA/' + pubDOI), headers={"Accept": "application/json"})
#         DOIregistry = r.json()[0]['RA']
#         print(DOIregistry)

#         # query the crossref or datacite API
#         if DOIregistry == 'DataCite':
#             # ask the Datacite API what type of publication
#             r = requests.get(('https://api.datacite.org/dois/' + pubDOI), headers = {'client-id': 'bl.nerc'})
#             print(r.status_code)
#             newPubTypeList.append(r.json()['data']['attributes']['types']['citeproc']) # is citeproc the correct one to use?

#         elif DOIregistry == 'Crossref':
#             r = requests.get(('https://api.crossref.org/works/'  + pubDOI), headers={"Accept": "application/json"})
#             print(r.status_code)
#             newPubTypeList.append(r.json()['message']['type']) # could also add 'subtype':r.json()['message']['subtype']
#         else:
#             print('Unknown DOI registry')
        
#     else: 
#         newPubTypeList.append(pubType) # in the cases where the pubType is not unknown keep it the same

# crossRef_df_processed['newPubTypeList'] = newPubTypeList
# print("Done")

# %%
pubDOI = '10.1007/s11368-018-1990-7'
r = requests.get(('https://doi.org/doiRA/' + pubDOI), headers={"Accept": "application/json"})
DOIregistry = r.json()[0]['RA']
print(DOIregistry)

# %%
# query the crossref or datacite API
if DOIregistry == 'DataCite':
    # ask the Datacite API what type of publication
    r = requests.get(('https://api.datacite.org/dois/' + pubDOI), headers = {'client-id': 'bl.nerc'})
    print(r.status_code)
    newPubTypeList.append(r.json()['data']['attributes']['types']['citeproc']) # is citeproc the correct one to use?

# %%
r = requests.get(('https://api.crossref.org/works/'  + pubDOI), headers={"Accept": "application/json"})
print(r.status_code)
r.json()['message']

# %%
# add a section to get publication info from DOI.org api to add to crossRef_df_gbif_filtered2_deduplicated? e.g. title, authors etc
doi_url = 'https://doi.org/10.5194/gmd-11-1377-2018'
print(doi_url)
r = requests.get(doi_url, headers={"Accept": "application/json"}) # sometimes throws up unexpected errors

# sometimes the API call returns info in a format that is not JSON 
r.json()
# Out:
# https://doi.org/10.5194/gmd-11-1377-2018
# {'indexed': {'date-parts': [[2023, 2, 9]],
#   'date-time': '2023-02-09T14:27:24Z',
#   'timestamp': 1675952844171},
#  'reference-count': 112,
#  'publisher': 'Copernicus GmbH',
#  'issue': '4',
#  'license': [{'start': {'date-parts': [[2018, 4, 12]],
#     'date-time': '2018-04-12T00:00:00Z',
#     'timestamp': 1523491200000},
#    'content-version': 'unspecified',
#    'delay-in-days': 0,
#    'URL': 'https://creativecommons.org/licenses/by/4.0/'}],
#  'content-domain': {'domain': [], 'crossmark-restriction': False},
#  'abstract': '<jats:p>Abstract. The dynamic global vegetation model LPJmL4 is a process-based model that simulates climate and land use change impacts on the terrestrial biosphere, agricultural production, and the water and carbon cycle. Different versions of the model have been developed and applied to evaluate the role of natural and managed ecosystems in the Earth system and the potential impacts of global environmental change. A comprehensive model description of the new model version, LPJmL4, is provided in a companion paper (Schaphoff et\xa0al., 2018c). Here, we provide a full picture of the model performance, going beyond standard benchmark procedures and give hints on the strengths and shortcomings of the model to identify the need for further model improvement. Specifically, we evaluate LPJmL4 against various datasets from in situ measurement sites, satellite observations, and agricultural yield statistics. We apply a range of metrics to evaluate the quality of the model to simulate stocks and flows of carbon and water in natural and managed ecosystems at different temporal and spatial scales. We show that an advanced phenology scheme improves the simulation of seasonal fluctuations in the atmospheric CO2 concentration, while the permafrost scheme improves estimates of carbon stocks. The full LPJmL4 code including the new developments will be supplied open source through https://gitlab.pik-potsdam.de/lpjml/LPJmL. We hope that this will lead to new model developments and applications that improve the model performance and possibly build up a new understanding of the terrestrial biosphere.\n                    </jats:p>',
#  'DOI': '10.5194/gmd-11-1377-2018',
#  'type': 'journal-article',
#  'created': {'date-parts': [[2018, 4, 12]],
#   'date-time': '2018-04-12T06:39:18Z',
#   'timestamp': 1523515158000},
#  'page': '1377-1403',
#  'source': 'Crossref',
#  'is-referenced-by-count': 42,
#  'title': 'LPJmL4 – a dynamic global vegetation model with managed land – Part\xa02: Model evaluation',
#  'prefix': '10.5194',
#  'volume': '11',
#  'author': [{'given': 'Sibyll',
#    'family': 'Schaphoff',
#    'sequence': 'first',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0003-0363-9697',
#    'authenticated-orcid': False,
#    'given': 'Matthias',
#    'family': 'Forkel',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Christoph',
#    'family': 'Müller',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0002-4947-7067',
#    'authenticated-orcid': False,
#    'given': 'Jürgen',
#    'family': 'Knauer',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Werner',
#    'family': 'von Bloh',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Dieter',
#    'family': 'Gerten',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Jonas',
#    'family': 'Jägermeyr',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Wolfgang',
#    'family': 'Lucht',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0001-5425-8718',
#    'authenticated-orcid': False,
#    'given': 'Anja',
#    'family': 'Rammig',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'ORCID': 'http://orcid.org/0000-0001-5283-4937',
#    'authenticated-orcid': False,
#    'given': 'Kirsten',
#    'family': 'Thonicke',
#    'sequence': 'additional',
#    'affiliation': []},
#   {'given': 'Katharina',
#    'family': 'Waha',
#    'sequence': 'additional',
#    'affiliation': []}],
#  'member': '3145',
#  'published-online': {'date-parts': [[2018, 4, 12]]},
#  'reference': [{'key': 'ref1',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Abramowitz, G.: Towards a benchmark for land surface models, Geophys. Res. Lett., 32, L22702, https://doi.org/10.1029/2005GL024419, 2005.',
#    'DOI': '10.1029/2005GL024419'},
#   {'key': 'ref2',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Abramowitz, G.: Towards a public, standardized, diagnostic benchmarking system for land surface models, Geosci. Model Dev., 5, 819–827, https://doi.org/10.5194/gmd-5-819-2012, 2012.',
#    'DOI': '10.5194/gmd-5-819-2012'},
#   {'key': 'ref3',
#    'unstructured': 'Alexandratos, N. and Bruinsma, J.: World agriculture towards 2030/2050: the 2012 revision, Tech. Rep.\xa012, FAO, Rome, FAO, 2012.'},
#   {'key': 'ref4',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Asseng, S., Brisson, N., Basso, B., Martre, P., Aggarwal, P.\xa0K., Angulo, C., Bertuzzi, P., Biernath, C., Challinor, A.\xa0J., Doltra, J., Gayler, S., Goldberg, R., Grant, R., Heng, L., Hooker, J., Hunt, L.\xa0A., Ingwersen, J., Izaurralde, R.\xa0C., Kersebaum, K.\xa0C., Müller, C., Kumar, S.\xa0N., Nendel, C., Leary, G.\xa0O., Olesen, J.\xa0E., Osborne, T.\xa0M., Palosuo, T., Priesack, E., Ripoche, D., Semenov, M.\xa0A., Shcherbak, I., Steduto, P., Stöckle, C., Stratonovitch, P., Streck, T., Supit, I., Tao, F., Travasso, M., Waha, K., Wallach, D., Williams, J.\xa0R., and Wolf, J.: Uncertainty in simulating wheat yields under climate change, Nat. Clim. Change, 3, 827–832, https://doi.org/10.1038/NCLIMATE1916, 2013.',
#    'DOI': '10.1038/nclimate1916'},
#   {'key': 'ref5',
#    'doi-asserted-by': 'crossref',
#    'unstructured': "Asseng, S., Ewert, F., Martre, P., Rotter, R.\xa0P., Lobell, D.\xa0B., Cammarano, D., Kimball, B.\xa0A., Ottman, M.\xa0J., Wall, G.\xa0W., White, J.\xa0W., Reynolds, M.\xa0P., Alderman, P.\xa0D., Prasad, P. V.\xa0V., Aggarwal, P.\xa0K., Anothai, J., Basso, B., Biernath, C., Challinor, A.\xa0J., De\xa0Sanctis, G., Doltra, J., Fereres, E., Garcia-Vila, M., Gayler, S., Hoogenboom, G., Hunt, L.\xa0A., Izaurralde, R.\xa0C., Jabloun, M., Jones, C.\xa0D., Kersebaum, K.\xa0C., Koehler, A.-K., Muller, C., Naresh\xa0Kumar, S., Nendel, C., O/'Leary, G., Olesen, J.\xa0E., Palosuo, T., Priesack, E., Eyshi\xa0Rezaei, E., Ruane, A.\xa0C., Semenov, M.\xa0A., Shcherbak, I., Stockle, C., Stratonovitch, P., Streck, T., Supit, I., Tao, F., Thorburn, P.\xa0J., Waha, K., Wang, E., Wallach, D., Wolf, J., Zhao, Z., and Zhu, Y.: Rising temperatures reduce global wheat production, Nat. Clim. Change, 5, 143–147, https://doi.org/10.1038/nclimate2470, 2015.",
#    'DOI': '10.1038/nclimate2470'},
#   {'key': 'ref6',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Baret, F., Weiss, M., Lacaze, R., Camacho, F., Makhmara, H., Pacholcyzk, P., and Smets, B.: GEOV1: LAI and FAPAR essential climate variables and FCOVER global time series capitalizing over existing products, Part1: Principles of development and production, Remote Sens. Environ., 137, 299–309, https://doi.org/10.1016/j.rse.2012.12.027, 2013.',
#    'DOI': '10.1016/j.rse.2012.12.027'},
#   {'key': 'ref7',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Bassu, S., Brisson, N., Durand, J.-L., Boote, K., Lizaso, J., Jones, J.\xa0W., Rosenzweig, C., Ruane, A.\xa0C., Adam, M., Baron, C., Basso, B., Biernath, C., Boogaard, H., Conijn, S., Corbeels, M., Deryng, D., De\xa0Sanctis, G., Gayler, S., Grassini, P., Hatfield, J., Hoek, S., Izaurralde, C., Jongschaap, R., Kemanian, A.\xa0R., Kersebaum, K.\xa0C., Kim, S.-H., Kumar, N.\xa0S., Makowski, D., Müller, C., Nendel, C., Priesack, E., Pravia, M.\xa0V., Sau, F., Shcherbak, I., Tao, F., Teixeira, E., Timlin, D., and Waha, K.: How do various maize crop models vary in their responses to climate change factors?, Glob. Change Biol., 20, 2301–2320, https://doi.org/10.1111/gcb.12520, 2014.',
#    'DOI': '10.1111/gcb.12520'},
#   {'key': 'ref8',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Becker, A., Finger, P., Meyer-Christoffer, A., Rudolf, B., Schamm, K., Schneider, U., and Ziese, M.: A description of the global land-surface precipitation data products of the Global Precipitation Climatology Centre with sample applications including centennial (trend) analysis from 1901–present, Earth Syst. Sci. Data, 5, 71–99, https://doi.org/10.5194/essd-5-71-2013, 2013.',
#    'DOI': '10.5194/essd-5-71-2013'},
#   {'key': 'ref9',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Beer, C., Reichstein, M., Tomelleri, E., Ciais, P., Jung, M., Carvalhais, N., Rödenbeck, C., Arain, M.\xa0A., Baldocchi, D., Bonan, G.\xa0B., Bondeau, A., Cescatti, A., Lasslop, G., Lindroth, A., Lomas, M., Luyssaert, S., Margolis, H., Oleson, K.\xa0W., Roupsard, O., Veenendaal, E., Viovy, N., Williams, C., Woodward, F.\xa0I., and Papale, D.: Terrestrial gross carbon dioxide uptake: global distribution and covariation with climate, Science, 329, 834–8, https://doi.org/10.1126/science.1184984, 2010.',
#    'DOI': '10.1126/science.1184984'},
#   {'key': 'ref10',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Biemans, H., Hutjes, R. W.\xa0a., Kabat, P., Strengers, B.\xa0J., Gerten, D., and Rost, S.: Effects of Precipitation Uncertainty on Discharge Calculations for Main River Basins, J. Hydrometeor., 10, 1011–1025, https://doi.org/10.1175/2008JHM1067.1, 2009.',
#    'DOI': '10.1175/2008JHM1067.1'},
#   {'key': 'ref11',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Biemans, H., Haddeland, I., Kabat, P., Ludwig, F., Hutjes, R. W.\xa0A., Heinke, J., von Bloh, W., and Gerten, D.: Impact of reservoirs on river discharge and irrigation water supply during the 20th century, Water Resour. Res., 47, W03509, https://doi.org/10.1029/2009WR008929, 2011.',
#    'DOI': '10.1029/2009WR008929'},
#   {'key': 'ref12',
#    'unstructured': 'Boden, T., Marland, G., and Andres, R.: Global, Regional, and National Fossil-Fuel CO2 Emissions, Carbon Dioxide Information Analysis Center (CDIAC), Oak Ridge National Laboratory, US Department of Energy, Oak Ridge, available at: http://cdiac.ornl.gov/trends/emis/overview.html, 2013.'},
#   {'key': 'ref13',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Bondeau, A., Smith, P., Zaehle, S., Schaphoff, S., Lucht, W., Cramer, W., Gerten, D., Lotze-Campen, Hermann, Müller, C., Reichstein, M., and Smith, B.: Modelling the role of agriculture for the 20th century global terrestrial carbon balance, Glob. Change Biol., 13, 679–706, https://doi.org/10.1111/j.1365-2486.2006.01305.x, 2007.',
#    'DOI': '10.1111/j.1365-2486.2006.01305.x'},
#   {'key': 'ref14',
#    'unstructured': 'Brouwer, C., Prins, K., and Heibloem, M.: Irrigation Water Management: Irrigation Scheduling, Training manual no. 4, Tech. Rep.\xa04, FAO Land and Water Development Division, Rome, Italy, available at: http://www.fao.org/docrep/t7202e/t7202e00.htm, 1989.'},
#   {'key': 'ref15',
#    'unstructured': 'Brown, J., Ferrians, O. J.\xa0J., Heginbottom, J.\xa0A., and Melnikov, E.\xa0S.: Circum-Arctic map of permafrost and ground-ice conditions, Boulder, CO: National Snow and Ice Data Center/World Data Center for Glaciology, available at: http://nsidc.org/data/ggd318.html, 1998.'},
#   {'key': 'ref16',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Brown, J., Hinkel, K.\xa0M., and Nelson, F.\xa0E.: The circumpolar active layer monitoring (calm) program: Research designs and initial results, Polar Geogr., 24, 166–258, https://doi.org/10.1080/10889370009377698, 2000.',
#    'DOI': '10.1080/10889370009377698'},
#   {'key': 'ref17',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Carvalhais, N., Forkel, M., Khomik, M., Bellarby, J., Jung, M., Migliavacca, M., Mu, M., Saatchi, S., Santoro, M., Thurner, M., Weber, U., Ahrens, B., Beer, C., Cescatti, A., Randerson, J.\xa0T., and Reichstein, M.: Global covariation of carbon turnover times with climate in terrestrial ecosystems, Nature, 514, 213–217, https://doi.org/10.1038/nature13731, 2014.',
#    'DOI': '10.1038/nature13731'},
#   {'key': 'ref18',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Chaturvedi, V., Hejazi, M., Edmonds, J., Clarke, L., Kyle, P., Davies, E., and Wise, M.: Climate mitigation policy implications for global irrigation water demand, Mitig. Adapt. Strat. Gl., 20, 389–407, https://doi.org/10.1007/s11027-013-9497-4, 2015.',
#    'DOI': '10.1007/s11027-013-9497-4'},
#   {'key': 'ref19',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Chuvieco, E., Yue, C., Heil, A., Mouillot, F., Alonso-Canas, I., Padilla, M., Pereira, J.\xa0M., Oom, D., and Tansey, K.: A new global burned area product for climate assessment of fire impacts, Global Ecol. Biogeogr., 25, 619–629, https://doi.org/10.1111/geb.12440, 2016.',
#    'DOI': '10.1111/geb.12440'},
#   {'key': 'ref20',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Cosby, B.\xa0J., Hornberger, G.\xa0M., Clapp, R.\xa0B., and Ginn, T.\xa0R.: A Statistical Exploration of the Relationships of Soil Moisture Characteristics to the Physical Properties of Soils, Water Resour. Res., 20, 682–690, https://doi.org/10.1029/WR020i006p00682, 1984.',
#    'DOI': '10.1029/WR020i006p00682'},
#   {'key': 'ref21',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Dee, D. P., Uppala, S. M., Simmons, A. J., Berrisford, P., Poli, P., Kobayashi, S., Andrae, U., Balmaseda, M. A., Balsamo, G., Bauer, P., Bechtold, P., Beljaars, A. C. M., van de Berg, I., Biblot, J., Bormann, N., Delsol, C., Dragani, R., Fuentes, M., Greer, A. J., Haimberger, L., Healy, S. B., Hersbach, H., Holm, E. V., Isaksen, L., Kallberg, P., Kohler, M., Matricardi, M., McNally, A. P., Mong-Sanz, B. M., Morcette, J.-J., Park, B.-K., Peubey, C., de Rosnay, P., Tavolato, C., Thepaut, J. N., and Vitart, F.: The ERA-Interim reanalysis: Configuration and performance of the data assimilation system, Q. J. Roy. Meteorol. Soc., 137, 553–597, https://doi.org/10.1002/qj.828, 2011.',
#    'DOI': '10.1002/qj.828'},
#   {'key': 'ref22',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Defries, R. and Hansen, M.: ISLSCP II Continuous Fields of Vegetation Cover, 1992–1993, ORNL Distributed Active Archive Center, https://doi.org/10.3334/ORNLDAAC/931, 2009.',
#    'DOI': '10.3334/ORNLDAAC/931'},
#   {'key': 'ref23',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Döll, P. and Siebert, S.: Global modeling of irrigation water requirements, Water Resour. Res., 38, 1037, https://doi.org/10.1029/2001WR000355, 2002.',
#    'DOI': '10.1029/2001WR000355'},
#   {'key': 'ref24',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Döll, P., Hoffmann-Dobrev, H., Portmann, F., Siebert, S., Eicker, A., Rodell, M., Strassberg, G., and Scanlon, B.: Impact of water withdrawals from groundwater and surface water on continental water storage variations, J. Geodyn., 59–60, 143–156, https://doi.org/10.1016/j.jog.2011.05.001, 2012.',
#    'DOI': '10.1016/j.jog.2011.05.001'},
#   {'key': 'ref25',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Döll, P., Müller\xa0Schmied, H., Schuh, C., Portmann, F.\xa0T., and Eicker, A.: Global-scale assessment of groundwater depletion and related groundwater abstractions: Combining hydrological modeling with information from well observations and GRACE satellites, Water Resour. Res., 50, 5698–5720, https://doi.org/10.1002/2014WR015595, 2014.',
#    'DOI': '10.1002/2014WR015595'},
#   {'key': 'ref26',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Evaristo, J., Jasechko, S., and McDonnell, J.\xa0J.: Global separation of plant transpiration from groundwater and streamflow, Nature, 525, 91–94, https://doi.org/10.1038/nature14983, 2015.',
#    'DOI': '10.1038/nature14983'},
#   {'key': 'ref27',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Fader, M., Rost, S., Müller, C., Bondeau, A., and Gerten, D.: Virtual water content of temperate cereals and maize: Present and potential future patterns, J. Hydrol., 384, 218–231, https://doi.org/10.1016/j.jhydrol.2009.12.011, 2010.',
#    'DOI': '10.1016/j.jhydrol.2009.12.011'},
#   {'key': 'ref28',
#    'unstructured': 'FAO-AQUASTAT: AQUASTAT database – Food and Agriculture Organization of the United Nations (FAO), available at: http://www.fao.org/nr/water/aquastat/data/query/index.html?lang=en, 2014.'},
#   {'key': 'ref29',
#    'unstructured': 'FAO/IIASA/ISRIC/ISSCAS/JRC: Harmonized World Soil Database (version 1.2), available at: http://www.iiasa.ac.at/Research/LUC/External-World-soil-database/HTML/, 2012.'},
#   {'key': 'ref30',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Folberth, C., Elliott, J., Müller, C., Balkovic, J., Chryssanthacopoulos, J., Izaurralde, R. C., Jones, C. D., Khabarov, N., Liu, W., Reddy, A., Schmid, E., Skalský, R., Yang, H., Arneth, A., Ciais, P., Deryng, D., Lawrence, P. J., Olin, S., Pugh, T. A. M., Ruane, A. C., and Wang, X.: Uncertainties in global crop model frameworks: effects of cultivar distribution, crop management and soil handling on crop yield estimates, Biogeosciences Discuss., https://doi.org/10.5194/bg-2016-527, 2016a.',
#    'DOI': '10.5194/bg-2016-527'},
#   {'key': 'ref31',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Folberth, C., Skalský, R., Moltchanova, E., Balkovič, J., Azevedo, L.\xa0B., Obersteiner, M., and van\xa0der Velde, M.: Uncertainty in soil data can outweigh climate impact signals in global crop yield simulations, Nat. Comm., 7, 11872, https://doi.org/10.1038/ncomms11872, 2016b.',
#    'DOI': '10.1038/ncomms11872'},
#   {'key': 'ref32',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Forkel, M., Carvalhais, N., Schaphoff, S., v. Bloh, W., Migliavacca, M., Thurner, M., and Thonicke, K.: Identifying environmental controls on vegetation greenness phenology through model–data integration, Biogeosciences, 11, 7025-7050, https://doi.org/10.5194/bg-11-7025-2014, 2014.',
#    'DOI': '10.5194/bg-11-7025-2014'},
#   {'key': 'ref33',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Forkel, M., Migliavacca, M., Thonicke, K., Reichstein, M., Schaphoff, S., Weber, U., and Carvalhais, N.: Codominant water control on global interannual variability and trends in land surface phenology and greenness, Glob. Change Biol., 21, 3414–3435, https://doi.org/10.1111/gcb.12950, 2015.',
#    'DOI': '10.1111/gcb.12950'},
#   {'key': 'ref34',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Forkel, M., Carvalhais, N., Rödenbeck, C., Keeling, R., Heimann, M., Thonicke, K., Zaehle, S., and Reichstein, M.: Enhanced seasonal CO2 exchange caused by amplified plant productivity in northern ecosystems, Science, 351, 696–699, https://doi.org/10.1126/science.aac4971, 2016',
#    'DOI': '10.1126/science.aac4971'},
#   {'key': 'ref35',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Gerten, D., Schaphoff, S., Haberlandt, U., Lucht, W., and Sitch, S.: Terrestrial vegetation and water balance–hydrological evaluation of a dynamic global vegetation model, J. Hydrol., 286, 249–270, https://doi.org/10.1016/j.jhydrol.2003.09.029, 2004.',
#    'DOI': '10.1016/j.jhydrol.2003.09.029'},
#   {'key': 'ref36',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Gerten, D., Lucht, W., Ostberg, S., Heinke, J., Kowarsch, M., Kreft, H., Kundzewicz, Z.\xa0W., Rastgooy, J., Warren, R., and Schellnhuber, H.\xa0J.: Asynchronous exposure to global warming: freshwater resources and terrestrial ecosystems, Environ. Res. Lett., 8, 034032, https://doi.org/10.1088/1748-9326/8/3/034032, 2013.',
#    'DOI': '10.1088/1748-9326/8/3/034032'},
#   {'key': 'ref37',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Giglio, L., Randerson, J.\xa0T., and van\xa0der Werf, G.\xa0R.: Analysis of daily, monthly, and annual burned area using the fourth-generation global fire emissions database (GFED4), J. Geophys. Res.- Biogeo., 118, 317–328, https://doi.org/10.1002/jgrg.20042, 2013.',
#    'DOI': '10.1002/jgrg.20042'},
#   {'key': 'ref38',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Haddeland, I., Clark, D.\xa0B., Franssen, W., Ludwig, F., Voß, F., Arnell, N.\xa0W., Bertrand, N., Best, M., Folwell, S., Gerten, D., Gomes, S., Gosling, S.\xa0N., Hagemann, S., Hanasaki, N., Harding, R., Heinke, J., Kabat, P., Koirala, S., Oki, T., Polcher, J., Stacke, T., Viterbo, P., Weedon, G.\xa0P., and Yeh, P.: Multimodel Estimate of the Global Terrestrial Water Balance: Setup and First Results, J. Hydrometeor., 12, 869–884, https://doi.org/10.1175/2011JHM1324.1, 2011.',
#    'DOI': '10.1175/2011JHM1324.1'},
#   {'key': 'ref39',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Harris, I., Jones, P., Osborn, T., and Lister, D.: Updated high-resolution grids of monthly climatic observations – the CRU TS3.10 Dataset, Int. J. Climatol., 34, 623–642, https://doi.org/10.1002/joc.3711, 2014.',
#    'DOI': '10.1002/joc.3711'},
#   {'key': 'ref40',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Harrison, P.\xa0A., Dunford, R.\xa0W., Holman, I.\xa0P., and Rounsevell, M. D.\xa0A.: Climate change impact modelling needs to include cross-sectoral interactions, Nat. Clim. Change, 6, 885–890, https://doi.org/10.1038/nclimate3039, 2016.',
#    'DOI': '10.1038/nclimate3039'},
#   {'key': 'ref41',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Hattermann, F.\xa0F., Krysanova, V., Gosling, S.\xa0N., Dankers, R., Daggupati, P., Donnelly, C., Flörke, M., Huang, S., Motovilov, Y., Buda, S., Yang, T., Müller, C., Leng, G., Tang, Q., Portmann, F.\xa0T., Hagemann, S., Gerten, D., Wada, Y., Masaki, Y., Alemayehu, T., Satoh, Y., and Samaniego, L.: Cross-scale intercomparison of climate change impacts simulated by regional and global hydrological models in eleven large river basins, Clim. Change, 141, 561–576, https://doi.org/10.1007/s10584-016-1829-4, 2017.',
#    'DOI': '10.1007/s10584-016-1829-4'},
#   {'key': 'ref42',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Heck, V., Gerten, D., Lucht, W., and Boysen, L.\xa0R.: Is extensive terrestrial carbon dioxide removal a “green” form of geoengineering? A global modelling study, Global Planet. Change, 137, 123–130, https://doi.org/10.1016/j.gloplacha.2015.12.008, 2016.',
#    'DOI': '10.1016/j.gloplacha.2015.12.008'},
#   {'key': 'ref43',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Hoff, H., Falkenmark, M., Gerten, D., Gordon, L., Karlberg, L., and Rockström, J.: Greening the global water system, J. Hydrol., 384, 177–186, https://doi.org/10.1016/j.jhydrol.2009.06.026, 2010.',
#    'DOI': '10.1016/j.jhydrol.2009.06.026'},
#   {'key': 'ref44',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Iizumi, T., Yokozawa, M., Sakurai, G., Travasso, M.\xa0I., Romanenkov, V., Oettli, P., Newby, T., Ishigooka, Y., and Furuya, J.: Historical changes in global yields: major cereal and legume crops from 1982 to 2006, Global Ecol. Biogeogr., 23, 346–357, https://doi.org/10.1111/geb.12120, 2014.',
#    'DOI': '10.1111/geb.12120'},
#   {'key': 'ref45',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Jägermeyr, J., Gerten, D., Lucht, W., Hostert, P., Migliavacca, M., and Nemani, R.: A high-resolution approach to estimating ecosystem respiration at continental scales using operational satellite data, Glob. Change Biol., 20, 1191–1210, https://doi.org/10.1111/gcb.12443, 2014.',
#    'DOI': '10.1111/gcb.12443'},
#   {'key': 'ref46',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Jägermeyr, J., Pastor, A., Biemans, h., and Gerten, D.: Reconciling irrigated food production with environmental flows for Sustainable Development Goals implementation, Nat. Comm., 8, https://doi.org/10.1038/ncomms15900, 2017.',
#    'DOI': '10.1038/ncomms15900'},
#   {'key': 'ref47',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Jung, M., Reichstein, M., Margolis, H.\xa0A., Cescatti, A., Richardson, A.\xa0D., Arain, M.\xa0A., Arneth, A., Bernhofer, C., Bonal, D., Chen, J., Gianelle, D., Gobron, N., Kiely, G., Kutsch, W., Lasslop, G., Law, B.\xa0E., Lindroth, A., Merbold, L., Montagnani, L., Moors, E.\xa0J., Papale, D., Sottocornola, M., Vaccari, F., and Williams, C.: Global patterns of land-atmosphere fluxes of carbon dioxide, latent heat, and sensible heat derived from eddy covariance, satellite, and meteorological observations, J. Geophys. Res.-Biogeo., 116, G00J07, https://doi.org/10.1029/2010JG001566, 2011.',
#    'DOI': '10.1029/2010JG001566'},
#   {'key': 'ref48',
#    'unstructured': 'Kalnay, E., Kanamitsu, M., Kistler, R., Collins, W., Deaven, D., Gandin, L., Iredell, M., Saha, S., White, G., and Woollen, J.: The NCEP/NCAR 40-year reanalysis project, B. Am. Meteorol. Soc., 77, 437–471, https://doi.org/10.1175/1520-0477(1996)077&amp;lt;0437:TNYRP&amp;gt;2.0.CO;2, 1996a.'},
#   {'key': 'ref49',
#    'unstructured': 'Kalnay, E., Kanamitsu, M., Kistler, R., Collins, W., Deaven, D., Gandin, L., Iredell, M., Saha, S., White, G., Woollen, J., Zhu, Y., Leetmaa, A., Reynolds, R., Chelliah, M., Ebisuzaki, W., Higgins, W., Janowiak, J., Mo, K.\xa0C., Ropelewski, C., Wang, J., Jenne, R., and Joseph, D.: The NCEP/NCAR 40-Year Reanalysis Project, B. Am. Meteorol. Soc., 77, 437–471, https://doi.org/10.1175/1520-0477(1996)077&amp;lt;0437:TNYRP&amp;gt;2.0.CO;2, 1996b.'},
#   {'key': 'ref50',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Kaminski, T., Heimann, M., and Giering, R.: A coarse grid three-dimensional global inverse model of the atmospheric transport: 2. Inversion of the transport of CO2 in the 1980s, J. Geophys. Res.-Atmos., 104, 18555–18581, https://doi.org/10.1029/1999JD900146, 1999.',
#    'DOI': '10.1029/1999JD900146'},
#   {'key': 'ref51',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Kelley, D. I., Prentice, I. C., Harrison, S. P., Wang, H., Simard, M., Fisher, J. B., and Willis, K. O.: A comprehensive benchmarking system for evaluating global vegetation models, Biogeosciences, 10, 3313–3340, https://doi.org/10.5194/bg-10-3313-2013, 2013.',
#    'DOI': '10.5194/bg-10-3313-2013'},
#   {'key': 'ref52',
#    'unstructured': 'Knyazikhin, Y., Glassy, J., Privette, J.\xa0L., Tian, Y., Lotsch, A., Zhang, Y., Wang, Y., Morisette, J.\xa0T., Votava, P., Myneni, R.\xa0B., and others: MODIS leaf area index (LAI) and fraction of photosynthetically active radiation absorbed by vegetation (FPAR) product (MOD15) algorithm theoretical basis document, Theoretical Basis Document, NASA Goddard Space Flight Center, Greenbelt, MD, 20771, 1999.'},
#   {'key': 'ref53',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Kollas, C., Kersebaum, K.\xa0C., Nendel, C., Manevski, K., Müller, C., Palosuo, T., Armas-Herrera, C.\xa0M., Beaudoin, N., Bindi, M., Charfeddine, M., Conradt, T., Constantin, J., Eitzinger, J., Ewert, F., Ferrise, R., Gaiser, T., Cortazar-Atauri, I. G.\xa0d., Giglio, L., Hlavinka, P., Hoffmann, H., Hoffmann, M.\xa0P., Launay, M., Manderscheid, R., Mary, B., Mirschel, W., Moriondo, M., Olesen, J.\xa0E., Öztürk, I., Pacholski, A., Ripoche-Wachter, D., Roggero, P.\xa0P., Roncossek, S., Rötter, R.\xa0P., Ruget, F., Sharif, B., Trnka, M., Ventrella, D., Waha, K., Wegehenkel, M., Weigel, H.-J., and Wu, L.: Crop rotation modelling–A European model intercomparison, Eur. J. Agron., 70, 98–111, https://doi.org/10.1016/j.eja.2015.06.007, 2015.',
#    'DOI': '10.1016/j.eja.2015.06.007'},
#   {'key': 'ref54',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Langerwisch, F., Rost, S., Gerten, D., Poulter, B., Rammig, A., and Cramer, W.: Potential effects of climate change on inundation patterns in the Amazon Basin, Hydrol. Earth Syst. Sci., 17, 2247-2262, https://doi.org/10.5194/hess-17-2247-2013, 2013.',
#    'DOI': '10.5194/hess-17-2247-2013'},
#   {'key': 'ref55',
#    'doi-asserted-by': 'crossref',
#    'unstructured': "Le Quéré, C., Moriarty, R., Andrew, R. M., Canadell, J. G., Sitch, S., Korsbakken, J. I., Friedlingstein, P., Peters, G. P., Andres, R. J., Boden, T. A., Houghton, R. A., House, J. I., Keeling, R. F., Tans, P., Arneth, A., Bakker, D. C. E., Barbero, L., Bopp, L., Chang, J., Chevallier, F., Chini, L. P., Ciais, P., Fader, M., Feely, R. A., Gkritzalis, T., Harris, I., Hauck, J., Ilyina, T., Jain, A. K., Kato, E., Kitidis, V., Klein Goldewijk, K., Koven, C., Landschützer, P., Lauvset, S. K., Lefèvre, N., Lenton, A., Lima, I. D., Metzl, N., Millero, F., Munro, D. R., Murata, A., Nabel, J. E. M. S., Nakaoka, S., Nojiri, Y., O'Brien, K., Olsen, A., Ono, T., Pérez, F. F., Pfeil, B., Pierrot, D., Poulter, B., Rehder, G., Rödenbeck, C., Saito, S., Schuster, U., Schwinger, J., Séférian, R., Steinhoff, T., Stocker, B. D., Sutton, A. J., Takahashi, T., Tilbrook, B., van der Laan-Luijkx, I. T., van der Werf, G. R., van Heuven, S., Vandemark, D., Viovy, N., Wiltshire, A., Zaehle, S., and Zeng, N.: Global Carbon Budget 2015, Earth Syst. Sci. Data, 7, 349–396, https://doi.org/10.5194/essd-7-349-2015, 2015.",
#    'DOI': '10.5194/essd-7-349-2015'},
#   {'key': 'ref56',
#    'doi-asserted-by': 'crossref',
#    'unstructured': "Lehner, B., Liermann, C.\xa0R., Revenga, C., Vörösmarty, C., Fekete, B., Crouzet, P., Döll, P., Endejan, M., Frenken, K., and Magome, J.: High-resolution mapping of the world's reservoirs and dams for sustainable river-flow management, Front. Ecol. Environ., 9, 494–502, https://doi.org/10.1890/100125, 2011.",
#    'DOI': '10.1890/100125'},
#   {'key': 'ref57',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Lin, Y., Medlyn, B.\xa0E., Duursma, R.\xa0E., Prentice, I.\xa0C., Wang, H., Baig, S., Eamus, D., Resco\xa0de Dios, V., Mitchell, P., Ellsworth, D.\xa0S., Op\xa0de Beeck, M., Wallin, G., Uddling, J., Tarvainen, L., Linderson, M., Cernusak, L.\xa0A., Nippert, J.\xa0B., Ocheltree, T.\xa0W., Tissue, D. T. andMartin-StPaul, N.\xa0K., Rogers, A., Warren, J.\xa0M., De\xa0Angelis, P., Hikosaka, K., Han, Q., Onoda, Y., Gimeno, T.\xa0E., Barton, C. V. M.\xa0andBennie, J., Bonal, J.\xa0andBosc, A., Löw, M., Macinins-Ng, C., Rey, A., Rowland, L., Setterfield, S.\xa0A., Tausz-Posch, S., Zaragoza-Castells, J.\xa0andBroadmeadow, M. S.\xa0J., Drake, J.\xa0E., Freeman, M., Ghannoum, O., Hutley, L.\xa0B., Kelly, J.\xa0W., Kikuzawa, K., Kolari, P., Koyama, K., Limousin, J., Meir, P., Lola\xa0da Costa, A.\xa0C., Mikkelsen, T.\xa0N., Salinas, N., Sun, W., and Wingate, L.: Optimal stomatal behaviour around the world, Nature Clim. Change, 5, 459–464, https://doi.org/10.1038/nclimate2550, 2015.',
#    'DOI': '10.1038/nclimate2550'},
#   {'key': 'ref58',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Liu, Y.\xa0Y., van Dijk, A. I. J.\xa0M., de\xa0Jeu, R. A.\xa0M., Canadell, J.\xa0G., McCabe, M.\xa0F., Evans, J.\xa0P., and Wang, G.: Recent reversal in loss of global terrestrial biomass, Nat. Clim. Change, 5, 470–474, https://doi.org/10.1038/nclimate2581, 2015.',
#    'DOI': '10.1038/nclimate2581'},
#   {'key': 'ref59',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Lobell, D.\xa0B. and Asner, G.\xa0P.: Moisture Effects on Soil Reflectance, Soil. Sci. Soc. Am. J., 66, 722–727, https://doi.org/10.2136/sssaj2002.7220, 2002.',
#    'DOI': '10.2136/sssaj2002.7220'},
#   {'key': 'ref60',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Lucht, W., Schaaf, C., and Strahler, A.: An algorithm for the retrieval of albedo from space using semiempirical BRDF models, IEEE T. Geosci. Remote, 38, 977–998, https://doi.org/10.1109/36.841980, 2000.',
#    'DOI': '10.1109/36.841980'},
#   {'key': 'ref61',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Luo, Y. Q., Randerson, J. T., Abramowitz, G., Bacour, C., Blyth, E., Carvalhais, N., Ciais, P., Dalmonech, D., Fisher, J. B., Fisher, R., Friedlingstein, P., Hibbard, K., Hoffman, F., Huntzinger, D., Jones, C. D., Koven, C., Lawrence, D., Li, D. J., Mahecha, M., Niu, S. L., Norby, R., Piao, S. L., Qi, X., Peylin, P., Prentice, I. C., Riley, W., Reichstein, M., Schwalm, C., Wang, Y. P., Xia, J. Y., Zaehle, S., and Zhou, X. H.: A framework for benchmarking land models, Biogeosciences, 9, 3857-3874, https://doi.org/10.5194/bg-9-3857-2012, 2012.',
#    'DOI': '10.5194/bg-9-3857-2012'},
#   {'key': 'ref62',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Luyssaert, S., Inglima, I., Jung, M., Richardson, A.\xa0D., Reichstein, M., Papale, D., Piao, S.\xa0L., Schulze, E.\xa0D., Wingate, L., Matteucci, G., Aragao, L., Aubinet, M., Beer, C., Bernhofer, C., Black, K.\xa0G., Bonal, D., Bonnefond, J.\xa0M., Chambers, J., Ciais, P., Cook, B., Davis, K.\xa0J., Dolman, A.\xa0J., Gielen, B., Goulden, M., Grace, J., Granier, A., Grelle, A., Griffis, T., Grünwald, T., Guidolotti, G., Hanson, P.\xa0J., Harding, R., Hollinger, D.\xa0Y., Hutyra, L.\xa0R., Kolari, P., Kruijt, B., Kutsch, W., Lagergren, F., Laurila, T., Law, B.\xa0E., Le\xa0Maire, G., Lindroth, A., Loustau, D., Malhi, Y., Mateus, J., Migliavacca, M., Misson, L., Montagnani, L., Moncrieff, J., Moors, E., Munger, J.\xa0W., Nikinmaa, E., Ollinger, S.\xa0V., Pita, G., Rebmann, C., Roupsard, O., Saigusa, N., Sanz, M.\xa0J., Seufert, G., Sierra, C., Smith, M.\xa0L., Tang, J., Valentini, R., Vesala, T., and Janssens, I.\xa0A.: CO2 balance of boreal, temperate, and tropical forests derived from a global database, Glob. Change Biol., 13, 2509–2537, https://doi.org/10.1111/j.1365-2486.2007.01439.x, 2007.',
#    'DOI': '10.1111/j.1365-2486.2007.01439.x'},
#   {'key': 'ref63',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Medlyn, B.\xa0E., Zaehle, S., De\xa0Kauwe, M.\xa0G., Walker, A.\xa0P., Dietze, M.\xa0C., Hanson, P.\xa0J., Hickler, T., Jain, A.\xa0K., Luo, Y., Parton, W., Prentice, I.\xa0C., Thornton, P.\xa0E., Wang, S., Wang, Y.-P., Weng, E., Iversen, C.\xa0M., McCarthy, H.\xa0R., Warren, J.\xa0M., Oren, R., and Norby, R.\xa0J.: Using ecosystem experiments to improve vegetation models, Nat. Clim. Change, 5, 528–534, https://doi.org/10.1038/nclimate2621, 2015.',
#    'DOI': '10.1038/nclimate2621'},
#   {'key': 'ref64',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Müller, C., Stehfest, E., Minnen, J. G.\xa0v., Strengers, B., Bloh, W.\xa0v., Beusen, A. H.\xa0W., Schaphoff, S., Kram, T., and Lucht, W.: Drivers and patterns of land biosphere carbon balance reversal, Environ. Res. Lett., 11, 044002, https://doi.org/10.1088/1748-9326/11/4/044002, 2016.',
#    'DOI': '10.1088/1748-9326/11/4/044002'},
#   {'key': 'ref65',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Müller, C., Elliott, J., Chryssanthacopoulos, J., Arneth, A., Balkovic, J., Ciais, P., Deryng, D., Folberth, C., Glotter, M., Hoek, S., Iizumi, T., Izaurralde, R. C., Jones, C., Khabarov, N., Lawrence, P., Liu, W., Olin, S., Pugh, T. A. M., Ray, D. K., Reddy, A., Rosenzweig, C., Ruane, A. C., Sakurai, G., Schmid, E., Skalsky, R., Song, C. X., Wang, X., de Wit, A., and Yang, H.: Global gridded crop model evaluation: benchmarking, skills, deficiencies and implications, Geosci. Model Dev., 10, 1403-1422, https://doi.org/10.5194/gmd-10-1403-2017, 2017.',
#    'DOI': '10.5194/gmd-10-1403-2017'},
#   {'key': 'ref66',
#    'unstructured': 'Nachtergaele, F., van Velthuizen, H., Verelst, L., Batjes, N., Dijkshoorn, K., van Engelen, V., Fischer, G., Jones, A., Montanarella, L., and Petri, M.: Harmonized world soil database, Food and Agriculture Organization of the United Nations, available at: http://www.fao.org/soils-portal/soil-survey/soil-maps-and-databases/harmonized-world-soil-database-v12/en/, 2008.'},
#   {'key': 'ref67',
#    'unstructured': 'New, M., Hulme, M., and Jones, P.: Representing Twentieth-Century Space–Time Climate Variability, Part II: Development of 1901–96 Monthly Grids of Terrestrial Surface Climate, J. Climate, 13, 2217–2238, https://doi.org/10.1175/1520-0442(2000)013&amp;lt;2217:RTCSTC&amp;gt;2.0.CO;2, 2000.'},
#   {'key': 'ref68',
#    'unstructured': 'ORNL\xa0DAAC, Oak\xa0Ridge, T.\xa0U.: Oak Ridge National Laboratory Distributed Active Archive Center (ORNL DAAC), available at: http://fluxnet.ornl.gov/, 2011.'},
#   {'key': 'ref69',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Ostberg, S., Schaphoff, S., Lucht, W., and Gerten, D.: Three centuries of dual pressure from land use and climate change on the biosphere, Environ. Res. Lett., 10, 44011, https://doi.org/10.1088/1748-9326/10/4/044011, 2015.',
#    'DOI': '10.1088/1748-9326/10/4/044011'},
#   {'key': 'ref70',
#    'unstructured': 'Portmann, F.\xa0T., Siebert, S., Bauer, C., and Döll, P.: Global dataset of monthly growing areas of 26 irrigated crops, Frankfurt Hydrology Paper, 2008.'},
#   {'key': 'ref71',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Portmann, F.\xa0T., Siebert, S., and Döll, P.: MIRCA2000 – Global monthly irrigated and rainfed crop areas around the year 2000: A new high-resolution data set for agricultural and hydrological modeling, Global Biogeochem. Cy., 24, 1–24, https://doi.org/10.1029/2008GB003435, 2010.',
#    'DOI': '10.1029/2008GB003435'},
#   {'key': 'ref72',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Porwollik, V., Müller, C., Elliott, J., Chryssanthacopoulos, J., Iizumi, T., Ray, D.\xa0K., Ruane, A.\xa0C., Arneth, A., Balkovič, J., Ciais, P., Deryng, D., Folberth, C., Izaurralde, R.\xa0C., Jones, C.\xa0D., Khabarov, N., Lawrence, P.\xa0J., Liu, W., Pugh, T.\xa0A., Reddy, A., Sakurai, G., Schmid, E., Wang, X., de\xa0Wit, A., and Wu, X.: Spatial and temporal uncertainty of crop yield aggregations, Eur. J. Agron., https://doi.org/10.1016/j.eja.2016.08.006, 2016.',
#    'DOI': '10.1016/j.eja.2016.08.006'},
#   {'key': 'ref73',
#    'unstructured': 'Randerson, J., van\xa0der Werf, G.\xa0R., Giglio, L., Collatz, G.\xa0J., and Kasibhatla, P.\xa0S.: Global Fire Emissions Database, Version 4, (GFEDv4), ORNL DAAC, https://doi.org/10.3334/ORNLDAAC/1293, 2015.'},
#   {'key': 'ref74',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Ray, D.\xa0K., Gerber, J.\xa0S., MacDonald, G.\xa0K., and West, P.\xa0C.: Climate variation explains a third of global crop yield variability, Nat. Comm., 6, 5989, https://doi.org/10.1038/ncomms6989, 2015.',
#    'DOI': '10.1038/ncomms6989'},
#   {'key': 'ref75',
#    'unstructured': 'Rödenbeck, C.: Estimating CO2 sources and sinks from atmospheric mixing ratio measurements using a global inversion of atmospheric transport, Technical Reports, Max Planck Institute for Biogeochemistry, available at: http://pubman.mpdl.mpg.de/pubman/faces/viewItemOverviewPage.jsp?itemId=escidoc:1691952, 2005.'},
#   {'key': 'ref76',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Rödenbeck, C., Houweling, S., Gloor, M., and Heimann, M.: CO2 flux history 1982–2001 inferred from atmospheric data using a global inversion of atmospheric transport, Atmos. Chem. Phys., 3, 1919–1964, https://doi.org/10.5194/acp-3-1919-2003, 2003.',
#    'DOI': '10.5194/acp-3-1919-2003'},
#   {'key': 'ref77',
#    'unstructured': 'Rosegrant, M.\xa0W., Cai, X., and Cline, S.\xa0A.: World Water and Food to 2025: Dealing with Scarcity, Tech. rep., International Food Policy Research Institute, Washigton, DC, 2002.'},
#   {'key': 'ref78',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Rosenzweig, C., Elliott, J., Deryng, D., Ruane, A.\xa0C., Müller, C., Arneth, A., Boote, K.\xa0J., Folberth, C., Glotter, M., and Khabarov, N.: Assessing agricultural risks of climate change in the 21st century in a global gridded crop model intercomparison, P. Natl. Acad. Sci. USA, 111, 3268–3273, https://doi.org/10.1073/pnas.1222463110, 2014.',
#    'DOI': '10.1073/pnas.1222463110'},
#   {'key': 'ref79',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Ruane, A.\xa0C., Hudson, N.\xa0I., Asseng, S., Camarrano, D., Ewert, F., Martre, P., Boote, K.\xa0J., Thorburn, P.\xa0J., Aggarwal, P.\xa0K., and Angulo, C.: Multi-wheat-model ensemble responses to interannual climate variability, Environ. Model. Softw., 81, 86–101, https://doi.org/10.1016/j.envsoft.2016.03.008, 2016.',
#    'DOI': '10.1016/j.envsoft.2016.03.008'},
#   {'key': 'ref80',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Saatchi, S.\xa0S., Harris, N.\xa0L., Brown, S., Lefsky, M., Mitchard, E. T.\xa0A., Salas, W., Zutta, B.\xa0R., Buermann, W., Lewis, S.\xa0L., Hagen, S., Petrova, S., White, L., Silman, M., and Morel, A.: Benchmark map of forest carbon stocks in tropical regions across three continents, P. Natl. Acad. Sci. USA, 108, 9899–9904, https://doi.org/10.1073/pnas.1019576108, 2011.',
#    'DOI': '10.1073/pnas.1019576108'},
#   {'key': 'ref81',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Saleska, S.\xa0R., Miller, S.\xa0D., Matross, D.\xa0M., Goulden, M.\xa0L., Wofsy, S.\xa0C., Da\xa0Rocha, H.\xa0R., De\xa0Camargo, P.\xa0B., Crill, P., Daube, B.\xa0C., De\xa0Freitas, H.\xa0C., Hutyra, L., Keller, M., Kirchhoff, V., Menton, M., Munger, J. W., Hammond Pyle, E., Rice, A. H., and Silva, H.: Carbon in Amazon Forests: Unexpected Seasonal Fluxes and Disturbance-Induced Losses, Science, 302, 1554–1557, https://doi.org/10.1126/science.1091165, 2003.',
#    'DOI': '10.1126/science.1091165'},
#   {'key': 'ref82',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Sauer, T., Havlík, P., Schneider, U.\xa0a., Schmid, E., Kindermann, G., and Obersteiner, M.: Agriculture and resource availability in a changing world: The role of irrigation, Water Resour. Res., 46, W06503, https://doi.org/10.1029/2009WR007729, 2010.',
#    'DOI': '10.1029/2009WR007729'},
#   {'key': 'ref83',
#    'doi-asserted-by': 'crossref',
#    'unstructured': "Schaaf, C.\xa0B., Gao, F., Strahler, A.\xa0H., Lucht, W., Li, X., Tsang, T., Strugnell, N.\xa0C., Zhang, X., Jin, Y., Muller, J.-P., Lewis, P., Barnsley, M., Hobson, P., Disney, M., Roberts, G., Dunderdale, M., Doll, C., d'Entremont, R.\xa0P., Hu, B., Liang, S., Privette, J.\xa0L., and Roy, D.: First operational BRDF, albedo nadir reflectance products from MODIS, The Moderate Resolution Imaging Spectroradiometer (MODIS): a new generation of Land Surface Monitoring, Remote Sens. Environ., 83, 135–148, https://doi.org/10.1016/S0034-4257(02)00091-3, 2002.",
#    'DOI': '10.1016/S0034-4257(02)00091-3'},
#   {'key': 'ref84',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Schaphoff, S., Heyder, U., Ostberg, S., Gerten, D., Heinke, J., and Lucht, W.: Contribution of permafrost soils to the global carbon budget, Environ. Res. Lett., 8, 014026, https://doi.org/10.1088/1748-9326/8/1/014026, 2013.',
#    'DOI': '10.1088/1748-9326/8/1/014026'},
#   {'key': 'ref85',
#    'unstructured': 'Schaphoff, S., von Bloh, W., Rammig, A., Thonicke, K., Forkel, M., Biemans, H., Gerten, D., Heinke, J., Jägermyer, J., Knauer, J., Lucht, W., Müller, C., Rolinski, S., and Waha, K.: LPJmL4 model output for the publications in GMD: LPJmL4 – a dynamic global vegetation model with managed land: Part I – Model description and Part II – Model evaluation, https://doi.org/10.5880/pik.2017.009, 2018a.'},
#   {'key': 'ref86',
#    'unstructured': 'Schaphoff, S., von Bloh, W., Thonicke, K., Biemans, H., Forkel, M., Heinke, J., Jägermyer, J., Müller, C., Rolinski, S., Waha, K., Stehfest, E., de\xa0Waal, L., Heyder, U., Gumpenberger, M., and Beringer, T.: LPJmL4 Model Code, V. 4.0. GFZ Data Services, https://doi.org/10.5880/pik.2018.002, 2018b.'},
#   {'key': 'ref87',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Schaphoff, S., von Bloh, W., Rammig, A., Thonicke, K., Biemans, H., Forkel, M., Gerten, D., Heinke, J., Jägermyer, J., Knauer, J., Langerwisch, F., Lucht, W., Müller, C., Rolinski, S., and Waha, K.: LPJmL4 – a dynamic global vegetation model with managed land – Part 1: Model description, Geosci. Model Dev., 11, 1343–1375, https://doi.org/10.5194/gmd-11-1343-2018, 2018c.',
#    'DOI': '10.5194/gmd-11-1343-2018'},
#   {'key': 'ref88',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Schauberger, B., Rolinski, S., and Müller, C.: A network-based approach for semi-quantitative knowledge mining and its application to yield variability, Environ. Res. Lett., 11, 123001, https://doi.org/10.1088/1748-9326/11/12/123001, 2016.',
#    'DOI': '10.1088/1748-9326/11/12/123001'},
#   {'key': 'ref89',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Schauberger, B., Rolinski, S., Schaphoff, S., and Müller, C.: Global historical soybean and wheat yield loss estimates from ozone pollution considering water and temperature as modifying effects, Glob. Change Biol., under review, 2018.',
#    'DOI': '10.1016/j.agrformet.2018.11.004'},
#   {'key': 'ref90',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Siderius, C., Biemans, H., Wiltshire, A., Rao, S., Franssen, W. H.\xa0P., Kumar, P., Gosain, A.\xa0K., van Vliet, M. T.\xa0H., and Collins, D.\xa0N.: Snowmelt contributions to discharge of the Ganges, Sci. Total Environ., 468, S93–S101, https://doi.org/10.1016/j.scitotenv.2013.05.084, 2013.',
#    'DOI': '10.1016/j.scitotenv.2013.05.084'},
#   {'key': 'ref91',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Siebert, S. and Döll, P.: Quantifying blue and green virtual water contents in global crop production as well as potential production losses without irrigation, J. Hydrol., 384, 198–217, https://doi.org/10.1016/j.jhydrol.2009.07.031, 2010.',
#    'DOI': '10.1016/j.jhydrol.2009.07.031'},
#   {'key': 'ref92',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Sitch, S., Smith, B., Prentice, I.\xa0C., Arneth, A., Bondeau, A., Cramer, W., Kaplan, J.\xa0O., Levis, S., Lucht, W., Sykes, M.\xa0T., Thonicke, K., and Venevsky, S.: Evaluation of ecosystem dynamics, plant geography and terrestrial carbon cycling in the LPJ dynamic global vegetation model, Glob. Change Biol., 9, 161–185, https://doi.org/10.1046/j.1365-2486.2003.00569.x, 2003.',
#    'DOI': '10.1046/j.1365-2486.2003.00569.x'},
#   {'key': 'ref93',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Smith, W.\xa0K., Reed, S.\xa0C., Cleveland, C.\xa0C., Ballantyne, A.\xa0P., Anderegg, W. R.\xa0L., Wieder, W.\xa0R., Liu, Y.\xa0Y., and Running, S.\xa0W.: Large divergence of satellite and Earth system model estimates of global terrestrial CO2 fertilization, Nat. Clim. Change, 6, 306–310, https://doi.org/10.1038/nclimate2879, 2016.',
#    'DOI': '10.1038/nclimate2879'},
#   {'key': 'ref94',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Steffen, W., Richardson, K., Rockström, J., Cornell, S.\xa0E., Fetzer, I., Bennett, E.\xa0M., Biggs, R., Carpenter, S.\xa0R., de\xa0Vries, W., de\xa0Wit, C.\xa0A., Folke, C., Gerten, D., Heinke, J., Mace, G.\xa0M., Persson, L.\xa0M., Ramanathan, V., Reyers, B., and Sörlin, S.: Planetary boundaries: Guiding human development on a changing planet, Science, 347, 1259855, https://doi.org/10.1126/science.1259855, 2015.',
#    'DOI': '10.1126/science.1259855'},
#   {'key': 'ref95',
#    'unstructured': 'Tans, P. and Keeling, R.: Trends in Atmospheric Carbon Dioxide, National Oceanic &amp;amp; Atmospheric Administration, Earth System Research Laboratory (NOAA/ESRL), available at: http://www.esrl.noaa.gov/gmd/ccgg/trends, 2015.'},
#   {'key': 'ref96',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Tarnocai, C., Canadell, J.\xa0G., Schuur, E. A.\xa0G., Kuhry, P., Mazhitova, G., and Zimov, S.: Soil organic carbon pools in the northern circumpolar permafrost region, Global Biogeochem. Cy., 23, GB2023, https://doi.org/10.1029/2008GB003327, 2009.',
#    'DOI': '10.1029/2008GB003327'},
#   {'key': 'ref97',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Taylor, K.\xa0E.: Summarizing multiple aspects of model performance in a single diagram, J. Geophys. Res.-Atmos., 106, 7183–7192, https://doi.org/10.1029/2000JD900719, 2001.',
#    'DOI': '10.1029/2000JD900719'},
#   {'key': 'ref98',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Thonicke, K., Venevsky, S., Sitch, S., and Cramer, W.: The role of fire disturbance for global vegetation dynamics: coupling fire into a Dynamic Global Vegetation Model, Global Ecol. Biogeogr., 10, 661–677, https://doi.org/10.1046/j.1466-822X.2001.00175.x, 2001.',
#    'DOI': '10.1046/j.1466-822X.2001.00175.x'},
#   {'key': 'ref99',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Thonicke, K., Spessa, A., Prentice, I. C., Harrison, S. P., Dong, L., and Carmona-Moreno, C.: The influence of vegetation, fire spread and fire behaviour on biomass burning and trace gas emissions: results from a process-based model, Biogeosciences, 7, 1991–2011, https://doi.org/10.5194/bg-7-1991-2010, 2010.',
#    'DOI': '10.5194/bg-7-1991-2010'},
#   {'key': 'ref100',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Thoning, K., Tans, P., and Komhyr, W.: Atmospheric carbon dioxide at Mauna Loa Observatory. II – Analysis of the NOAA GMCC data, 1974–1985, J. Geophys. Res., 94, 8549–8565, https://doi.org/10.1029/JD094iD06p08549, 1989.',
#    'DOI': '10.1029/JD094iD06p08549'},
#   {'key': 'ref101',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Thurner, M., Beer, C., Santoro, M., Carvalhais, N., Wutzler, T., Schepaschenko, D., Shvidenko, A., Kompter, E., Ahrens, B., Levick, S.\xa0R., and Schmullius, C.: Carbon stock and density of northern boreal and temperate forests, Global Ecol. Biogeogr., 23, 297–310, https://doi.org/10.1111/geb.12125, 2014.',
#    'DOI': '10.1111/geb.12125'},
#   {'key': 'ref102',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'University\xa0of East Anglia Climatic Research Unit, Harris, I. C., and Jones, P.: CRU TS3.23: Climatic Research Unit (CRU) Time-Series (TS) Version 3.23 of High Resolution Gridded Data of Month-by-month Variation in Climate (Jan. 1901–Dec. 2014), Centre for Environmental Data Analysis, https://doi.org/10.5285/4c7fdfa6-f176-4c58-acee-683d5e9d2ed5, 2015.',
#    'DOI': '10.5285/4c7fdfa6-f176-4c58-acee-683d5e9d2ed5'},
#   {'key': 'ref103',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Vorosmarty, C. and Fekete, B.: ISLSCP II River Routing Data (STN-30p), in: ISLSCP Initiative II Collection, Data set, edited by: Hall, F.\xa0G., Collatz, G., Meeson, B., Los, S., Brown\xa0de Colstoun, E., and Landis, D., ORNL Distributed Active Archive Center, https://doi.org/10.3334/ORNLDAAC/1005, 2011.',
#    'DOI': '10.3334/ORNLDAAC/1005'},
#   {'key': 'ref104',
#    'unstructured': 'Vörösmarty, C.\xa0J., Fekete, B., and Tucker, B.: River Discharge Database, Version 1.0 (RivDIS v1.0), Volumes 0 through 6, A contribution to IHP-V Theme 1. Technical Documents in Hydrology Series, UNESCO, Paris, 1996.'},
#   {'key': 'ref105',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Wada, Y. and Bierkens, M. F.\xa0P.: Sustainability of global water use: past reconstruction and future projections, Environ. Res. Lett., 9, 104003, https://doi.org/10.1088/1748-9326/9/10/104003, 2014.',
#    'DOI': '10.1088/1748-9326/9/10/104003'},
#   {'key': 'ref106',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Wada, Y., van Beek, L. P.\xa0H., Viviroli, D., Dürr, H.\xa0H., Weingartner, R., and Bierkens, M. F.\xa0P.: Global monthly water stress: 2. Water demand and severity of water stress, Water Resour. Res., 47, W07518, https://doi.org/10.1029/2010WR009792, 2011.',
#    'DOI': '10.1029/2010WR009792'},
#   {'key': 'ref107',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Waha, K., van Bussel, L. G.\xa0J., Müller, C., and Bondeau, A.: Climate-driven simulation of global crop sowing dates, Global Ecol. Biogeogr., 21, 247–259, https://doi.org/10.1111/j.1466-8238.2011.00678.x, 2012.',
#    'DOI': '10.1111/j.1466-8238.2011.00678.x'},
#   {'key': 'ref108',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Waha, K., Müller, C., Bondeau, a., Dietrich, J., Kurukulasuriya, P., Heinke, J., and Lotze-Campen, H.: Adaptation to climate change through the choice of cropping system and sowing date in sub-Saharan Africa, Global Environ. Chang., 23, 130–143, https://doi.org/10.1016/j.gloenvcha.2012.11.001, 2013.',
#    'DOI': '10.1016/j.gloenvcha.2012.11.001'},
#   {'key': 'ref109',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Warszawski, L., Frieler, K., Huber, V., Piontek, F., Serdeczny, O., and Schewe, J.: The Inter-Sectoral Impact Model Intercomparison Project (ISI–MIP): Project framework, P. Natl. Acad. Sci. USA, 111, 3228–3232, https://doi.org/10.1073/pnas.1312330110, 2014.',
#    'DOI': '10.1073/pnas.1312330110'},
#   {'key': 'ref110',
#    'unstructured': 'Willmott, C.\xa0J.: Some comments on the evaluation of model performance, B. Am. Meteorol. Soc., 63, 1309–1313, https://doi.org/10.1175/1520-0477(1982)063&amp;lt;1309:SCOTEO&amp;gt;2.0.CO;2, 1982.'},
#   {'key': 'ref111',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Zhu, Z., Bi, J., Pan, Y., Ganguly, S., Anav, A., Xu, L., Samanta, A., Piao, S., Nemani, R.\xa0R., and Myneni, R.\xa0B.: Global Data Sets of Vegetation Leaf Area Index (LAI)3g and Fraction of Photosynthetically Active Radiation (FPAR)3g Derived from Global Inventory Modeling and Mapping Studies (GIMMS) Normalized Difference Vegetation Index (NDVI3g) for the Period 1981 to 2011, Remote Sens., 5, 927–948, https://doi.org/10.3390/rs5020927, 2013.',
#    'DOI': '10.3390/rs5020927'},
#   {'key': 'ref112',
#    'doi-asserted-by': 'crossref',
#    'unstructured': 'Zscheischler, J., Mahecha, M., Von\xa0Buttlar, J., Harmeling, S., Jung, M., Rammig, A., Randerson, J.\xa0T., Schöllkopf, B., Seneviratne, S.\xa0I., Tomelleri, E., Zaehle, S., and Reichstein, M.: Few extreme events dominate global interannual variability in gross primary production, Environ. Res. Lett., 9, 035001, https://doi.org/10.1088/1748-9326/9/3/035001, 2014a.',
#    'DOI': '10.1088/1748-9326/9/3/035001'}],
#  'container-title': 'Geoscientific Model Development',
#  'original-title': [],
#  'language': 'en',
#  'link': [{'URL': 'https://gmd.copernicus.org/articles/11/1377/2018/gmd-11-1377-2018.pdf',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'deposited': {'date-parts': [[2020, 9, 15]],
#   'date-time': '2020-09-15T23:49:17Z',
#   'timestamp': 1600213757000},
#  'score': 1,
#  'resource': {'primary': {'URL': 'https://gmd.copernicus.org/articles/11/1377/2018/'}},
#  'subtitle': [],
#  'short-title': [],
#  'issued': {'date-parts': [[2018, 4, 12]]},
#  'references-count': 112,
#  'journal-issue': {'issue': '4', 'published-online': {'date-parts': [[2018]]}},
#  'URL': 'http://dx.doi.org/10.5194/gmd-11-1377-2018',
#  'relation': {'is-part-of': [{'id-type': 'doi',
#     'id': '10.5880/pik.2017.009',
#     'asserted-by': 'subject'},
#    {'id-type': 'doi', 'id': '10.5880/pik.2018.002', 'asserted-by': 'subject'}],
#   'has-preprint': [{'id-type': 'doi',
#     'id': '10.5194/gmd-2017-146',
#     'asserted-by': 'subject'},
#    {'id-type': 'doi', 'id': '10.5194/gmd-2017-146', 'asserted-by': 'object'}]},
#  'ISSN': ['1991-9603'],
#  'container-title-short': 'Geosci. Model Dev.',
#  'published': {'date-parts': [[2018, 4, 12]]}}

# %%
# very slow if crossRef_df_gbif_filtered2_deduplicated is large - about 1 hour for everything from year 2000
# CHANGE THIS TO CROSSREF API BECAUSE DOI.ORG API IS bad
# section to get publication info from DOI.org api to add to crossRef_df_gbif_filtered2_deduplicated? e.g. title, authors etc
pub_info = []
for pubdoi in crossRef_df_gbif_filtered2_deduplicated['subj_id']:
    r = requests.get(pubdoi, headers={"Accept": "application/json"})
    
    try:
        title = r.json()['title']
    except:
        title = "Info not given"
    
    try:           
        authors = []
        for jj in range(len(r.json()['author'])):
            authors.append([r.json()['author'][jj]['given'],r.json()['author'][jj]['family']])
    except:
        authors = "Info not given"
    
    try:
        publisher = r.json()['publisher']
    except:
        publisher = "Info not given"
        
    pub_info.append({
            'pub_doi': pubdoi,
            'pub_Title': title,
            'pub_authors': authors,
            'publisher': publisher
        # add publication date to this - in order to check if this is before the dataset publication date - could be a way to filter out dodgy results
    })
    
    print(pubdoi)
    
# add new publication info columns to dataframe
pubInfo_df = pd.DataFrame(pub_info)

# loop through new columns to be added to df
for ii in pubInfo_df.columns[1:]:
    # create dictionary of doi, value pairs 
    d = pubInfo_df.set_index('pub_doi')[ii].to_dict()
    
    # use the doi to map the dictionary to crossRef_df_gbif_filtered2_deduplicated
    crossRef_df_gbif_filtered2_deduplicated.loc[:,ii] = crossRef_df_gbif_filtered2_deduplicated.subj_id.map(d)
    
print("Done!")
# Out:
# https://doi.org/10.29110/soylemdergi.1169829
# https://doi.org/10.1186/s12888-022-04460-7
# https://doi.org/10.34234/ded.1166387
# https://doi.org/10.46652/rgn.v6i27.766
# https://doi.org/10.1007/978-3-030-78280-1_11
# https://doi.org/10.3145/epi.2023.ene.06
# https://doi.org/10.22430/24223182.1800
# https://doi.org/10.4236/jfrm.2021.104023
# https://doi.org/10.24142/rvc.n26a4
# https://doi.org/10.22495/cbsrv3i2art10
# https://doi.org/10.1075/silv.27.11bla
# https://doi.org/10.1038/s41598-021-81716-4
# https://doi.org/10.1111/icad.12578
# https://doi.org/10.1007/s10531-022-02469-8
# https://doi.org/10.5194/essd-10-951-2018
# https://doi.org/10.1002/esp.4005
# https://doi.org/10.1016/j.ecolind.2022.108610
# https://doi.org/10.1007/s10661-022-10118-4
# https://doi.org/10.1007/s10584-018-2145-y
# https://doi.org/10.5194/hess-24-561-2020
# https://doi.org/10.5194/gmd-12-2285-2019
# https://doi.org/10.1016/j.ejrh.2021.100967
# https://doi.org/10.3390/atmos12111533
# https://doi.org/10.1088/1748-9326/ac7a4e
# https://doi.org/10.1007/s10584-022-03405-z
# https://doi.org/10.3390/rs14153823
# https://doi.org/10.31796/ogummf.933440
# https://doi.org/10.46498/reduipb.v25i3.1511
# https://doi.org/10.4018/ijgbl.294011
# https://doi.org/10.1007/978-981-16-7582-9_4
# https://doi.org/10.3145/epi.2022.ene.09
# https://doi.org/10.18778/0208-600x.78.05
# https://doi.org/10.1080/09535314.2022.2045258
# https://doi.org/10.20525/ijrbs.v10i3.1124
# https://doi.org/10.3846/tede.2021.14513
# https://doi.org/10.37989/gumussagbil.1097639
# https://doi.org/10.17976/jpps/2021.01.11
# https://doi.org/10.1177/09720634221109307
# https://doi.org/10.1186/s12894-018-0364-1
# https://doi.org/10.54167/tch.v13i2.522
# https://doi.org/10.11144/javeriana.m12-24.rcdp
# https://doi.org/10.18037/ausbd.1181513
# https://doi.org/10.15381/rpb.v29i4.22935
# https://doi.org/10.18092/ulikidince.1144391
# https://doi.org/10.20473/jkl.v12i1si.2020.104-120
# https://doi.org/10.5194/hess-23-4011-2019
# https://doi.org/10.5194/hess-21-1189-2017
# https://doi.org/10.1061/(asce)he.1943-5584.0001892
# https://doi.org/10.2478/jlecol-2018-0015
# https://doi.org/10.1111/ele.13157
# https://doi.org/10.5194/essd-13-4155-2021
# https://doi.org/10.5194/gmd-12-1909-2019
# https://doi.org/10.1007/s11368-018-1990-7
# https://doi.org/10.1007/s10980-021-01321-8
# https://doi.org/10.1029/2019wr025583
# https://doi.org/10.1016/j.agee.2021.107755
# https://doi.org/10.1038/s42003-020-01562-4
# https://doi.org/10.1016/j.ecolind.2021.108463
# https://doi.org/10.1101/605105
# https://doi.org/10.3389/fevo.2022.787345
# https://doi.org/10.3390/land11030399
# https://doi.org/10.1007/s00267-022-01648-1
# https://doi.org/10.1016/j.ecoser.2020.101065
# https://doi.org/10.21203/rs.3.rs-2152244/v1
# https://doi.org/10.1101/2021.06.04.447042
# https://doi.org/10.1016/j.ttbdis.2022.102103
# https://doi.org/10.5194/gmd-15-1913-2022
# https://doi.org/10.1007/s40745-015-0067-3
# https://doi.org/10.5194/hess-21-1189-2017
# https://doi.org/10.5194/hess-24-561-2020
# https://doi.org/10.5194/gmd-12-2285-2019
# https://doi.org/10.1016/j.jhydrol.2021.126667
# https://doi.org/10.1061/(asce)he.1943-5584.0001892
# https://doi.org/10.5194/essd-10-951-2018
# https://doi.org/10.5194/hess-23-4583-2019
# https://doi.org/10.33326/26644649.2021.5.2.1191
# https://doi.org/10.5209/rced.73717
# https://doi.org/10.29038/eejpl.2021.8.2.pen
# https://doi.org/10.35622/j.rg.2022.02.002
# https://doi.org/10.33364/konstruksi/v.19-1.944
# https://doi.org/10.35669/rcys.2020.10(1).43-66
# https://doi.org/10.19053/20278306.v7.n1.2016.5635
# https://doi.org/10.31466/kfbd.947353
# https://doi.org/10.21930/rcta.vol22_num2_art:1632
# https://doi.org/10.1145/2872518.2890459
# https://doi.org/10.1007/978-981-19-4226-6_5
# https://doi.org/10.21511/dm.18(1).2020.04
# https://doi.org/10.20473/jkl.v12i1si.2020.104-120
# https://doi.org/10.31289/jab.v8i2.7577
# https://doi.org/10.4236/aasoci.2022.1211052
# https://doi.org/10.24146/tk.1108780
# https://doi.org/10.17533/udea.acbi/v43n115a04
# https://doi.org/10.20990/kilisiibfakademik.1077482
# https://doi.org/10.3390/su132313030
# https://doi.org/10.1038/s41598-022-05476-5
# https://doi.org/10.1002/2017jg003952
# https://doi.org/10.5194/bg-16-1641-2019
# https://doi.org/10.1038/s41598-021-81716-4
# https://doi.org/10.1038/s43247-021-00334-0
# https://doi.org/10.1007/s12061-021-09397-0
# https://doi.org/10.1016/j.ecolind.2022.108719
# https://doi.org/10.5194/gmd-15-1913-2022
# https://doi.org/10.1088/1748-9326/ac810e
# https://doi.org/10.1098/rsta.2021.0292
# https://doi.org/10.1029/2022ef002905
# https://doi.org/10.53047/josse.998220
# https://doi.org/10.51637/jimuseumed.958918
# https://doi.org/10.17645/mac.v9i4.4173
# https://doi.org/10.1145/3449148
# https://doi.org/10.17645/up.v6i4.4630
# https://doi.org/10.38122/ased.52.1
# https://doi.org/10.37016/mr-2020-91
# https://doi.org/10.30692/sisad.1020020
# https://doi.org/10.1145/3485447.3512271
# https://doi.org/10.1145/3491102.3517441
# https://doi.org/10.35290/rcui.v9n2.2022.550
# https://doi.org/10.15446/mag.v36n1.100870
# https://doi.org/10.1145/3461702.3462600
# https://doi.org/10.1144/sp513-2020-258
# https://doi.org/10.36799/el.v7i2.121
# https://doi.org/10.18009/jcer.1175412
# https://doi.org/10.56554/jtom.1101762
# https://doi.org/10.23887/jiku.v10i1.43287
# https://doi.org/10.1007/s11269-018-1914-8
# https://doi.org/10.1007/s10750-015-2181-9
# https://doi.org/10.1061/(asce)wr.1943-5452.0000660
# https://doi.org/10.1038/s43247-021-00334-0
# https://doi.org/10.1002/hyp.14823
# https://doi.org/10.23947/2334-8496-2020-8-3-47-59
# https://doi.org/10.1016/j.childyouth.2021.106332
# https://doi.org/10.1144/m55-2018-68
# https://doi.org/10.14422/ee.v97.i381-382.y2022.008
# https://doi.org/10.14422/ee.v97.i381-382.y2022.013
# https://doi.org/10.21892/01239813.491
# https://doi.org/10.47023/ea.bilim.5230
# https://doi.org/10.4236/ojbm.2022.105141
# https://doi.org/10.5194/hess-21-1189-2017
# https://doi.org/10.5194/hess-22-611-2018
# https://doi.org/10.5194/hess-23-4011-2019
# https://doi.org/10.1016/j.agee.2021.107755
# https://doi.org/10.5194/hess-22-611-2018
# https://doi.org/10.1007/s00799-016-0175-5
# https://doi.org/10.5194/hess-22-5387-2018
# https://doi.org/10.1002/2017jg004312
# Done!

# %%
# add a step to remove results not from an approved list of publishers/journals?

# how to make a list of approved publishers?

# %%
crossRef_df_gbif_filtered2_deduplicated
# Out:
#     relation_type_id source_id  \
# 0         references  crossref
# 1         references  crossref
# 2         references  crossref
# 3         references  crossref
# 4         references  crossref
# ..               ...       ...
# 411       references  crossref
# 448       is-part-of  crossref
# 465       references  crossref
# 466       is-part-of  crossref
# 478       references  crossref
#
#                                                 obj_id  \
# 0    https://doi.org/10.5285/507A5E1F-E056-454C-8FF...
# 1    https://doi.org/10.5285/507A5E1F-E056-454C-8FF...
# 2    https://doi.org/10.5285/507A5E1F-E056-454C-8FF...
# 3    https://doi.org/10.5285/507A5E1F-E056-454C-8FF...
# 4    https://doi.org/10.5285/507A5E1F-E056-454C-8FF...
# ..                                                 ...
# 411  https://doi.org/10.5285/d7da6cb9-104b-4dbc-b70...
# 448  https://doi.org/10.5285/f2856ee8-da6e-4b67-bed...
# 465  https://doi.org/10.5285/f3723162-4fed-4d9d-92c...
# 466  https://doi.org/10.5285/f3723162-4fed-4d9d-92c...
# 478  https://doi.org/10.5285/fd7ca5ef-460a-463c-ad2...
#
#                                           subj_id subj_work_type_id  \
# 0    https://doi.org/10.29110/soylemdergi.1169829   journal-article
# 1      https://doi.org/10.1186/s12888-022-04460-7   journal-article
# 2            https://doi.org/10.34234/ded.1166387   journal-article
# 3          https://doi.org/10.46652/rgn.v6i27.766   journal-article
# 4    https://doi.org/10.1007/978-3-030-78280-1_11      book-chapter
# ..                                            ...               ...
# 411    https://doi.org/10.1016/j.agee.2021.107755   journal-article
# 448      https://doi.org/10.5194/hess-22-611-2018   journal-article
# 465     https://doi.org/10.1007/s00799-016-0175-5    Info not given
# 466     https://doi.org/10.5194/hess-22-5387-2018   journal-article
# 478          https://doi.org/10.1002/2017jg004312   journal-article
#
#                                          dataset_Title  \
# 0    Water chemistry, hydrology and fluvial carbon ...
# 1    Water chemistry, hydrology and fluvial carbon ...
# 2    Water chemistry, hydrology and fluvial carbon ...
# 3    Water chemistry, hydrology and fluvial carbon ...
# 4    Water chemistry, hydrology and fluvial carbon ...
# ..                                                 ...
# 411  Woody linear features framework, Great Britain...
# 448  Gridded estimates of daily and monthly areal r...
# 465                        Future flows hydrology data
# 466                        Future flows hydrology data
# 478  UK Environmental Change Network (ECN) stream w...
#
#                                        dataset_authors dataset_date  \
# 0                       [Vihermaa, L. E., Waldron, S.]   2015-06-01
# 1                       [Vihermaa, L. E., Waldron, S.]   2015-06-01
# 2                       [Vihermaa, L. E., Waldron, S.]   2015-06-01
# 3                       [Vihermaa, L. E., Waldron, S.]   2015-06-01
# 4                       [Vihermaa, L. E., Waldron, S.]   2015-06-01
# ..                                                 ...          ...
# 411  [Scholefield, P.A., Morton, R.D., Rowland, C.S...   2016-11-08
# 448  [Tanguy, M., Dixon, H., Prosdocimi, I., Morris...   2015-09-25
# 465  [Haxton, T., Crooks, S., Jackson, C.R., Barkwi...   2012-04-01
# 466  [Haxton, T., Crooks, S., Jackson, C.R., Barkwi...   2012-04-01
# 478  [Rennie, S., Adamson, J., Anderson, R., Andrew...   2017-12-07
#
#     dataset_date_Type                           related_identifiers_list  \
# 0           Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 1           Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 2           Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 3           Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 4           Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# ..                ...                                                ...
# 411         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 448         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 465         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 466         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
# 478         Submitted  [{'relationType': 'IsDescribedBy', 'relatedIde...
#
#      DataCite_Citation_count  \
# 0                         22
# 1                         22
# 2                         22
# 3                         22
# 4                         22
# ..                       ...
# 411                        3
# 448                        5
# 465                        6
# 466                        6
# 478                        4
#
#                                DataCite_Citations_list  \
# 0    [{'id': '10.18778/0208-600x.78.05', 'type': 'd...
# 1    [{'id': '10.18778/0208-600x.78.05', 'type': 'd...
# 2    [{'id': '10.18778/0208-600x.78.05', 'type': 'd...
# 3    [{'id': '10.18778/0208-600x.78.05', 'type': 'd...
# 4    [{'id': '10.18778/0208-600x.78.05', 'type': 'd...
# ..                                                 ...
# 411  [{'id': '10.1111/1365-2664.13412', 'type': 'do...
# 448  [{'id': '10.5194/hess-22-611-2018', 'type': 'd...
# 465  [{'id': '10.5194/hess-22-5387-2018', 'type': '...
# 466  [{'id': '10.5194/hess-22-5387-2018', 'type': '...
# 478  [{'id': '10.1002/2017jg004312', 'type': 'dois'...
#
#                       dataset_publisher_processed  \
# 0    Environmental Information Data Centre (EIDC)
# 1    Environmental Information Data Centre (EIDC)
# 2    Environmental Information Data Centre (EIDC)
# 3    Environmental Information Data Centre (EIDC)
# 4    Environmental Information Data Centre (EIDC)
# ..                                            ...
# 411  Environmental Information Data Centre (EIDC)
# 448  Environmental Information Data Centre (EIDC)
# 465  Environmental Information Data Centre (EIDC)
# 466  Environmental Information Data Centre (EIDC)
# 478  Environmental Information Data Centre (EIDC)
#
#                                              pub_Title  \
# 0    Katılımcı İnternet Sözlüklerinde Tahsin Yücel:...
# 1    Work-related stress and associated factors amo...
# 2    Sınıf Öğretmeni Adaylarına Göre Geleneksel Çoc...
# 3    Gamificación: Reflexiones teóricas desde el en...
# 4    Humour and Politics: A Discursive Approach to ...
# ..                                                 ...
# 411  Does agri-environment scheme participation in ...
# 448  A large set of potential past, present and fut...
# 465  Implementation of a workflow for publishing ci...
# 466  Future hot-spots for hydro-hazards in Great Br...
# 478  A Molecular Budget for a Peatland Based Upon<s...
#
#                                            pub_authors  \
# 0                   [[Cansu, AVCI], [Erdoğan, KARTAL]]
# 1    [[Tsegaye Adane, Birhan], [Muche, Ambissa], [T...
# 2    [[Mustafa, EROL], [Mehmet Umut, AKBAKLA], [Nur...
# 3    [[Dayana Sofia, Barros-Pozo], [Ricardo Patrici...
# 4                            [[Maria Aldina, Marques]]
# ..                                                 ...
# 411  [[Mike, Image], [Emma, Gardner], [Yann, Clough...
# 448  [[Benoit P., Guillod], [Richard G., Jones], [S...
# 465  [[Kathryn A., Harrison], [Daniel G., Wright], ...
# 466  [[Lila, Collet], [Shaun, Harrigan], [Christel,...
# 478  [[Catherine S., Moody], [Fred, Worrall], [Gare...
#
#                                              publisher
# 0                              SOYLEM Filoloji Dergisi
# 1              Springer Science and Business Media LLC
# 2                             Degerler Egitimi Dergisi
# 3    Centro de Investigaciones en Ciencias Sociales...
# 4                    Springer International Publishing
# ..                                                 ...
# 411                                        Elsevier BV
# 448                                    Copernicus GmbH
# 465            Springer Science and Business Media LLC
# 466                                    Copernicus GmbH
# 478                   American Geophysical Union (AGU)
#
# [144 rows x 16 columns]

# %% [markdown]
# ### Get the citation string (APA format) of the publication that has cited the dataset

# %%
# TAKES A LONG TIME - can skip this if you don't want this info
citationStrList = [] # create an empty list in which to put the citation strings

for pubDOI in crossRef_df_gbif_filtered2_deduplicated['subj_id']:
    
    r = requests.get((pubDOI), headers={"Accept": "text/x-bibliography", "style": "apa"})
    #print(r.status_code)
    citationStrList.append(r.text) # add the citation strings to the list
    
crossRef_df_gbif_filtered2_deduplicated['PubCitationStr'] = citationStrList # add the citation string list to the Scholex df

# %%
crossRef_df_gbif_filtered2_deduplicated

# %%
# add section comparing counts from crossref, DataCite and scholex
# first build a tool that takes one dataset and compares citation results from each source

# %%
# Output csv file

from datetime import date
today = date.today()

crossRef_df_processed_filename = 'dataset_citation_publication_info_' + start_date + "_to_" + end_date + "_retrieved_" + (today.strftime("%d%m%Y")) + '.csv'
crossRef_df_gbif_filtered2_deduplicated.to_csv(crossRef_df_processed_filename, index = False)
print(crossRef_df_processed_filename)

dataset_filename = 'dataset_citation_counts_' + start_date + "_to_" + end_date + "_retrieved_" + (today.strftime("%d%m%Y")) + '.csv'
dataset_df.to_csv(dataset_filename, index = False)
print(dataset_filename)

# %%
# Output csv file if based on list of DOIs rather than dates

from datetime import date
today = date.today()
doi_list_name = "marika_doi_list_scholix"

crossRef_df_processed_filename = 'dataset_citation_publication_info_' + doi_list_name + "_retrieved_" + (today.strftime("%d%m%Y")) + '.csv'
crossRef_df_gbif_filtered2_deduplicated.to_csv(crossRef_df_processed_filename, index = False)
print(crossRef_df_processed_filename)

dataset_filename = 'dataset_citation_counts_' + doi_list_name + "_retrieved_" + (today.strftime("%d%m%Y")) + '.csv'
dataset_df.to_csv(dataset_filename, index = False)
print(dataset_filename)
# Out:
# dataset_citation_publication_info_marika_doi_list_scholix_retrieved_08032023.csv
# dataset_citation_counts_marika_doi_list_scholix_retrieved_08032023.csv
