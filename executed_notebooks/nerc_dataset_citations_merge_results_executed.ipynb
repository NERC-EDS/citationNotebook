# %%
import pandas as pd
from datetime import date
from citations_fun.mergeCitations import merge_citation_dfs
from citations_fun.getCitationString import get_citation_str
from citations_fun.filterCitations import filterCitations

# load results - datacite, scholex and overton
dataCite_df = pd.read_pickle("Results/intermediate_data/latest_results_dataCite.pkl")
scholex_df = pd.read_pickle("Results/intermediate_data/latest_results_scholex.pkl")
overton_df = pd.read_pickle("Results/intermediate_data/latest_results_overton.pkl")

# %%
# merge all results
df_list = [dataCite_df, scholex_df, overton_df]
nerc_citations_df = merge_citation_dfs(df_list)

# %%
# remove doi.org for 
nerc_citations_df['pub_doi'] = nerc_citations_df['pub_doi'].str.replace(
    'https://doi.org/', '', regex=False
)

# %%
# filtering - keep the results that are filtered out for later checks

# returns list of 2 dataframes, first is the main df, second is everything that has been filtered out
results = filterCitations(nerc_citations_df)
nerc_citations_df_filtered = results[0]
filtered_out_df = results[1]

# write to file for a record
filtered_out_df.to_csv("Results/v3/filtered_out_df.csv", index= False)

# %%
# get citation string - takes about 2 hours
nerc_citations_df = get_citation_str(nerc_citations_df_filtered)
# Out:
# 10.1016/j.scitotenv.2012.05.023
# 200
# An error occurred for 10.1016/j.scitotenv.2012.05.023: 'latin-1' codec can't encode character '\u2013' in position 227: ordinal not in range(256)
# 10.1002/2015gl065750
# 200
# An error occurred for 10.1002/2015gl065750: 'latin-1' codec can't encode character '\u2013' in position 184: ordinal not in range(256)
# 10.17863/cam.20713
# 200
# 10.1111/1365-2656.12728
# 200
# An error occurred for 10.1111/1365-2656.12728: 'latin-1' codec can't encode character '\u2013' in position 227: ordinal not in range(256)
# 10.5194/cp-2017-18
# 200
# 10.1002/2016gl068130
# 200
# An error occurred for 10.1002/2016gl068130: 'latin-1' codec can't encode character '\u2010' in position 91: ordinal not in range(256)
# 10.1029/2007gl032529
# 200
# 10.1029/2009gl040104
# 200
# An error occurred for 10.1029/2009gl040104: 'latin-1' codec can't encode character '\u2010' in position 104: ordinal not in range(256)
# 10.1029/2009jd012263
# 200
# 10.1002/2015gl065750
# 200
# An error occurred for 10.1002/2015gl065750: 'latin-1' codec can't encode character '\u2013' in position 184: ordinal not in range(256)
# 10.3189/172756494794587438
# 200
# An error occurred for 10.3189/172756494794587438: 'latin-1' codec can't encode character '\u2013' in position 242: ordinal not in range(256)
# 10.1029/2007gl032529
# 200
# 10.1029/2009gl040104
# 200
# An error occurred for 10.1029/2009gl040104: 'latin-1' codec can't encode character '\u2010' in position 104: ordinal not in range(256)
# 10.1111/1365-2656.12798
# 200
# An error occurred for 10.1111/1365-2656.12798: 'latin-1' codec can't encode character '\u2019' in position 56: ordinal not in range(256)
# 10.5194/cp-2017-18
# 200
# 10.1029/2018jc013982
# 200
# An error occurred for 10.1029/2018jc013982: 'latin-1' codec can't encode character '\u2010' in position 126: ordinal not in range(256)
# 10.1175/jcli-d-17-0320.1
# 200
# An error occurred for 10.1175/jcli-d-17-0320.1: 'latin-1' codec can't encode character '\u2013' in position 219: ordinal not in range(256)
# 10.1111/ele.13129
# 200
# An error occurred for 10.1111/ele.13129: 'latin-1' codec can't encode character '\u2013' in position 302: ordinal not in range(256)
# 10.1016/j.jenvrad.2017.06.024
# 200
# An error occurred for 10.1016/j.jenvrad.2017.06.024: 'latin-1' codec can't encode character '\u2019' in position 176: ordinal not in range(256)
# 10.1029/2018jc014464
# 200
# An error occurred for 10.1029/2018jc014464: 'latin-1' codec can't encode character '\u2013' in position 272: ordinal not in range(256)
# 10.5285/4859dc19-e8e9-4148-8c50-cb2ab16dc696
# 200
# 10.5285/65abc40d-e256-414b-8b50-a5569556d1be
# 200
# 10.5285/c11bdb27-df44-4b56-8f4c-afc51b6e1e3a
# 200
# An error occurred for 10.5285/c11bdb27-df44-4b56-8f4c-afc51b6e1e3a: 'latin-1' codec can't encode character '\u2019' in position 1: ordinal not in range(256)
# 10.1016/j.cub.2017.04.034
# 200
# 10.5194/essd-9-445-2017
# 200
# An error occurred for 10.5194/essd-9-445-2017: 'latin-1' codec can't encode character '\u2013' in position 166: ordinal not in range(256)
# 10.1111/2041-210x.12779
# 200
# An error occurred for 10.1111/2041-210x.12779: 'latin-1' codec can't encode character '\u2010' in position 109: ordinal not in range(256)
# 10.1080/13658816.2016.1158823
# 200
# An error occurred for 10.1080/13658816.2016.1158823: 'latin-1' codec can't encode character '\u2013' in position 248: ordinal not in range(256)
# 10.5285/902fc4d8-db74-46c9-b7eb-c988f5325903
# 200
# 10.5194/hess-22-2023-2018
# 200
# An error occurred for 10.5194/hess-22-2023-2018: 'latin-1' codec can't encode character '\u2013' in position 175: ordinal not in range(256)
# 10.1111/1365-2656.12489
# 200
# An error occurred for 10.1111/1365-2656.12489: 'latin-1' codec can't encode character '\u2013' in position 222: ordinal not in range(256)
# 10.5285/a87b7897-354c-4435-a1bc-e6053e7569e0
# 200
# 10.5285/0579d4a8-e315-41d7-af43-25fb50c7d3da
# 200
# 10.1016/j.agsy.2019.02.015
# 200
# An error occurred for 10.1016/j.agsy.2019.02.015: 'latin-1' codec can't encode character '\u2013' in position 188: ordinal not in range(256)
# 10.1016/j.jhydrol.2018.07.034
# 200
# An error occurred for 10.1016/j.jhydrol.2018.07.034: 'latin-1' codec can't encode character '\u202f' in position 193: ordinal not in range(256)
# 10.5194/hess-22-2023-2018
# 200
# An error occurred for 10.5194/hess-22-2023-2018: 'latin-1' codec can't encode character '\u2013' in position 175: ordinal not in range(256)
# 10.1016/j.ejrh.2015.05.014
# 200
# An error occurred for 10.1016/j.ejrh.2015.05.014: 'latin-1' codec can't encode character '\u2013' in position 180: ordinal not in range(256)
# 10.5194/hess-22-2023-2018
# 200
# An error occurred for 10.5194/hess-22-2023-2018: 'latin-1' codec can't encode character '\u2013' in position 175: ordinal not in range(256)
# 10.5194/essd-10-951-2018
# 200
# An error occurred for 10.5194/essd-10-951-2018: 'latin-1' codec can't encode character '\u2013' in position 171: ordinal not in range(256)
# 10.1016/j.scitotenv.2018.08.190
# 200
# An error occurred for 10.1016/j.scitotenv.2018.08.190: 'latin-1' codec can't encode character '\u2013' in position 339: ordinal not in range(256)
# 10.1002/hyp.11380
# 200
# An error occurred for 10.1002/hyp.11380: 'latin-1' codec can't encode character '\u2010' in position 118: ordinal not in range(256)
# 10.5194/gmd-12-2285-2019
# 200
# An error occurred for 10.5194/gmd-12-2285-2019: 'latin-1' codec can't encode character '\u2013' in position 232: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1080/1747423x.2018.1537312
# 200
# An error occurred for 10.1080/1747423x.2018.1537312: 'latin-1' codec can't encode character '\u2013' in position 216: ordinal not in range(256)
# 10.1002/joc.5789
# 200
# An error occurred for 10.1002/joc.5789: 'latin-1' codec can't encode character '\u2013' in position 216: ordinal not in range(256)
# 10.1016/j.agsy.2019.02.015
# 200
# An error occurred for 10.1016/j.agsy.2019.02.015: 'latin-1' codec can't encode character '\u2013' in position 188: ordinal not in range(256)
# 10.5194/gmd-12-2285-2019
# 200
# An error occurred for 10.5194/gmd-12-2285-2019: 'latin-1' codec can't encode character '\u2013' in position 232: ordinal not in range(256)
# 10.1016/j.jhydrol.2017.05.018
# 200
# An error occurred for 10.1016/j.jhydrol.2017.05.018: 'latin-1' codec can't encode character '\u2013' in position 106: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1016/j.jhydrol.2017.05.018
# 200
# An error occurred for 10.1016/j.jhydrol.2017.05.018: 'latin-1' codec can't encode character '\u2013' in position 106: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1016/j.jhydrol.2017.05.018
# 200
# An error occurred for 10.1016/j.jhydrol.2017.05.018: 'latin-1' codec can't encode character '\u2013' in position 106: ordinal not in range(256)
# 10.1007/s10584-018-2145-y
# 200
# An error occurred for 10.1007/s10584-018-2145-y: 'latin-1' codec can't encode character '\u2013' in position 189: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1016/j.jhydrol.2017.05.018
# 200
# An error occurred for 10.1016/j.jhydrol.2017.05.018: 'latin-1' codec can't encode character '\u2013' in position 106: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1007/s10584-018-2145-y
# 200
# An error occurred for 10.1007/s10584-018-2145-y: 'latin-1' codec can't encode character '\u2013' in position 189: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1002/gdj3.55
# 200
# An error occurred for 10.1002/gdj3.55: 'latin-1' codec can't encode character '\u2010' in position 66: ordinal not in range(256)
# 10.1111/1365-2656.12594
# 200
# An error occurred for 10.1111/1365-2656.12594: 'latin-1' codec can't encode character '\u2013' in position 239: ordinal not in range(256)
# 10.1016/j.ecolind.2015.11.004
# 200
# An error occurred for 10.1016/j.ecolind.2015.11.004: 'latin-1' codec can't encode character '\u2019' in position 76: ordinal not in range(256)
# 10.1002/2017wr020827
# 200
# An error occurred for 10.1002/2017wr020827: 'latin-1' codec can't encode character '\u2013' in position 130: ordinal not in range(256)
# 10.1002/lno.10512
# 200
# An error occurred for 10.1002/lno.10512: 'latin-1' codec can't encode character '\u2013' in position 164: ordinal not in range(256)
# 10.1111/1365-2656.12489
# 200
# An error occurred for 10.1111/1365-2656.12489: 'latin-1' codec can't encode character '\u2013' in position 222: ordinal not in range(256)
# 10.1111/1365-2656.12519
# 200
# An error occurred for 10.1111/1365-2656.12519: 'latin-1' codec can't encode character '\u2013' in position 276: ordinal not in range(256)
# 10.1007/s00411-013-0493-6
# 200
# An error occurred for 10.1007/s00411-013-0493-6: 'latin-1' codec can't encode character '\u2013' in position 232: ordinal not in range(256)
# 10.1111/1365-2656.12489
# 200
# An error occurred for 10.1111/1365-2656.12489: 'latin-1' codec can't encode character '\u2013' in position 222: ordinal not in range(256)
# 10.5194/essd-10-339-2018
# 200
# An error occurred for 10.5194/essd-10-339-2018: 'latin-1' codec can't encode character '\u2013' in position 231: ordinal not in range(256)
# 10.5194/essd-10-339-2018
# 200
# An error occurred for 10.5194/essd-10-339-2018: 'latin-1' codec can't encode character '\u2013' in position 231: ordinal not in range(256)
# 10.1002/esp.4005
# 200
# An error occurred for 10.1002/esp.4005: 'latin-1' codec can't encode character '\u2013' in position 222: ordinal not in range(256)
# 10.1016/j.jenvrad.2011.12.008
# 200
# An error occurred for 10.1016/j.jenvrad.2011.12.008: 'latin-1' codec can't encode character '\u2013' in position 219: ordinal not in range(256)
# 10.1016/j.jenvrad.2015.08.018
# 200
# An error occurred for 10.1016/j.jenvrad.2015.08.018: 'latin-1' codec can't encode character '\u2013' in position 192: ordinal not in range(256)
# 10.1007/s10750-015-2181-9
# 200
# An error occurred for 10.1007/s10750-015-2181-9: 'latin-1' codec can't encode character '\u2013' in position 214: ordinal not in range(256)
# 10.1038/hdy.2012.52
# 200
# An error occurred for 10.1038/hdy.2012.52: 'latin-1' codec can't encode character '\u2013' in position 267: ordinal not in range(256)
# 10.1021/es303550f
# 200
# An error occurred for 10.1021/es303550f: 'latin-1' codec can't encode character '\u2013' in position 254: ordinal not in range(256)
# 10.1111/ele.13157
# 200
# An error occurred for 10.1111/ele.13157: 'latin-1' codec can't encode character '\u2010' in position 118: ordinal not in range(256)
# 10.1111/2041-210x.12779
# 200
# An error occurred for 10.1111/2041-210x.12779: 'latin-1' codec can't encode character '\u2010' in position 109: ordinal not in range(256)
# 10.1021/es403707q
# 200
# An error occurred for 10.1021/es403707q: 'latin-1' codec can't encode character '\u2013' in position 266: ordinal not in range(256)
# 10.1111/ejss.12350
# 200
# An error occurred for 10.1111/ejss.12350: 'latin-1' codec can't encode character '\u2013' in position 449: ordinal not in range(256)
# 10.1016/j.geoderma.2018.07.019
# 200
# An error occurred for 10.1016/j.geoderma.2018.07.019: 'latin-1' codec can't encode character '\u03b4' in position 129: ordinal not in range(256)
# 10.1002/ece3.2607
# 200
# An error occurred for 10.1002/ece3.2607: 'latin-1' codec can't encode character '\u2013' in position 202: ordinal not in range(256)
# 10.1016/j.geoderma.2015.05.018
# 200
# An error occurred for 10.1016/j.geoderma.2015.05.018: 'latin-1' codec can't encode character '\u2013' in position 100: ordinal not in range(256)
# 10.1017/s0031182016001797
# 200
# An error occurred for 10.1017/s0031182016001797: 'latin-1' codec can't encode character '\u2013' in position 220: ordinal not in range(256)
# 10.1016/j.geoderma.2015.05.018
# 200
# An error occurred for 10.1016/j.geoderma.2015.05.018: 'latin-1' codec can't encode character '\u2013' in position 100: ordinal not in range(256)
# 10.1017/s0031182016001797
# 200
# An error occurred for 10.1017/s0031182016001797: 'latin-1' codec can't encode character '\u2013' in position 220: ordinal not in range(256)
# 10.1016/j.geoderma.2015.05.018
# 200
# An error occurred for 10.1016/j.geoderma.2015.05.018: 'latin-1' codec can't encode character '\u2013' in position 100: ordinal not in range(256)
# 10.5194/hess-21-1189-2017
# 200
# An error occurred for 10.5194/hess-21-1189-2017: 'latin-1' codec can't encode character '\u2013' in position 217: ordinal not in range(256)
# 10.1016/j.scitotenv.2016.12.160
# 200
# An error occurred for 10.1016/j.scitotenv.2016.12.160: 'latin-1' codec can't encode character '\u2013' in position 274: ordinal not in range(256)
# 10.1016/j.ejrh.2015.05.014
# 200
# An error occurred for 10.1016/j.ejrh.2015.05.014: 'latin-1' codec can't encode character '\u2013' in position 180: ordinal not in range(256)
# 10.1142/s2345737615500050
# 200
# 10.1016/j.scitotenv.2016.03.066
# 200
# An error occurred for 10.1016/j.scitotenv.2016.03.066: 'latin-1' codec can't encode character '\u2013' in position 238: ordinal not in range(256)
# 10.1111/2041-210x.12779
# 200
# An error occurred for 10.1111/2041-210x.12779: 'latin-1' codec can't encode character '\u2010' in position 109: ordinal not in range(256)
# 10.1016/j.scitotenv.2018.03.052
# 200
# An error occurred for 10.1016/j.scitotenv.2018.03.052: 'latin-1' codec can't encode character '\u2013' in position 312: ordinal not in range(256)
# 10.1007/s10980-019-00822-x
# 200
# An error occurred for 10.1007/s10980-019-00822-x: 'latin-1' codec can't encode character '\u2013' in position 218: ordinal not in range(256)
# 10.1002/joc.5336
# 200
# An error occurred for 10.1002/joc.5336: 'latin-1' codec can't encode character '\u2013' in position 224: ordinal not in range(256)
# 10.5194/hess-19-2395-2015
# 200
# An error occurred for 10.5194/hess-19-2395-2015: 'latin-1' codec can't encode character '\u2013' in position 217: ordinal not in range(256)
# 10.1016/j.scitotenv.2018.12.108
# 200
# An error occurred for 10.1016/j.scitotenv.2018.12.108: 'latin-1' codec can't encode character '\u2013' in position 307: ordinal not in range(256)
# 10.1088/1748-9326/aac78c
# 200
# 10.5194/essd-8-89-2016
# 200
# An error occurred for 10.5194/essd-8-89-2016: 'latin-1' codec can't encode character '\u2013' in position 102: ordinal not in range(256)
# 10.1016/j.envsoft.2018.07.006
# 200
# An error occurred for 10.1016/j.envsoft.2018.07.006: 'latin-1' codec can't encode character '\u2013' in position 248: ordinal not in range(256)
# 10.5194/gmd-12-765-2019
# 200
# An error occurred for 10.5194/gmd-12-765-2019: 'latin-1' codec can't encode character '\u2013' in position 271: ordinal not in range(256)
# 10.1038/nature21709
# 200
# An error occurred for 10.1038/nature21709: 'latin-1' codec can't encode character '\u2013' in position 228: ordinal not in range(256)
# 10.1890/15-0546
# 200
# An error occurred for 10.1890/15-0546: 'latin-1' codec can't encode character '\u2013' in position 255: ordinal not in range(256)
# 10.1890/15-0546
# 200
# An error occurred for 10.1890/15-0546: 'latin-1' codec can't encode character '\u2013' in position 255: ordinal not in range(256)
# 10.1002/ece3.2607
# 200
# An error occurred for 10.1002/ece3.2607: 'latin-1' codec can't encode character '\u2013' in position 202: ordinal not in range(256)
# 10.3389/fmicb.2014.00720
# 200
# 10.1111/1365-2656.12489
# 200
# An error occurred for 10.1111/1365-2656.12489: 'latin-1' codec can't encode character '\u2013' in position 222: ordinal not in range(256)
# 10.1016/j.jenvrad.2015.03.022
# 200
# An error occurred for 10.1016/j.jenvrad.2015.03.022: 'latin-1' codec can't encode character '\u2013' in position 264: ordinal not in range(256)
# 10.5194/essd-10-1637-2018
# 200
# An error occurred for 10.5194/essd-10-1637-2018: 'latin-1' codec can't encode character '\u2013' in position 152: ordinal not in range(256)
# 10.1111/1365-2664.12519
# 200
# An error occurred for 10.1111/1365-2664.12519: 'latin-1' codec can't encode character '\u2010' in position 129: ordinal not in range(256)
# 10.1111/1365-2664.12519
# 200
# An error occurred for 10.1111/1365-2664.12519: 'latin-1' codec can't encode character '\u2010' in position 129: ordinal not in range(256)
# 10.1111/1365-2664.12519
# 200
# An error occurred for 10.1111/1365-2664.12519: 'latin-1' codec can't encode character '\u2010' in position 129: ordinal not in range(256)
# 10.5194/essdd-8-827-2015
# 200
# An error occurred for 10.5194/essdd-8-827-2015: 'latin-1' codec can't encode character '\u2013' in position 102: ordinal not in range(256)
# 10.1111/1365-2664.12519
# 200
# An error occurred for 10.1111/1365-2664.12519: 'latin-1' codec can't encode character '\u2010' in position 129: ordinal not in range(256)
# 10.1371/journal.pone.0129892
# 200
# 10.1016/j.jenvrad.2013.05.007
# 200
# An error occurred for 10.1016/j.jenvrad.2013.05.007: 'latin-1' codec can't encode character '\u2013' in position 215: ordinal not in range(256)
# 10.1016/j.jenvrad.2012.01.027
# 200
# An error occurred for 10.1016/j.jenvrad.2012.01.027: 'latin-1' codec can't encode character '\u2013' in position 164: ordinal not in range(256)
# 10.1016/j.jenvrad.2015.12.006
# 200
# An error occurred for 10.1016/j.jenvrad.2015.12.006: 'latin-1' codec can't encode character '\u2013' in position 231: ordinal not in range(256)
# 10.1016/j.jenvrad.2015.08.018
# 200
# An error occurred for 10.1016/j.jenvrad.2015.08.018: 'latin-1' codec can't encode character '\u2013' in position 192: ordinal not in range(256)
# 10.1016/j.scitotenv.2017.11.005
# 200
# An error occurred for 10.1016/j.scitotenv.2017.11.005: 'latin-1' codec can't encode character '\u2013' in position 256: ordinal not in range(256)
# 10.1016/j.jenvrad.2018.11.011
# 200
# An error occurred for 10.1016/j.jenvrad.2018.11.011: 'latin-1' codec can't encode character '\u2013' in position 279: ordinal not in range(256)
# 10.1016/j.geoderma.2017.08.011
# 200
# An error occurred for 10.1016/j.geoderma.2017.08.011: 'latin-1' codec can't encode character '\u2013' in position 205: ordinal not in range(256)
# 10.1080/13658816.2016.1158823
# 200
# An error occurred for 10.1080/13658816.2016.1158823: 'latin-1' codec can't encode character '\u2013' in position 248: ordinal not in range(256)
# 10.1080/13658816.2016.1158823
# 200
# An error occurred for 10.1080/13658816.2016.1158823: 'latin-1' codec can't encode character '\u2013' in position 248: ordinal not in range(256)
# 10.5194/essdd-8-827-2015
# 200
# An error occurred for 10.5194/essdd-8-827-2015: 'latin-1' codec can't encode character '\u2013' in position 102: ordinal not in range(256)
# 10.1007/s00484-018-1509-3
# 200
# An error occurred for 10.1007/s00484-018-1509-3: 'latin-1' codec can't encode character '\u2013' in position 261: ordinal not in range(256)
# 10.1088/1748-9326/aac78c
# 200
# 10.1016/j.agsy.2019.02.015
# 200
# An error occurred for 10.1016/j.agsy.2019.02.015: 'latin-1' codec can't encode character '\u2013' in position 188: ordinal not in range(256)
# 10.5194/hess-22-611-2018
# 200
# An error occurred for 10.5194/hess-22-611-2018: 'latin-1' codec can't encode character '\u2013' in position 194: ordinal not in range(256)
# 10.1002/joc.5721
# 200
# An error occurred for 10.1002/joc.5721: 'latin-1' codec can't encode character '\u2010' in position 137: ordinal not in range(256)
# 10.1080/20423489.2017.1344043
# 200
# An error occurred for 10.1080/20423489.2017.1344043: 'latin-1' codec can't encode character '\u2013' in position 110: ordinal not in range(256)
# 10.1016/j.jhydrol.2018.07.009
# 200
# An error occurred for 10.1016/j.jhydrol.2018.07.009: 'latin-1' codec can't encode character '\u2013' in position 135: ordinal not in range(256)
# 10.5194/hess-21-1189-2017
# 200
# An error occurred for 10.5194/hess-21-1189-2017: 'latin-1' codec can't encode character '\u2013' in position 217: ordinal not in range(256)
# 10.5194/hess-21-1189-2017
# 200
# An error occurred for 10.5194/hess-21-1189-2017: 'latin-1' codec can't encode character '\u2013' in position 217: ordinal not in range(256)
# 10.5194/hess-22-611-2018
# 200
# An error occurred for 10.5194/hess-22-611-2018: 'latin-1' codec can't encode character '\u2013' in position 194: ordinal not in range(256)
# 10.1111/2041-210x.12779
# 200
# An error occurred for 10.1111/2041-210x.12779: 'latin-1' codec can't encode character '\u2010' in position 109: ordinal not in range(256)
# 10.1111/2041-210x.12779
# 200
# An error occurred for 10.1111/2041-210x.12779: 'latin-1' codec can't encode character '\u2010' in position 109: ordinal not in range(256)
# 10.1139/cjz-2017-0090
# 200
# An error occurred for 10.1139/cjz-2017-0090: 'latin-1' codec can't encode character '\u2013' in position 213: ordinal not in range(256)
# 10.5194/essd-10-745-2018
# 200
# An error occurred for 10.5194/essd-10-745-2018: 'latin-1' codec can't encode character '\u2013' in position 152: ordinal not in range(256)
# 10.1016/j.jag.2018.06.003
# 200
# An error occurred for 10.1016/j.jag.2018.06.003: 'latin-1' codec can't encode character '\u2013' in position 132: ordinal not in range(256)
# 10.1016/j.jenvrad.2019.106020
# 200
# An error occurred for 10.1016/j.jenvrad.2019.106020: 'latin-1' codec can't encode character '\u2013' in position 165: ordinal not in range(256)
# 10.5285/1467b446-54eb-45c1-8a31-f4af21e60e60
# 200
# 10.5285/1467b446-54eb-45c1-8a31-f4af21e60e60
# 200
# 10.1016/j.scitotenv.2016.03.066
# 200
# An error occurred for 10.1016/j.scitotenv.2016.03.066: 'latin-1' codec can't encode character '\u2013' in position 238: ordinal not in range(256)
# 10.5194/acp-16-13773-2016
# 200
# An error occurred for 10.5194/acp-16-13773-2016: 'latin-1' codec can't encode character '\u2013' in position 228: ordinal not in range(256)
# 10.1016/j.compenvurbsys.2017.07.003
# 200
# An error occurred for 10.1016/j.compenvurbsys.2017.07.003: 'latin-1' codec can't encode character '\u2013' in position 181: ordinal not in range(256)
# 10.5194/acp-18-4497-2018
# 200
# An error occurred for 10.5194/acp-18-4497-2018: 'latin-1' codec can't encode character '\u2013' in position 199: ordinal not in range(256)
# 10.1109/access.2019.2896934
# 200
# An error occurred for 10.1109/access.2019.2896934: 'latin-1' codec can't encode character '\u2013' in position 135: ordinal not in range(256)
# 10.1016/j.landurbplan.2019.01.008
# 200
# An error occurred for 10.1016/j.landurbplan.2019.01.008: 'latin-1' codec can't encode character '\u2013' in position 198: ordinal not in range(256)
# 10.1111/1365-2664.13146
# 200
# An error occurred for 10.1111/1365-2664.13146: 'latin-1' codec can't encode character '\u2010' in position 94: ordinal not in range(256)
# 10.1038/srep36051
# 200
# An error occurred for 10.1038/srep36051: 'latin-1' codec can't encode character '\u2019' in position 52: ordinal not in range(256)
# 10.1371/journal.pone.0155241
# 200
# 10.1111/1365-2664.12718
# 200
# An error occurred for 10.1111/1365-2664.12718: 'latin-1' codec can't encode character '\u2013' in position 226: ordinal not in range(256)
# 10.1088/1748-9326/aaafda
# 200
# 10.5194/bg-2016-238
# 200
# 10.1088/1748-9326/aaafda
# 200
# 10.1038/nature21709
# 200
# An error occurred for 10.1038/nature21709: 'latin-1' codec can't encode character '\u2013' in position 228: ordinal not in range(256)
# 10.1111/1365-2664.13412
# 200
# An error occurred for 10.1111/1365-2664.13412: 'latin-1' codec can't encode character '\u2010' in position 180: ordinal not in range(256)
# 10.1016/j.scitotenv.2019.01.073
# 200
# An error occurred for 10.1016/j.scitotenv.2019.01.073: 'latin-1' codec can't encode character '\u202f' in position 145: ordinal not in range(256)
# 10.1111/1365-2435.12823
# 200
# An error occurred for 10.1111/1365-2435.12823: 'latin-1' codec can't encode character '\u2013' in position 148: ordinal not in range(256)
# 10.5194/essd-10-1637-2018
# 200
# An error occurred for 10.5194/essd-10-1637-2018: 'latin-1' codec can't encode character '\u2013' in position 152: ordinal not in range(256)
# 10.1016/j.scitotenv.2018.03.052
# 200
# An error occurred for 10.1016/j.scitotenv.2018.03.052: 'latin-1' codec can't encode character '\u2013' in position 312: ordinal not in range(256)
# 10.1111/icad.12345
# 200
# An error occurred for 10.1111/icad.12345: 'latin-1' codec can't encode character '\u2013' in position 181: ordinal not in range(256)
# 10.1111/jfr3.12464
# 200
# An error occurred for 10.1111/jfr3.12464: 'latin-1' codec can't encode character '\u2010' in position 79: ordinal not in range(256)
# 10.1007/s10980-019-00822-x
# 200
# An error occurred for 10.1007/s10980-019-00822-x: 'latin-1' codec can't encode character '\u2013' in position 218: ordinal not in range(256)
# 10.1016/j.scitotenv.2019.02.228
# 200
# An error occurred for 10.1016/j.scitotenv.2019.02.228: 'latin-1' codec can't encode character '\u2013' in position 230: ordinal not in range(256)
# 10.5194/bg-15-1497-2018
# 200
# An error occurred for 10.5194/bg-15-1497-2018: 'latin-1' codec can't encode character '\u2013' in position 181: ordinal not in range(256)
# 10.1007/s11368-018-1990-7
# 200
# An error occurred for 10.1007/s11368-018-1990-7: 'latin-1' codec can't encode character '\u2013' in position 154: ordinal not in range(256)
# 10.1002/ece3.4087
# 200
# An error occurred for 10.1002/ece3.4087: 'latin-1' codec can't encode character '\u2013' in position 161: ordinal not in range(256)
# 10.5194/acp-2018-513
# 200
# 10.3390/land7010017
# 200
# 10.1016/j.envint.2018.10.005
# 200
# An error occurred for 10.1016/j.envint.2018.10.005: 'latin-1' codec can't encode character '\u0161' in position 12: ordinal not in range(256)
# 10.1016/j.scitotenv.2017.10.263
# 200
# An error occurred for 10.1016/j.scitotenv.2017.10.263: 'latin-1' codec can't encode character '\u2013' in position 250: ordinal not in range(256)
# 10.1111/ecog.04295
# 200
# An error occurred for 10.1111/ecog.04295: 'latin-1' codec can't encode character '\u2013' in position 155: ordinal not in range(256)
# 10.1080/17445647.2019.1600591
# 200
# An error occurred for 10.1080/17445647.2019.1600591: 'latin-1' codec can't encode character '\u2013' in position 218: ordinal not in range(256)
# 10.1101/605105
# 200
# 10.1111/1365-2664.13412
# 200
# An error occurred for 10.1111/1365-2664.13412: 'latin-1' codec can't encode character '\u2010' in position 180: ordinal not in range(256)
# 10.1016/j.catena.2018.11.018
# 200
# An error occurred for 10.1016/j.catena.2018.11.018: 'latin-1' codec can't encode character '\u2013' in position 159: ordinal not in range(256)
# 10.1016/j.agee.2018.10.008
# 200
# An error occurred for 10.1016/j.agee.2018.10.008: 'latin-1' codec can't encode character '\u2013' in position 169: ordinal not in range(256)
# 10.5194/hess-22-2023-2018
# 200
# An error occurred for 10.5194/hess-22-2023-2018: 'latin-1' codec can't encode character '\u2013' in position 175: ordinal not in range(256)
# 10.1088/1748-9326/aac78c
# 200
# 10.1016/j.envint.2018.10.005
# 200
# An error occurred for 10.1016/j.envint.2018.10.005: 'latin-1' codec can't encode character '\u0161' in position 12: ordinal not in range(256)
# 10.1130/g35512.1
# 200
# An error occurred for 10.1130/g35512.1: 'latin-1' codec can't encode character '\u2019' in position 97: ordinal not in range(256)
# 10.1371/journal.pone.0120036
# 200
# 10.1016/j.gr.2015.10.018
# 200
# An error occurred for 10.1016/j.gr.2015.10.018: 'latin-1' codec can't encode character '\u2013' in position 279: ordinal not in range(256)
# 10.1111/1365-2664.13146
# 200
# An error occurred for 10.1111/1365-2664.13146: 'latin-1' codec can't encode character '\u2010' in position 94: ordinal not in range(256)
# 10.1016/j.jenvrad.2015.12.027
# 200
# An error occurred for 10.1016/j.jenvrad.2015.12.027: 'latin-1' codec can't encode character '\u2013' in position 247: ordinal not in range(256)
# 10.1016/j.jenvrad.2008.03.002
# 200
# An error occurred for 10.1016/j.jenvrad.2008.03.002: 'latin-1' codec can't encode character '\u2013' in position 250: ordinal not in range(256)
# 10.5194/gmd-12-765-2019
# 200
# An error occurred for 10.5194/gmd-12-765-2019: 'latin-1' codec can't encode character '\u2013' in position 271: ordinal not in range(256)
# 10.1038/s41559-018-0602-7
# 200
# An error occurred for 10.1038/s41559-018-0602-7: 'latin-1' codec can't encode character '\u2013' in position 144: ordinal not in range(256)
# 10.5194/essd-10-951-2018
# 200
# An error occurred for 10.5194/essd-10-951-2018: 'latin-1' codec can't encode character '\u2013' in position 171: ordinal not in range(256)
# 10.1016/j.scitotenv.2018.08.190
# 200
# An error occurred for 10.1016/j.scitotenv.2018.08.190: 'latin-1' codec can't encode character '\u2013' in position 339: ordinal not in range(256)
# 10.5194/gmd-12-765-2019
# 200
# An error occurred for 10.5194/gmd-12-765-2019: 'latin-1' codec can't encode character '\u2013' in position 271: ordinal not in range(256)
# 10.1038/sdata.2018.239
# 200
# 10.5194/tc-11-2491-2017
# 200
# An error occurred for 10.5194/tc-11-2491-2017: 'latin-1' codec can't encode character '\u2013' in position 188: ordinal not in range(256)
# 10.5285/49f4cbe0-ab31-4aa3-bc2d-cea572ff4e97
# 200
# 10.5194/tc-11-2491-2017
# 200
# An error occurred for 10.5194/tc-11-2491-2017: 'latin-1' codec can't encode character '\u2013' in position 188: ordinal not in range(256)
# 10.5285/c9079345-74a8-42af-8843-2151e6557e0f
# 200
# 10.5285/c26e3873-e33e-45be-b76b-87f3b8827101
# 200
# 10.5285/3bbacca6-d2cd-46be-b824-b828572ca486
# 200
# 10.5194/tc-2018-260
# 200
# 10.5194/tc-6-923-2012
# 200
# An error occurred for 10.5194/tc-6-923-2012: 'latin-1' codec can't encode character '\u2013' in position 194: ordinal not in range(256)
# 10.5285/61100705-dfbc-489d-b729-1268ec743bbf
# 200
# 10.5285/b317f707-2ef6-449c-acc3-6bb087efecb1
# 200
# 10.5285/3bbacca6-d2cd-46be-b824-b828572ca486
# 200
# 10.5194/tc-2018-260
# 200
# 10.5194/tc-6-923-2012
# 200
# An error occurred for 10.5194/tc-6-923-2012: 'latin-1' codec can't encode character '\u2013' in position 194: ordinal not in range(256)
# 10.5285/61100705-dfbc-489d-b729-1268ec743bbf
# 200
# 10.5285/b317f707-2ef6-449c-acc3-6bb087efecb1
# 200
# 10.5285/c26e3873-e33e-45be-b76b-87f3b8827101
# 200
# 10.5194/tc-2018-260
# 200
# 10.5285/61100705-dfbc-489d-b729-1268ec743bbf
# 200
# 10.5194/tc-2018-260
# 200
# 10.5285/b317f707-2ef6-449c-acc3-6bb087efecb1
# 200
# 10.5285/c26e3873-e33e-45be-b76b-87f3b8827101
# 200
# 10.5285/3bbacca6-d2cd-46be-b824-b828572ca486
# 200
# 10.1073/pnas.1801769115
# 200
# An error occurred for 10.1073/pnas.1801769115: 'latin-1' codec can't encode character '\u2019' in position 114: ordinal not in range(256)
# 10.5285/a7f28dea-64f7-43b5-bc39-a6cfcdeefbda
# 200
# 10.5285/6be7d300-b42c-42f4-af59-2138e2a4dfe4
# 200
# 10.5285/1846aa2c-7617-4daf-9928-60a336e256a6
# 200
# 10.5285/65140444-b5fa-4a5e-9ab4-e86c106051e2
# 200
# 10.5285/6e35ef4b-35fa-4a0d-a3f5-b86c820bc4c4
# 200
# 10.5285/a7f28dea-64f7-43b5-bc39-a6cfcdeefbda
# 200
# 10.5285/65140444-b5fa-4a5e-9ab4-e86c106051e2
# 200
# 10.5285/65140444-b5fa-4a5e-9ab4-e86c106051e2
# 200
# 10.5285/6be7d300-b42c-42f4-af59-2138e2a4dfe4
# 200
# 10.5285/a7f28dea-64f7-43b5-bc39-a6cfcdeefbda
# 200
# 10.5285/a7f28dea-64f7-43b5-bc39-a6cfcdeefbda
# 200
# 10.5285/d80f5c86-89a7-46d6-8718-47e3d34ab368
# 200
# 10.5285/1846aa2c-7617-4daf-9928-60a336e256a6
# 200
# 10.1038/s41598-018-34327-5
# 200
# 10.5285/6e35ef4b-35fa-4a0d-a3f5-b86c820bc4c4
# 200
# 10.5285/1846aa2c-7617-4daf-9928-60a336e256a6
# 200
# 10.5285/6be7d300-b42c-42f4-af59-2138e2a4dfe4
# 200
# 10.3189/002214308787779988
# 200
# An error occurred for 10.3189/002214308787779988: 'latin-1' codec can't encode character '\u2013' in position 136: ordinal not in range(256)
# 10.5285/6e35ef4b-35fa-4a0d-a3f5-b86c820bc4c4
# 200
# 10.5285/6e35ef4b-35fa-4a0d-a3f5-b86c820bc4c4
# 200
# 10.5285/d80f5c86-89a7-46d6-8718-47e3d34ab368
# 200
# 10.5285/d80f5c86-89a7-46d6-8718-47e3d34ab368
# 200
# 10.1002/2017jf004529
# 200
# An error occurred for 10.1002/2017jf004529: 'latin-1' codec can't encode character '\u2013' in position 300: ordinal not in range(256)
# 10.1038/s41598-018-34327-5
# 200
# 10.1002/2017jf004529
# 200
# An error occurred for 10.1002/2017jf004529: 'latin-1' codec can't encode character '\u2013' in position 300: ordinal not in range(256)
# 10.5285/65140444-b5fa-4a5e-9ab4-e86c106051e2
# 200
# 10.5285/6be7d300-b42c-42f4-af59-2138e2a4dfe4
# 200
# 10.5285/1846aa2c-7617-4daf-9928-60a336e256a6
# 200
# 10.5285/65140444-b5fa-4a5e-9ab4-e86c106051e2
# 200
# 10.5285/6e35ef4b-35fa-4a0d-a3f5-b86c820bc4c4
# 200
# 10.5285/a7f28dea-64f7-43b5-bc39-a6cfcdeefbda
# 200
# 10.5285/d80f5c86-89a7-46d6-8718-47e3d34ab368
# 200
# 10.1038/s41598-018-34327-5
# 200
# 10.5285/6be7d300-b42c-42f4-af59-2138e2a4dfe4
# 200
# 10.5285/1846aa2c-7617-4daf-9928-60a336e256a6
# 200
# 10.5285/d80f5c86-89a7-46d6-8718-47e3d34ab368
# 200
# 10.1038/s41598-018-34327-5
# 200
# 10.1002/2017jf004529
# 200
# An error occurred for 10.1002/2017jf004529: 'latin-1' codec can't encode character '\u2013' in position 300: ordinal not in range(256)
# 10.1016/j.geomorph.2004.04.007
# 200
# An error occurred for 10.1016/j.geomorph.2004.04.007: 'latin-1' codec can't encode character '\u2013' in position 115: ordinal not in range(256)
# 10.1016/j.asr.2017.11.014
# 200
# An error occurred for 10.1016/j.asr.2017.11.014: 'latin-1' codec can't encode character '\u2013' in position 265: ordinal not in range(256)
# 10.1002/2017gl074929
# 200
# An error occurred for 10.1002/2017gl074929: 'latin-1' codec can't encode character '\u2013' in position 173: ordinal not in range(256)
# 10.1029/2018gl080383
# 200
# An error occurred for 10.1029/2018gl080383: 'latin-1' codec can't encode character '\u2013' in position 161: ordinal not in range(256)
# 10.5194/tc-12-2461-2018
# 200
# An error occurred for 10.5194/tc-12-2461-2018: 'latin-1' codec can't encode character '\u2019' in position 159: ordinal not in range(256)
# 10.5194/tc-11-451-2017
# 200
# An error occurred for 10.5194/tc-11-451-2017: 'latin-1' codec can't encode character '\u2013' in position 158: ordinal not in range(256)
# 10.1002/2016gl068972
# 200
# An error occurred for 10.1002/2016gl068972: 'latin-1' codec can't encode character '\u2010' in position 83: ordinal not in range(256)
# 10.1098/rstb.2003.1405
# 200
# An error occurred for 10.1098/rstb.2003.1405: 'latin-1' codec can't encode character '\u2013' in position 142: ordinal not in range(256)
# 10.1098/rspb.2004.3049
# 200
# An error occurred for 10.1098/rspb.2004.3049: 'latin-1' codec can't encode character '\u2013' in position 271: ordinal not in range(256)
# 10.1098/rstb.2003.1405
# 200
# An error occurred for 10.1098/rstb.2003.1405: 'latin-1' codec can't encode character '\u2013' in position 142: ordinal not in range(256)
# 10.1098/rstb.2003.1405
# 200
# An error occurred for 10.1098/rstb.2003.1405: 'latin-1' codec can't encode character '\u2013' in position 142: ordinal not in range(256)
# 10.5285/ba29d42b-ebee-4da8-9861-f46277e14b5d
# 200
# 10.5285/b5ffac8a-9846-4f86-9a71-3ce992a18148
# 200
# An error occurred for 10.5285/b5ffac8a-9846-4f86-9a71-3ce992a18148: 'latin-1' codec can't encode character '\u2019' in position 1: ordinal not in range(256)
# 10.1111/1365-2656.12489
# 200
# An error occurred for 10.1111/1365-2656.12489: 'latin-1' codec can't encode character '\u2013' in position 222: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5285/51e6c931-0cec-48aa-aa37-a60f92f8a12f
# 200
# 10.5285/90d09062-2f50-4742-b4da-41b92d88fbe6
# 200
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.5194/essd-2019-74
# 200
# An error occurred for 10.5194/essd-2019-74: 'latin-1' codec can't encode character '\u2013' in position 98: ordinal not in range(256)
# 10.1073/pnas.1904087116
# 200
# An error occurred for 10.1073/pnas.1904087116: 'latin-1' codec can't encode character '\u2013' in position 213: ordinal not in range(256)
# 10.1016/j.landusepol.2017.09.018
# 200
# An error occurred for 10.1016/j.landusepol.2017.09.018: 'latin-1' codec can't encode character '\u2013' in position 143: ordinal not in range(256)
# 10.1007/s00799-016-0175-5
# 200
# An error occurred for 10.1007/s00799-016-0175-5: 'latin-1' codec can't encode character '\u2013' in position 246: ordinal not in range(256)
# 10.1016/j.landusepol.2017.09.018
# 200
# An error occurred for 10.1016/j.landusepol.2017.09.018: 'latin-1' codec can't encode character '\u2013' in position 143: ordinal not in range(256)
# 10.5194/hess-23-3233-2019
# 200
# An error occurred for 10.5194/hess-23-3233-2019: 'latin-1' codec can't encode character '\u2013' in position 213: ordinal not in range(256)
# 10.1029/2018wr024464
# 200
# An error occurred for 10.1029/2018wr024464: 'latin-1' codec can't encode character '\u2013' in position 116: ordinal not in range(256)
# 10.5194/hess-23-3233-2019
# 200
# An error occurred for 10.5194/hess-23-3233-2019: 'latin-1' codec can't encode character '\u2013' in position 213: ordinal not in range(256)
# 10.1029/2018wr024464
# 200
# An error occurred for 10.1029/2018wr024464: 'latin-1' codec can't encode character '\u2013' in position 116: ordinal not in range(256)
# 10.1111/1365-2664.13402
# 200
# An error occurred for 10.1111/1365-2664.13402: 'latin-1' codec can't encode character '\u2013' in position 230: ordinal not in range(256)
# 10.1002/eco.2123
# 200
# 10.1016/j.advwatres.2019.05.019
# 200
# An error occurred for 10.1016/j.advwatres.2019.05.019: 'latin-1' codec can't encode character '\u2013' in position 229: ordinal not in range(256)
# 10.5194/bg-16-1641-2019
# 200
# An error occurred for 10.5194/bg-16-1641-2019: 'latin-1' codec can't encode character '\u2013' in position 204: ordinal not in range(256)
# 10.1016/j.scitotenv.2019.06.052
# 200
# An error occurred for 10.1016/j.scitotenv.2019.06.052: 'latin-1' codec can't encode character '\u2013' in position 280: ordinal not in range(256)
# 10.1080/21606544.2019.1611481
# 200
# An error occurred for 10.1080/21606544.2019.1611481: 'latin-1' codec can't encode character '\u2013' in position 171: ordinal not in range(256)
# 10.1002/ece3.5424
# 200
# An error occurred for 10.1002/ece3.5424: 'latin-1' codec can't encode character '\u2010' in position 136: ordinal not in range(256)
# 10.1002/ece3.5424
# 200
# An error occurred for 10.1002/ece3.5424: 'latin-1' codec can't encode character '\u2010' in position 136: ordinal not in range(256)
# 10.1002/ece3.5376
# 200
# An error occurred for 10.1002/ece3.5376: 'latin-1' codec can't encode character '\u2013' in position 187: ordinal not in range(256)
# 10.1016/j.agsy.2019.02.015
# 200
# An error occurred for 10.1016/j.agsy.2019.02.015: 'latin-1' codec can't encode character '\u2013' in position 188: ordinal not in range(256)
# 10.1002/ece3.5376
# 200
# An error occurred for 10.1002/ece3.5376: 'latin-1' codec can't encode character '\u2013' in position 187: ordinal not in range(256)
# 10.1002/lom3.10281
# 200
# An error occurred for 10.1002/lom3.10281: 'latin-1' codec can't encode character '\u2013' in position 205: ordinal not in range(256)
# 10.1098/rspb.2019.0795
# 200
# 10.1111/fwb.13370
# 200
# An error occurred for 10.1111/fwb.13370: 'latin-1' codec can't encode character '\u2010' in position 157: ordinal not in range(256)
# 10.1111/fwb.13370
# 200
# An error occurred for 10.1111/fwb.13370: 'latin-1' codec can't encode character '\u2010' in position 157: ordinal not in range(256)
# 10.1080/10548408.2019.1575787
# 200
# An error occurred for 10.1080/10548408.2019.1575787: 'latin-1' codec can't encode character '\u010d' in position 47: ordinal not in range(256)
# 10.1002/ece3.5376
# 200
# An error occurred for 10.1002/ece3.5376: 'latin-1' codec can't encode character '\u2013' in position 187: ordinal not in range(256)
# 10.1016/j.jenvrad.2017.06.024
# 200
# An error occurred for 10.1016/j.jenvrad.2017.06.024: 'latin-1' codec can't encode character '\u2019' in position 176: ordinal not in range(256)
# 10.1007/s00799-016-0175-5
# 200
# An error occurred for 10.1007/s00799-016-0175-5: 'latin-1' codec can't encode character '\u2013' in position 246: ordinal not in range(256)
# 10.1007/s00799-016-0175-5
# 200
# An error occurred for 10.1007/s00799-016-0175-5: 'latin-1' codec can't encode character '\u2013' in position 246: ordinal not in range(256)
# 10.1007/s00799-016-0175-5
# 200
# An error occurred for 10.1007/s00799-016-0175-5: 'latin-1' codec can't encode character '\u2013' in position 246: ordinal not in range(256)
# 10.1016/j.chemgeo.2017.06.024
# 200
# An error occurred for 10.1016/j.chemgeo.2017.06.024: 'latin-1' codec can't encode character '\u2013' in position 179: ordinal not in range(256)
# 10.1007/s00799-016-0175-5
# 200
# An error occurred for 10.1007/s00799-016-0175-5: 'latin-1' codec can't encode character '\u2013' in position 246: ordinal not in range(256)
# 10.1007/s00799-016-0175-5
# 200
# An error occurred for 10.1007/s00799-016-0175-5: 'latin-1' codec can't encode character '\u2013' in position 246: ordinal not in range(256)
# 10.1080/21606544.2019.1597772
# 200
# An error occurred for 10.1080/21606544.2019.1597772: 'latin-1' codec can't encode character '\u2013' in position 208: ordinal not in range(256)
# 10.5194/acp-2019-259
# 200
# 10.3390/w11091790
# 200
# 10.3390/w11091790
# 200
# 10.5285/4e94de3b-e156-4f6f-a854-8edeaa4e8302
# 200
# An error occurred for 10.5285/4e94de3b-e156-4f6f-a854-8edeaa4e8302: 'latin-1' codec can't encode character '\u2019' in position 161: ordinal not in range(256)
# 10.1111/ele.12939
# 200
# An error occurred for 10.1111/ele.12939: 'latin-1' codec can't encode character '\u2010' in position 75: ordinal not in range(256)
# 10.5285/fff8afee-4978-495e-9210-120872983a8d
# 200
# 10.5285/5d63777d-b375-4791-918f-9a5527093298
# 200
# 10.1016/j.gloenvcha.2019.101944
# 200
# 10.1111/fwb.13402
# 200
# An error occurred for 10.1111/fwb.13402: 'latin-1' codec can't encode character '\u2010' in position 151: ordinal not in range(256)
# 10.1016/j.watres.2019.115136
# 200
# 10.1038/s41597-019-0269-1
# 200
# An error occurred for 10.1038/s41597-019-0269-1: 'latin-1' codec can't encode character '\u2013' in position 146: ordinal not in range(256)
# 10.1111/icad.12345
# 200
# An error occurred for 10.1111/icad.12345: 'latin-1' codec can't encode character '\u2013' in position 181: ordinal not in range(256)
# 10.1016/j.agee.2019.106619
# 200
# An error occurred for 10.1016/j.agee.2019.106619: 'latin-1' codec can't encode character '\u2018' in position 83: ordinal not in range(256)
# 10.1016/j.scitotenv.2019.135573
# 200
# 10.1002/ece3.5613
# 200
# An error occurred for 10.1002/ece3.5613: 'latin-1' codec can't encode character '\u2013' in position 223: ordinal not in range(256)
# 10.1002/pan3.10042
# 200
# An error occurred for 10.1002/pan3.10042: 'latin-1' codec can't encode character '\u2013' in position 139: ordinal not in range(256)
# 10.1016/j.rse.2019.111410
# 200
# 10.1111/cobi.13316
# 200
# An error occurred for 10.1111/cobi.13316: 'latin-1' codec can't encode character '\u2010' in position 125: ordinal not in range(256)
# 10.1111/fwb.13369
# 200
# An error occurred for 10.1111/fwb.13369: 'latin-1' codec can't encode character '\u2013' in position 243: ordinal not in range(256)
# 10.1111/icad.12345
# 200
# An error occurred for 10.1111/icad.12345: 'latin-1' codec can't encode character '\u2013' in position 181: ordinal not in range(256)
# 10.1111/gcbb.12655
# 200
# An error occurred for 10.1111/gcbb.12655: 'latin-1' codec can't encode character '\u2013' in position 172: ordinal not in range(256)
# 10.1214/19-aoas1288
# 200
# 10.5285/2dd66461-94af-458f-a9d2-c24bb0bd0322
# 200
# 10.5285/0579d4a8-e315-41d7-af43-25fb50c7d3da
# 200
# 10.5285/8e0a573d-61a4-4a6f-9fca-fc34cbd5fb45
# 200
# 10.5285/77ca631f-a3a4-4f26-bc90-57bb17baa6fc
# 200
# 10.5285/77ca631f-a3a4-4f26-bc90-57bb17baa6fc
# 200
# 10.5285/2dd66461-94af-458f-a9d2-c24bb0bd0322
# 200
# 10.5285/ab953cb8-8675-4a85-b561-add6ceba015f
# 200
# 10.5285/a87b7897-354c-4435-a1bc-e6053e7569e0
# 200
# 10.5285/0579d4a8-e315-41d7-af43-25fb50c7d3da
# 200
# 10.5285/a87b7897-354c-4435-a1bc-e6053e7569e0
# 200
# 10.5285/0579d4a8-e315-41d7-af43-25fb50c7d3da
# 200
# 10.5285/ab953cb8-8675-4a85-b561-add6ceba015f
# 200
# 10.5285/2dd66461-94af-458f-a9d2-c24bb0bd0322
# 200
# 10.5285/8e0a573d-61a4-4a6f-9fca-fc34cbd5fb45
# 200
# 10.5285/77ca631f-a3a4-4f26-bc90-57bb17baa6fc
# 200
# 10.5285/a87b7897-354c-4435-a1bc-e6053e7569e0
# 200
# 10.5285/ab953cb8-8675-4a85-b561-add6ceba015f
# 200
# 10.5285/8e0a573d-61a4-4a6f-9fca-fc34cbd5fb45
# 200
# 10.5285/0579d4a8-e315-41d7-af43-25fb50c7d3da
# 200
# 10.1016/j.agee.2018.06.025
# 200
# An error occurred for 10.1016/j.agee.2018.06.025: 'latin-1' codec can't encode character '\u2013' in position 221: ordinal not in range(256)
# 10.1038/s41467-019-09393-6
# 200
# 10.1016/10.1111/jbi.13501
# 404
# 10.1016/10.5194/essd-9-445-2017
# 404
# 10.1016/10.1371/journal.pone.0190119
# 404
# 10.1016/10.5194/bg-14-2069-2017
# 404
# 10.1016/10.1371/journal.ppat.1006951
# 404
# 10.1016/10.1007/s40745-015-0067-3
# 404
# 10.1016/10.1007/s10336-018-1570-z
# 404
# 10.1016/10.5194/bg-14-799-2017
# 404
# 10.1016/10.1007/s11269-018-1914-8
# 404
# 10.1016/10.1038/sdata.2018.208
# 404
# 10.1016/10.1002/ece3.2725
# 404
# 10.1016/10.1007/s10584-018-2145-y
# 404
# 10.1007/s10584-018-2145-y
# 200
# An error occurred for 10.1007/s10584-018-2145-y: 'latin-1' codec can't encode character '\u2013' in position 189: ordinal not in range(256)
# 10.1016/10.1007/s00484-018-1509-3
# 404
# 10.1016/10.1016/j.scitotenv.2018.03.378
# 404
# 10.1016/10.1080/10548408.2019.1575787
# 404
# 10.1016/10.1002/wat2.1130
# 404
# 10.1016/10.1038/nature21709
# 404
# 10.1016/10.1111/1365-2664.12912
# 404
# 10.1016/10.1002/ecs2.2002
# 404
# 10.1016/10.1002/lno.10619
# 404
# 10.1016/10.5194/hess-21-4785-2017
# 404
# 10.1016/10.1038/s41467-017-01774-z
# 404
# 10.1016/10.1080/00063657.2014.962482
# 404
# 10.1016/10.1007/s10336-018-1570-z
# 404
# 10.1016/10.1038/ncomms13444
# 404
# 10.1016/10.1007/s10980-019-00844-5
# 404
# 10.1016/10.1186/s12864-015-1401-z
# 404
# 10.1016/10.5194/bg-14-1181-2017
# 404
# 10.1016/10.1111/fwb.12858
# 404
# 10.1016/10.1038/srep37041
# 404
# 10.1016/10.5194/essd-9-445-2017
# 404
# 10.1016/10.1111/eva.12395
# 404
# 10.1016/10.1371/journal.pone.0190119
# 404
# 10.1007/s11269-018-1914-8
# 200
# An error occurred for 10.1007/s11269-018-1914-8: 'latin-1' codec can't encode character '\u2013' in position 213: ordinal not in range(256)
# 10.1002/ece3.2725
# 200
# ...
# 200
# An error occurred for 10.2307/2649028: 'latin-1' codec can't encode character '\u2013' in position 123: ordinal not in range(256)
# 10.3390/taxonomy2010011
# 200
# An error occurred for 10.3390/taxonomy2010011: 'latin-1' codec can't encode character '\u2013' in position 200: ordinal not in range(256)
# 10.1007/978-3-319-41674-8_3
# 200
# An error occurred for 10.1007/978-3-319-41674-8_3: 'latin-1' codec can't encode character '\u2013' in position 97: ordinal not in range(256)
# 10.5285/cdbca137-0bb3-4281-b872-399a4df8e946
# 200
# 10.1029/2020gl087311
# 200
# An error occurred for 10.1029/2020gl087311: 'latin-1' codec can't encode character '\u2010' in position 115: ordinal not in range(256)
# 10.1029/2004ja010851
# 200
# 10.1002/2013ja019281
# 200
# An error occurred for 10.1002/2013ja019281: 'latin-1' codec can't encode character '\u2010' in position 56: ordinal not in range(256)
# 10.1002/2014ja020366
# 200
# An error occurred for 10.1002/2014ja020366: 'latin-1' codec can't encode character '\u2013' in position 209: ordinal not in range(256)
# 10.5285/2b0afaea-6931-4a7a-b72f-23feeed2d22a
# 200
# An error occurred for 10.5285/2b0afaea-6931-4a7a-b72f-23feeed2d22a: 'latin-1' codec can't encode character '\u03bb' in position 135: ordinal not in range(256)
# 10.1029/97ja02919
# 200
# An error occurred for 10.1029/97ja02919: 'latin-1' codec can't encode character '\u2019' in position 64: ordinal not in range(256)
# 10.5285/5ef0d6cd-67c2-48fc-8a6a-dfe44a63979e
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/82907459c1c74495874df13503053e3c
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/acbe9091dc4249fb94f02aa9064582fe
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/2ffddce56f01468b888b01942eba75dc
# 200
# 10.5285/ca81ecd6acd441ac89fc5b505a355102
# 200
# 10.5285/eb49848446ef41dcad6c45658b8c644a
# 200
# 10.5285/edf7a41f4c4a40b8946c21ab1cab5d47
# 200
# 10.5285/340711b723124764bd42f39c4465d728
# 200
# 10.5285/3f7d71a981d341708bcb4db1edbff62e
# 200
# 10.5285/4b30bf7c8f1243bcbc70c4816356a8d6
# 200
# 10.5285/a88dca766a6f4059bf60a866258f4903
# 200
# 10.5285/1a072df93a19434e85b4fff7fabfdafa
# 200
# 10.5285/f8c4787b-fcdb-4514-8a03-76ed93f47de5
# 200
# 10.5285/d80f5c86-89a7-46d6-8718-47e3d34ab368
# 200
# 10.3189/2013aog64a201
# 200
# An error occurred for 10.3189/2013aog64a201: 'latin-1' codec can't encode character '\u2013' in position 157: ordinal not in range(256)
# 10.5285/c5fa84fb-f6e3-4780-8517-de0f78b62ea3
# 200
# 10.5285/5f545c54-6d76-4328-ba10-9a358456f035
# 200
# 10.3189/002214308787779988
# 200
# An error occurred for 10.3189/002214308787779988: 'latin-1' codec can't encode character '\u2013' in position 136: ordinal not in range(256)
# 10.1086/695767
# 200
# An error occurred for 10.1086/695767: 'latin-1' codec can't encode character '\u2019' in position 90: ordinal not in range(256)
# 10.1007/s00300-014-1480-3
# 200
# An error occurred for 10.1007/s00300-014-1480-3: 'latin-1' codec can't encode character '\u2013' in position 204: ordinal not in range(256)
# 10.1007/s00300-014-1584-9
# 200
# An error occurred for 10.1007/s00300-014-1584-9: 'latin-1' codec can't encode character '\u2013' in position 231: ordinal not in range(256)
# 10.3354/meps12861
# 200
# An error occurred for 10.3354/meps12861: 'latin-1' codec can't encode character '\u2013' in position 205: ordinal not in range(256)
# 10.1016/j.pocean.2018.09.017
# 200
# An error occurred for 10.1016/j.pocean.2018.09.017: 'latin-1' codec can't encode character '\u2013' in position 244: ordinal not in range(256)
# 10.3354/meps11527
# 200
# An error occurred for 10.3354/meps11527: 'latin-1' codec can't encode character '\u2013' in position 233: ordinal not in range(256)
# 10.1111/jfb.12776
# 200
# An error occurred for 10.1111/jfb.12776: 'latin-1' codec can't encode character '\u2013' in position 206: ordinal not in range(256)
# 10.3354/meps12093
# 200
# An error occurred for 10.3354/meps12093: 'latin-1' codec can't encode character '\u2013' in position 198: ordinal not in range(256)
# 10.1016/j.dsr2.2011.07.003
# 200
# An error occurred for 10.1016/j.dsr2.2011.07.003: 'latin-1' codec can't encode character '\u2013' in position 310: ordinal not in range(256)
# 10.1016/j.dsr2.2011.07.002
# 200
# An error occurred for 10.1016/j.dsr2.2011.07.002: 'latin-1' codec can't encode character '\u2013' in position 306: ordinal not in range(256)
# 10.1016/j.enggeo.2013.01.010
# 200
# An error occurred for 10.1016/j.enggeo.2013.01.010: 'latin-1' codec can't encode character '\u2013' in position 326: ordinal not in range(256)
# 10.1594/pangaea.781962
# 200
# 10.5285/c73b01f0-c015-4312-e053-6c86abc08369
# 200
# 10.1016/0045-7949(87)90180-5
# 200
# An error occurred for 10.1016/0045-7949(87)90180-5: 'latin-1' codec can't encode character '\u2013' in position 151: ordinal not in range(256)
# 10.5285/59e5a6f5-e67d-4a05-99af-30f656569401
# 200
# 10.5285/0c3a6698-1078-4465-a2c0-ca17ca0a0c39
# 200
# 10.5285/d762710b-562b-41a6-b9b4-adb26bfad4c6
# 200
# 10.5285/926b5321-408f-4560-b72d-f38bbe97ac21
# 200
# 10.5285/cdf7e028-0274-4db7-a2ec-180220b1dd71
# 200
# 10.1017/s0954102014000339
# 200
# An error occurred for 10.1017/s0954102014000339: 'latin-1' codec can't encode character '\u2013' in position 206: ordinal not in range(256)
# 10.5194/hess-2017-136
# 200
# 10.5285/4337ee2a-b428-4f78-a694-7c8b8e41d4bf
# 200
# 10.6084/m9.figshare.c.4498925
# 200
# An error occurred for 10.6084/m9.figshare.c.4498925: 'latin-1' codec can't encode character '\u2018' in position 91: ordinal not in range(256)
# 10.1111/jfb.12776
# 200
# An error occurred for 10.1111/jfb.12776: 'latin-1' codec can't encode character '\u2013' in position 206: ordinal not in range(256)
# 10.1007/s00300-016-2046-3
# 200
# An error occurred for 10.1007/s00300-016-2046-3: 'latin-1' codec can't encode character '\u2013' in position 265: ordinal not in range(256)
# 10.5061/dryad.gc67t
# 200
# An error occurred for 10.5061/dryad.gc67t: 'latin-1' codec can't encode character '\u2019' in position 101: ordinal not in range(256)
# 10.3389/fmars.2019.00530
# 200
# 10.1016/j.dsr2.2011.07.003
# 200
# An error occurred for 10.1016/j.dsr2.2011.07.003: 'latin-1' codec can't encode character '\u2013' in position 310: ordinal not in range(256)
# 10.1007/s00300-014-1480-3
# 200
# An error occurred for 10.1007/s00300-014-1480-3: 'latin-1' codec can't encode character '\u2013' in position 204: ordinal not in range(256)
# 10.1007/s00300-014-1584-9
# 200
# An error occurred for 10.1007/s00300-014-1584-9: 'latin-1' codec can't encode character '\u2013' in position 231: ordinal not in range(256)
# 10.5285/5798742d-dd5f-480b-8298-2c2b449cbab3
# 200
# 10.3354/meps08064
# 200
# An error occurred for 10.3354/meps08064: 'latin-1' codec can't encode character '\u2013' in position 183: ordinal not in range(256)
# 10.3354/meps11527
# 200
# An error occurred for 10.3354/meps11527: 'latin-1' codec can't encode character '\u2013' in position 233: ordinal not in range(256)
# 10.1007/s00300-008-0423-2
# 200
# An error occurred for 10.1007/s00300-008-0423-2: 'latin-1' codec can't encode character '\u2013' in position 247: ordinal not in range(256)
# 10.1016/j.pocean.2018.09.017
# 200
# An error occurred for 10.1016/j.pocean.2018.09.017: 'latin-1' codec can't encode character '\u2013' in position 244: ordinal not in range(256)
# 10.5285/1f19a50c-b600-4f63-9512-e6c94f79d49c
# 200
# 10.5285/cd213efe-a8d2-493c-9e2d-a4e6f7242eb5
# 200
# 10.5285/e38c58a6-48ec-4ad1-a996-6c6144968d7d
# 200
# 10.5285/153a5938-bbcd-4264-aa65-f5ee1fd86e23
# 200
# 10.5285/49a1ec0e-ae5f-4df5-a59b-fa6dff614678
# 200
# 10.1016/j.dsr2.2006.05.004
# 200
# An error occurred for 10.1016/j.dsr2.2006.05.004: 'latin-1' codec can't encode character '\u2013' in position 225: ordinal not in range(256)
# 10.5285/90c6703c-08ad-155d-e053-6c86abc0b870
# 200
# 10.5285/908f84ec-d20c-7c88-e053-6c86abc08fda
# 200
# 10.5285/116a5210-2d58-5ceb-e053-6c86abc0d420
# 200
# 10.5285/6293f443-2670-59be-e053-6c86abc05dea
# 200
# 10.5285/626f2fa6-1595-5de6-e053-6c86abc0645d
# 200
# 10.3189/002214310791190848
# 200
# An error occurred for 10.3189/002214310791190848: 'latin-1' codec can't encode character '\u2013' in position 172: ordinal not in range(256)
# 10.1029/2007gl031207
# 200
# 10.3189/002214308786570872
# 200
# An error occurred for 10.3189/002214308786570872: 'latin-1' codec can't encode character '\u2013' in position 296: ordinal not in range(256)
# 10.1029/2008gl036369
# 200
# 10.7275/1929742
# 200
# 10.5281/zenodo.4289400
# 200
# 10.5281/zenodo.4266837
# 200
# 10.1038/s41396-019-0456-2
# 200
# An error occurred for 10.1038/s41396-019-0456-2: 'latin-1' codec can't encode character '\u2019' in position 136: ordinal not in range(256)
# 10.5285/e15d622c-5c7e-45e9-b127-f27def94bbe8
# 200
# 10.5285/e184e81a-e43c-424e-abec-122036ee2cfd
# 200
# 10.3389/fmars.2016.00136
# 200
# 10.1093/icesjms/fsaa031
# 200
# An error occurred for 10.1093/icesjms/fsaa031: 'latin-1' codec can't encode character '\u2013' in position 364: ordinal not in range(256)
# 10.3354/meps136037
# 200
# An error occurred for 10.3354/meps136037: 'latin-1' codec can't encode character '\u2013' in position 277: ordinal not in range(256)
# 10.1016/j.dsr2.2011.10.001
# 200
# An error occurred for 10.1016/j.dsr2.2011.10.001: 'latin-1' codec can't encode character '\u2013' in position 215: ordinal not in range(256)
# 10.1016/j.dsr2.2011.07.002
# 200
# An error occurred for 10.1016/j.dsr2.2011.07.002: 'latin-1' codec can't encode character '\u2013' in position 306: ordinal not in range(256)
# 10.3354/meps136037
# 200
# An error occurred for 10.3354/meps136037: 'latin-1' codec can't encode character '\u2013' in position 277: ordinal not in range(256)
# 10.5285/e15d622c-5c7e-45e9-b127-f27def94bbe8
# 200
# 10.5285/bfd7eb53-d07a-46e0-a185-54d7c4a829e2
# 200
# 10.3389/fmars.2016.00136
# 200
# 10.1594/pangaea.963392
# 200
# 10.1111/gcb.13834
# 200
# An error occurred for 10.1111/gcb.13834: 'latin-1' codec can't encode character '\u2010' in position 141: ordinal not in range(256)
# 10.3354/meps11527
# 200
# An error occurred for 10.3354/meps11527: 'latin-1' codec can't encode character '\u2013' in position 233: ordinal not in range(256)
# 10.1175/bams-d-15-00035.1
# 200
# An error occurred for 10.1175/bams-d-15-00035.1: 'latin-1' codec can't encode character '\u2013' in position 256: ordinal not in range(256)
# 10.1080/01490410903297766
# 200
# An error occurred for 10.1080/01490410903297766: 'latin-1' codec can't encode character '\u2013' in position 161: ordinal not in range(256)
# 10.5285/86a42d77-e190-4762-e053-6c86abc0deae
# 200
# 10.5285/86a42d77-e194-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d895-2c4c-e053-6c86abc0db01
# 200
# 10.5285/868f1e92-b51b-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/86a42d77-e192-4762-e053-6c86abc0deae
# 200
# 10.5285/868f1e92-b51c-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/868f1e92-b51c-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/86a42d77-e190-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d895-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86a42d77-e191-4762-e053-6c86abc0deae
# 200
# 10.5285/868f1e92-b51b-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/86a42d77-e194-4762-e053-6c86abc0deae
# 200
# 10.5285/868f1e92-b51c-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/86a42d77-e191-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d893-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86a42d77-e192-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d895-2c4c-e053-6c86abc0db01
# 200
# 10.5285/868f1e92-b51b-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/86a42d77-e190-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d894-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86a42d77-e194-4762-e053-6c86abc0deae
# 200
# 10.5285/868f1e92-b51b-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/868f1e92-b51c-7cf6-e053-6c86abc01bf7
# 200
# 10.5285/86a42d77-e191-4762-e053-6c86abc0deae
# 200
# 10.5285/86a42d77-e192-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d895-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86532abd-d895-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86a42d77-e194-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d893-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86a42d77-e190-4762-e053-6c86abc0deae
# 200
# 10.5285/86532abd-d894-2c4c-e053-6c86abc0db01
# 200
# 10.5285/86a42d77-e191-4762-e053-6c86abc0deae
# 200
# 10.5285/86a42d77-e192-4762-e053-6c86abc0deae
# 200
# 10.5285/868f1e92-b51c-7cf6-e053-6c86abc01bf7
# 200
# Done!

# %%
# add 'doi.org/' to data and pub dois in new columns
nerc_citations_df['data_doi_url'] = 'doi.org/' + nerc_citations_df['data_doi']
# need extra logic here as overton pub_doi column usually just a normal url
nerc_citations_df['publication_doi_url'] = nerc_citations_df['pub_doi'].apply(
    lambda x: f"doi.org/{x}" if x.startswith("10.") else x
)

# %%
# create publicationYear column from pub_date
def pub_year_splitter(date):
    if date == "Info not given":
        return None
    else:
        try:
            return date.split('/')[2]
        except:
            try:
                return date.split('-')[0]
            except:
                print(date)
                return None

nerc_citations_df['publicationYear'] = nerc_citations_df['pub_date'].apply(pub_year_splitter)
# Out:
# None
# None

# %%
# map to excected column names for API schema 
# data_Publisher	data_doi	data_Title	data_Authors	relation_type_id publication_doi	publication_type	publication_title	publication_authors	publication_date	citation_event_source	PubCitationStr data_doi_url	publication_doi_url	publicationYear

cols = {
    # 'old':'new',
    'relation_type':'relation_type_id', 
    'pub_doi':'publication_doi', 'pub_title':'publication_title', 'pub_date':'publication_date',
    'pub_authors':'publication_authors', 'source_id':'citation_event_source', 'pub_type':'publication_type',
    'pub_citation_str':'PubCitationStr'
}

nerc_citations_df_renamed = nerc_citations_df.rename(columns=cols)

# %%
# add index date_added

# read last week's result
old_results = pd.read_csv("Results/v3/latest_results.csv")

# Prepare a mapping of old pairs and date_added
date_map = (
    old_results[['data_doi', 'publication_doi', 'date_added']]
    .drop_duplicates(subset=['data_doi', 'publication_doi'])
    .set_index(['data_doi', 'publication_doi'])['date_added']
)

# map old dates onto new df
nerc_citations_df_renamed['date_added'] = nerc_citations_df_renamed.set_index(['data_doi', 'publication_doi']).index.map(date_map)

# Fill in today's date where no old date exists
nerc_citations_df_renamed['date_added'] = nerc_citations_df_renamed['date_added'].fillna(str(date.today()))

# %%
# write to csv and json file
results_folder_path = "Results/v3/"
#Results/v3
#/home/matnic/Projects/citationNotebook/Results/v3

latest_file_name_csv = results_folder_path + 'latest_results.csv'
nerc_citations_df_renamed.to_csv(latest_file_name_csv, index= False, encoding="utf-8-sig")

# write data to 'latest_results' json file with data publisher as top level key
latest_file_name_json = results_folder_path + 'latest_results.json'

# Group by 'data_Publisher' and convert the DataFrame to a nested dictionary
nested_dict = nerc_citations_df_renamed.groupby('data_publisher').apply(
    lambda x: x.drop('data_publisher', axis=1).to_dict(orient='records')
).to_dict()

# Convert the nested dictionary to a JSON object
import json
json_object = json.dumps(nested_dict, ensure_ascii=False)

# Save the JSON object to a file
with open(latest_file_name_json, 'w', encoding='utf-8') as f:
    f.write(json_object)
# Out:
# /tmp/ipykernel_2125/1122557546.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   nested_dict = nerc_citations_df_renamed.groupby('data_publisher').apply(

# %% [markdown]
# Development stuff below here:

# %%
row = nerc_citations_df_filtered[nerc_citations_df_filtered['pub_doi'] == "10.1016/j.jenvrad.2017.06.024"]
row['pub_authors'][31]
# Out:
# [['J.', 'Guillén'],
#  ['N.A.', 'Beresford'],
#  ['A.', 'Baeza'],
#  ['M.', 'Izquierdo'],
#  ['M.D.', 'Wood'],
#  ['A.', 'Salas'],
#  ['A.', 'Muñoz-Serrano'],
#  ['J.M.', 'Corrales-Vázquez'],
#  ['J.G.', 'Muñoz-Muñoz']]

# %%
nerc_citations_df_filtered.to_csv("encoding_test.csv", index=False, encoding="utf-8-sig")

# %%
# # code to filter out things like if pub_doi contians "egusphere" etc? - always a conference abstract
# count = 0
# for pub_doi in nerc_citations_df['pub_doi']:
#     if "egusphere" in pub_doi:
#         print(pub_doi)
#         count =count + 1
# print(count)

# %%
# nerc_citations_df['pub_citation_str'].value_counts()

# %%
# nerc_citations_df["pub_type"].value_counts()

# %%
# # take data_doi and pub_doi columns from each df, concatenate vertically
# doi_df = pd.concat([scholex_df[['data_doi', 'pub_doi']], dataCite_df[['data_doi', 'pub_doi']], overton_df[['data_doi', 'pub_doi']]], ignore_index=True)
# doi_df_unique = doi_df.drop_duplicates(subset=['data_doi', 'pub_doi'])
# print(len(doi_df))
# print(len(doi_df_unique))
