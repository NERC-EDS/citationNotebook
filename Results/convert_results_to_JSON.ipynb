# %%
import convertCSVtoJSON
csv_file_path = "C:/Users/matnic/OneDrive/OneDrive - UKCEH/Projects/DataCentre Citations/Results/dataset_citation_publication_info_2000-01-01_to_2023-03-01_retrieved_03032023.csv"
json_file_path = "C:/Users/matnic/OneDrive/OneDrive - UKCEH/Projects/DataCentre Citations/Results/dataset_citation_publication_info_2000-01-01_to_2023-03-01_retrieved_03032023.json"

convertCSVtoJSON.convertCSVtoJSON(csv_file_path, json_file_path)

# %%
import json

f = open("C:/Users/matnic/OneDrive/OneDrive - UKCEH/Projects/DataCentre Citations/Results/dataCitations_allSourcesMerged.json")
json_object = json.load(f)
json_formatted_str = json.dumps(json_object, indent=2)

# %%
json_object['Environmental Information Data Centre (EIDC)']
# Out:
# [{'data_Publisher': 'Environmental Information Data Centre (EIDC)',
#   'data_doi': '10.5285/bb15e200-9349-403c-bda9-b430093807c7',
#   'data_Title': 'Land Cover Map 2015 (25m raster, GB)',
#   'data_Authors': '[\'Rowland, C.S.\', \'Morton, R.D.\', \'Carrasco, L.\', \'McShane, G.\', "O\'Neil, A.W.", \'Wood, C.M.\']',
#   'relation_type_id': 'IsReferencedBy',
#   'publication_doi': '10.1007/s10531-020-01938-2',
#   'publication_type': 'journal-article',
#   'pub_publication_titleTitle': 'An empirical, cross-taxon evaluation of landscape-scale connectivity',
#   'publication_authors': "['Hunter-Ayad, James', 'Hassall, Christopher']",
#   'citation_event_source': 'Scholix'},
#  {'data_Publisher': 'Environmental Information Data Centre (EIDC)',
#   'data_doi': '10.5285/bb15e200-9349-403c-bda9-b430093807c7',
#   'data_Title': 'Land Cover Map 2015 (25m raster, GB)',
# ...
